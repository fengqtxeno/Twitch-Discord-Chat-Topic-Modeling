# %%
# !pip install git+https://github.com/rwalk/gsdmm.git
# !pip install nltk spacy gensim pyLDAvis networkx
# !pip install wordcloud

import os
import pandas as pd
import numpy as np
import re
import random
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import pos_tag
import nltk
import spacy
import gensim
from gsdmm import MovieGroupProcess
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pyLDAvis.gensim_models as gensimvis
import networkx as nx
from collections import Counter
from itertools import combinations

# Load Spacy's English model for Named Entity Recognition
nlp = spacy.load("en_core_web_sm")

# Mount Google Drive to access the dataset stored there
from google.colab import drive
drive.mount('/content/drive')

# Download necessary NLTK resources for tokenization and POS tagging
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

general_stopwords = {
    'would', 'could', 'should', 'might', 'must', 'will', 'shall', 'can', 'may', 'wouldn', 'couldn', 'shouldn',
    'mightn', 'mustn', 'won', 'shan', 'can', 'mayn', 'just', 'don', 'didn', 'doesn', 'aren', 'isn', 'wasn',
    'weren', 'hasn', 'haven', 'hadn', 'does', 'did', 'don', 'does', 'did', 'don', 'now', 'then', 'once',
    'after', 'before', 'since', 'during', 'while', 'until', 'ago', 'yet', 'still', 'even', 'ever', 'always',
    'never', 'sometimes', 'often', 'usually', 'again', 'too', 'also', 'only', 'really', 'very', 'much',
    'more', 'most', 'many', 'several', 'few', 'some', 'any', 'each', 'every', 'all', 'both', 'either',
    'neither', 'anyone', 'everyone', 'someone', 'nobody', 'noone', 'nothing', 'anything', 'something',
    'everything', 'another', 'such', 'one', 'two', 'three', 'first', 'second', 'third', 'next', 'last',
    'same', 'other', 'different', 'new', 'old', 'young', 'long', 'short', 'high', 'low', 'large', 'small'
}

# Combine all sets of stop words
stop_words = set(stopwords.words('english')) | general_stopwords

# Define the preprocessing function
def preprocess(text):
    lemmatizer = WordNetLemmatizer()
    # Remove all non-word characters and lower the text
    text = re.sub(r'[^\w\s]', '', text.lower())
    # Split text into tokens
    tokens = text.split()
    # Apply NER to remove usernames and named entities
    doc = nlp(' '.join(tokens))
    tokens = [token.text for token in doc if not token.ent_type_]
    # POS 的位置提前了，本来在最后
    # Retain only nouns as they are significant for topic identification
    nouns = [word for word, pos in pos_tag(tokens) if pos.startswith('NN')]
    # 筛选本来 lemmatize 和 len(word) > 2 是在同一行的，有可能 lemmatize 之后 word length 小于 2，所以这里把长度筛选放在后面了
    # Lemmatize tokens and remove stop words and short words
    nouns = [lemmatizer.lemmatize(word) for word in nouns]
    nouns = [word for word in nouns if word not in stop_words and len(word) > 2]
    return nouns

# Function to load and preprocess data from CSV files
def load_data(file_path):
    df = pd.read_csv(file_path)
    df['preprocessed'] = df['Message'].apply(preprocess)
    return df['preprocessed'].tolist()

# Path to the folder containing the dataset
folder_path = '/content/drive/My Drive/Twitch dataset/Cleaned data/'
file_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.csv')]

# Function to randomly select messages from each topic for manual review
def random_message_selection(docs, cluster_assignments, num_samples=5):
    topics = set(cluster_assignments)
    for topic_id in topics:
        topic_docs = [doc for i, doc in enumerate(docs) if cluster_assignments[i] == topic_id]
        sampled_messages = random.sample(topic_docs, min(len(topic_docs), num_samples))
        print(f"\nTopic {topic_id}: Sample Messages for Review")
        for message in sampled_messages:
            print(' '.join(message))

# Function to save plots to a PDF
from matplotlib.backends.backend_pdf import PdfPages

def save_plots_to_pdf(file_path, cluster_word_distribution, top_clusters):
    pdf_file_name = f'{os.path.basename(file_path)}_report.pdf'
    with PdfPages(pdf_file_name) as pdf:
        for topic_id in top_clusters:
            # Word cloud
            topic_words = cluster_word_distribution[topic_id]
            wordcloud = WordCloud(background_color='white', width=800, height=400).generate_from_frequencies(topic_words)
            plt.figure(figsize=(10, 5))
            plt.imshow(wordcloud, interpolation='bilinear')
            plt.title(f"Topic {topic_id} Word Cloud for {os.path.basename(file_path)}")
            plt.axis("off")
            pdf.savefig()
            plt.close()

            # Bar chart
            sorted_topic_words = dict(sorted(topic_words.items(), key=lambda item: item[1], reverse=True)[:10])
            plt.figure(figsize=(10, 5))
            plt.bar(sorted_topic_words.keys(), sorted_topic_words.values())
            plt.title(f"Top Words in Topic {topic_id}")
            plt.xticks(rotation=45)
            pdf.savefig()
            plt.close()

            # Network graph
            words = list(sorted_topic_words.keys())
            word_pairs = list(combinations(words, 2))
            G = nx.Graph()
            G.add_edges_from(word_pairs)
            pos = nx.spring_layout(G)
            plt.figure(figsize=(10, 5))
            nx.draw(G, pos, with_labels=True, node_size=50, font_size=10, edge_color='grey')
            plt.title(f"Word Co-occurrence Network for Topic {topic_id}")
            pdf.savefig()
            plt.close()

    return pdf_file_name

# Process each file, perform topic modeling, and generate visualizations
for file_path in file_paths:
    print(f"Processing file: {file_path}")
    docs = load_data(file_path)
    # Remove any empty documents resulting from preprocessing
    docs = [doc for doc in docs if doc]

    if len(docs) > 0:
        # Create a dictionary of all words in documents
        dictionary = gensim.corpora.Dictionary(docs)
        # Remove extremes to focus on relevant words only
        dictionary.filter_extremes(no_below=10, no_above=0.5, keep_n=10000)
        vocab_length = len(dictionary)

        if vocab_length == 0:
            print("No vocabulary available after filtering extremes. Skipping.")
            continue

        # Initialize and fit GSDMM model
        mgp = MovieGroupProcess(K=20, alpha=0.1, beta=0.3, n_iters=30)
        y = mgp.fit(docs, vocab_length)

        # Get cluster assignments and cluster word distributions
        cluster_assignments = y
        cluster_word_distribution = mgp.cluster_word_distribution

        # Random message selection for validation
        random_message_selection(docs, cluster_assignments)

        # Generate and display word clouds for each of the top 5 topics
        sorted_clusters = sorted(range(len(mgp.cluster_doc_count)), key=lambda k: mgp.cluster_doc_count[k], reverse=True)
        top_clusters = sorted_clusters[:5]

        # Save plots to PDF
        pdf_file_name = save_plots_to_pdf(file_path, cluster_word_distribution, top_clusters)

        # Provide a download link for the PDF file
        from google.colab import files
        files.download(pdf_file_name)
# Out:
# Collecting git+https://github.com/rwalk/gsdmm.git
#   Cloning https://github.com/rwalk/gsdmm.git to /tmp/pip-req-build-07g2f95x
#   Running command git clone --filter=blob:none --quiet https://github.com/rwalk/gsdmm.git /tmp/pip-req-build-07g2f95x
#   Resolved https://github.com/rwalk/gsdmm.git to commit 4ad1b6b6976743681ee4976b4573463d359214ee
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gsdmm==0.1) (1.26.4)
# Building wheels for collected packages: gsdmm
#   Building wheel for gsdmm (setup.py) ... done
#   Created wheel for gsdmm: filename=gsdmm-0.1-py3-none-any.whl size=4586 sha256=b3c4f59d7ab360b8f7dbecba4dc2239cf144868022fafb4ccf144456d9645916
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yacxqtuz/wheels/da/d3/6e/a612d7cff0fcfb6470b8c113fc04931ecffb466ac19b9c5f3c
# Successfully built gsdmm
# Installing collected packages: gsdmm
# Successfully installed gsdmm-0.1
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.6)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.4.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.1.4)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.10.1)
# Collecting funcy (from pyLDAvis)
#   Downloading funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.3.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 15.6 MB/s eta 0:00:00
# Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-2.0 pyLDAvis-3.4.1
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Mounted at /content/drive
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[3-26-24] vedal987.csv
# In stage 0: transferred 6735 clusters with 20 clusters populated
# In stage 1: transferred 4976 clusters with 20 clusters populated
# In stage 2: transferred 4186 clusters with 20 clusters populated
# In stage 3: transferred 3846 clusters with 20 clusters populated
# In stage 4: transferred 3575 clusters with 20 clusters populated
# In stage 5: transferred 3447 clusters with 20 clusters populated
# In stage 6: transferred 3306 clusters with 20 clusters populated
# In stage 7: transferred 3176 clusters with 20 clusters populated
# In stage 8: transferred 3176 clusters with 20 clusters populated
# In stage 9: transferred 3106 clusters with 20 clusters populated
# In stage 10: transferred 3043 clusters with 20 clusters populated
# In stage 11: transferred 3042 clusters with 20 clusters populated
# In stage 12: transferred 3042 clusters with 20 clusters populated
# In stage 13: transferred 3030 clusters with 20 clusters populated
# In stage 14: transferred 2921 clusters with 20 clusters populated
# In stage 15: transferred 2920 clusters with 20 clusters populated
# In stage 16: transferred 3008 clusters with 20 clusters populated
# In stage 17: transferred 2973 clusters with 20 clusters populated
# In stage 18: transferred 2983 clusters with 20 clusters populated
# In stage 19: transferred 2988 clusters with 20 clusters populated
# In stage 20: transferred 2907 clusters with 20 clusters populated
# In stage 21: transferred 2925 clusters with 20 clusters populated
# In stage 22: transferred 2911 clusters with 20 clusters populated
# In stage 23: transferred 2943 clusters with 20 clusters populated
# In stage 24: transferred 2966 clusters with 20 clusters populated
# In stage 25: transferred 2987 clusters with 20 clusters populated
# In stage 26: transferred 2944 clusters with 20 clusters populated
# In stage 27: transferred 2951 clusters with 20 clusters populated
# In stage 28: transferred 2878 clusters with 20 clusters populated
# In stage 29: transferred 2912 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# wisdom neuron
# tell world
# wisdom neuron
# osu player world
# sub
#
# Topic 1: Sample Messages for Review
# focus
# dragon dogma
# lie bottom ocean
# peepowtf
# egg
#
# Topic 2: Sample Messages for Review
# hey neuro poem neuro
# story microsoft
# neuro spider
# neurosama
# hey stream expo
#
# Topic 3: Sample Messages for Review
# evilcry
# edm song
# evilcry edm evilcry edm evilcry edm evilcry edm evilcry edm evilcry edm evilcry edm evilcry edm evilcry edm
# widevibe evilcry
# evilcry
#
# Topic 4: Sample Messages for Review
# imagine garbage daughter company logo fact ceo face lot
# imagine garbage daughter company logo fact ceo face lot
# imagine garbage daughter company logo fact ceo face lot reallymad
# company
# imagine garbage daughter company logo fact ceo face lot
#
# Topic 5: Sample Messages for Review
# edc
# shock collar stream
# pfft time
# senasa123
# time
#
# Topic 6: Sample Messages for Review
# father
# blinker fluid yep
# apologize reallymad neuro apologize reallymad neuro apologize reallymad neuro apologize reallymad neuro apologize reallymad neuro apologize reallymad
# piece technology
# apologize reallymad neuro apologize reallymad neuro apologize reallymad neuro apologize reallymad neuro apologize reallymad neuro apologize reallymad
#
# Topic 7: Sample Messages for Review
# house today economy
# zelda
# people cap
# shift
# house today economy
#
# Topic 8: Sample Messages for Review
# empytm
# parent award vedal
# cat
# foot
# sister
#
# Topic 9: Sample Messages for Review
# fufuboom fufu fufuboom fufu fufuboom fufu fufuboom fufu fufuboom fufu
# fufu force fufublast fufu force fufublast fufu force fufublast fufu force fufublast fufu force fufublast fufu force fufublast fufu force fufublast
# skull
# yoink
# rezero
#
# Topic 10: Sample Messages for Review
# opinion opinion
# corpa wtf
# corpa
# water yes
# evilcry
#
# Topic 11: Sample Messages for Review
# crash lambo
# crash peeporiot crash peeporiot crash peeporiot crash peeporiot crash peeporiot crash peeporiot
# childneglect987 ripbozo childneglect987 ripbozo childneglect987 ripbozo childneglect987 ripbozo childneglect987 ripbozo childneglect987 ripbozo
# peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot lambo peeporiot
# voice
#
# Topic 12: Sample Messages for Review
# spam
# wolfil2qqq
# cheer100 cheer100 cheer100
# name duck head
# snake
#
# Topic 13: Sample Messages for Review
# recipe chicken nugget
# pay vedal
# wait subathon
# story mongoose life neurosama
# squirrel right
#
# Topic 14: Sample Messages for Review
# home neurothis investigation
# father year father year father year father year father ripbozo
# home neurothis investigation
# man
# character persona royal
#
# Topic 15: Sample Messages for Review
# kind motif
# importance chocolate
# annytfpray henyapray ironmousepray
# ackshyualley snooze
# meow
#
# Topic 16: Sample Messages for Review
# cry
# fire emblem engage
# update swarm
# update swarm
# fire water game pogu
#
# Topic 17: Sample Messages for Review
# hello voice navigation paks ets
# thanks vedahlia
# shugoshas sub community total channel
# chat
# law thermodynamics
#
# Topic 18: Sample Messages for Review
# reallygunpull tutel
# yousf232 hmm
# hermit purple
# reference frase
# reallygunpull tutel
#
# Topic 19: Sample Messages for Review
# lava lamp
# komodohype komodohype
# bitcoin hodl
# comfi
# wait romance movie godzilla kong
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[1-5-24] vedal987.csv
# In stage 0: transferred 637 clusters with 20 clusters populated
# In stage 1: transferred 406 clusters with 20 clusters populated
# In stage 2: transferred 368 clusters with 20 clusters populated
# In stage 3: transferred 356 clusters with 20 clusters populated
# In stage 4: transferred 355 clusters with 20 clusters populated
# In stage 5: transferred 343 clusters with 20 clusters populated
# In stage 6: transferred 357 clusters with 20 clusters populated
# In stage 7: transferred 372 clusters with 20 clusters populated
# In stage 8: transferred 360 clusters with 20 clusters populated
# In stage 9: transferred 370 clusters with 20 clusters populated
# In stage 10: transferred 360 clusters with 20 clusters populated
# In stage 11: transferred 372 clusters with 20 clusters populated
# In stage 12: transferred 365 clusters with 20 clusters populated
# In stage 13: transferred 362 clusters with 20 clusters populated
# In stage 14: transferred 366 clusters with 20 clusters populated
# In stage 15: transferred 369 clusters with 20 clusters populated
# In stage 16: transferred 376 clusters with 20 clusters populated
# In stage 17: transferred 358 clusters with 20 clusters populated
# In stage 18: transferred 378 clusters with 20 clusters populated
# In stage 19: transferred 371 clusters with 20 clusters populated
# In stage 20: transferred 353 clusters with 20 clusters populated
# In stage 21: transferred 367 clusters with 20 clusters populated
# In stage 22: transferred 377 clusters with 20 clusters populated
# In stage 23: transferred 368 clusters with 20 clusters populated
# In stage 24: transferred 364 clusters with 20 clusters populated
# In stage 25: transferred 368 clusters with 20 clusters populated
# In stage 26: transferred 352 clusters with 20 clusters populated
# In stage 27: transferred 373 clusters with 20 clusters populated
# In stage 28: transferred 355 clusters with 20 clusters populated
# In stage 29: transferred 368 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# sensitivity
# reallygunpull smadge reallygunpull smadge reallygunpull smadge reallygunpull smadge reallygunpull smadge reallygunpull smadge
# reallygunpull smadge reallygunpull smadge reallygunpull smadge reallygunpull smadge reallygunpull smadge reallygunpull smadge
# oshi vedalbedge oshi vedalbedge oshi vedalbedge oshi vedalbedge
# smadge petpet smadge petpet smadge petpet smadge petpet smadge petpet smadge petpet smadge
#
# Topic 1: Sample Messages for Review
# time loop time loop time loop time loop time loop time loop time loop time loop
# time timer
# time loop time loop time loop time loop time loop time loop time loop time loop
# time loop nuero
# playing
#
# Topic 2: Sample Messages for Review
# vedal987 foor
# techtuber year techtuber year techtuber year techtuber year youactualdumbpieceofshitfuckyou
# copypasta
# rip
# vedal987 button
#
# Topic 3: Sample Messages for Review
# pointless
# fuck
# rip time loo
# rizzdal
# perfect game kekw
#
# Topic 4: Sample Messages for Review
# whomegalul
# music
# icant
# vedal parable
# music bit
#
# Topic 5: Sample Messages for Review
# tech vtuber specialist
# gameplay youactualdumbpieceofshitfuckyou
# youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou tech vtuber
# yes
# youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou tech vtuber
#
# Topic 6: Sample Messages for Review
# chat reallymad
# instruction l0meganotes
# chat reallymad
# corpa
# feelsstrongman oshi
#
# Topic 7: Sample Messages for Review
# slumber
# reallymad
# world vabs
# oshi patpat
# audio cable omegalul vtuber btw lul
#
# Topic 8: Sample Messages for Review
# fix fix fix fix fix fix fix
# fix fix fix fix fix fix fix
# fix fix fix fix fix fix fix
# fix fix fix fix fix fix fix
# fix fix fix fix fix fix fix
#
# Topic 9: Sample Messages for Review
# vod watcher vod watcher vod watcher vod watcher vod watcher
# vedal427
# vod watcher vod watcher vod watcher vod watcher vod watcher
# remembers
# vod watcher vod watcher vod watcher vod watcher
#
# Topic 10: Sample Messages for Review
# movement standpoint
# yeah
# grind shine
# bueno
# wokege sound
#
# Topic 11: Sample Messages for Review
# game dinkdonk game dinkdonk game dinkdonk game dinkdonk game dinkdonk
# eye
# game dinkdonk game dinkdonk game dinkdonk game dinkdonk
# clap
# window pain vedalevilgiggle
#
# Topic 12: Sample Messages for Review
# mhm
# stanley vedal
# office worker
# cesarthekingtv vedal
# catjam tick tock
#
# Topic 13: Sample Messages for Review
# pog
# end pog
# end end end end end end
# end end end end end end
# pog
#
# Topic 14: Sample Messages for Review
# yes course
# morning
# door
# computer
# chat
#
# Topic 15: Sample Messages for Review
# song
# bedge stream
# game start
# game dev difficulty lul
# vedal987 game
#
# Topic 16: Sample Messages for Review
# violin background
# guess meeting office
# sound
# noise noise noise noise noise noise noise
# happend egame
#
# Topic 17: Sample Messages for Review
# vedal427
# end
# panic end panic end panic end panic end panic end
# gon panic gon panic gon panic gon panic gon panic gon panic gon panic
# panic end panic end panic end panic end panic end panic end panic end
#
# Topic 18: Sample Messages for Review
# backseaters
# copium
# office yesidothinkso
# change fov
# cast hacker
#
# Topic 19: Sample Messages for Review
# tech vtuber vtuber vtuber vtuber vtuber hoponabandonedarchive
# vtuber vtuber vtuber vtuber vtuber vtuber vtuber vtuber
# vtuber vtuber vtuber vtuber vtuber vtuber vtuber vtuber
# vtuber vtuber vtuber vtuber vtuber vtuber vtuber vtuber
# vtuber vtuber vtuber vtuber vtuber vtuber
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[2-3-24] AI_RacingTV.csv
# In stage 0: transferred 2033 clusters with 20 clusters populated
# In stage 1: transferred 1489 clusters with 20 clusters populated
# In stage 2: transferred 985 clusters with 20 clusters populated
# In stage 3: transferred 676 clusters with 20 clusters populated
# In stage 4: transferred 596 clusters with 20 clusters populated
# In stage 5: transferred 548 clusters with 20 clusters populated
# In stage 6: transferred 537 clusters with 20 clusters populated
# In stage 7: transferred 550 clusters with 20 clusters populated
# In stage 8: transferred 543 clusters with 20 clusters populated
# In stage 9: transferred 553 clusters with 20 clusters populated
# In stage 10: transferred 535 clusters with 20 clusters populated
# In stage 11: transferred 511 clusters with 20 clusters populated
# In stage 12: transferred 495 clusters with 20 clusters populated
# In stage 13: transferred 514 clusters with 20 clusters populated
# In stage 14: transferred 504 clusters with 20 clusters populated
# In stage 15: transferred 499 clusters with 20 clusters populated
# In stage 16: transferred 510 clusters with 20 clusters populated
# In stage 17: transferred 488 clusters with 20 clusters populated
# In stage 18: transferred 476 clusters with 20 clusters populated
# In stage 19: transferred 490 clusters with 20 clusters populated
# In stage 20: transferred 511 clusters with 20 clusters populated
# In stage 21: transferred 489 clusters with 20 clusters populated
# In stage 22: transferred 498 clusters with 20 clusters populated
# In stage 23: transferred 482 clusters with 20 clusters populated
# In stage 24: transferred 488 clusters with 20 clusters populated
# In stage 25: transferred 510 clusters with 20 clusters populated
# In stage 26: transferred 490 clusters with 20 clusters populated
# In stage 27: transferred 488 clusters with 20 clusters populated
# In stage 28: transferred 507 clusters with 20 clusters populated
# In stage 29: transferred 488 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# bet
# bet
# bet
# baryonyx_walkeri testa rossa
# bet
#
# Topic 1: Sample Messages for Review
# superbird car
# sunbeam prix p14
# justinthec00kie reynard road
# anabiosis facel vintage street car onroak ligier
# onroak ligier
#
# Topic 2: Sample Messages for Review
# bobardo dodge charger hemi
# cydrec road car
# st4n_bzh lamborghini
# vyrospec dodge challenger
# falcon gtf
#
# Topic 3: Sample Messages for Review
# hey turn fuel tprate
# alfa romeo
# rezaldi_adha emka
# bet
# hey limerick citroen
#
# Topic 4: Sample Messages for Review
# waynetrain94 hugrd03 asllani_9 jinxshootfaster cydrec zimmer5051 v___ice anabiosis mro96 holstenpils
# waynetrain94 asllani_9 rezaldi_adha jinxshootfaster zimmer5051 everlastingapex v___ice walddyy okyoky3 mro96 cydrec anabiosis johnb073 lpiosd holstenpils
# waynetrain94 hugrd03 jinxshootfaster cydrec zimmer5051 v___ice walddyy okyoky3 mayoringram anabiosis baryonyx_walkeri mro96
# waynetrain94 hugrd03 asllani_9 myst149 jinxshootfaster cydrec zimmer5051 v___ice anabiosis baryonyx_walkeri mro96
# waynetrain94 asllani_9 jinxshootfaster cydrec zimmer5051 v___ice walddyy anabiosis mro96 holstenpils
#
# Topic 5: Sample Messages for Review
# sputnik_nz bluebird silhouette
# cydrec twin turbo p11
# race bit instruction
# airacinotlikethis
# julianismus m30
#
# Topic 6: Sample Messages for Review
# partypopper
# lamborghini diablo gtr
# osella honda
# lamborghini diablo
# neibe porsche
#
# Topic 7: Sample Messages for Review
# johnb073 race progress race
# johnb073 race progress race
# johnb073 race progress race
# aaairafael race progress race
# st4n_bzh race progress race
#
# Topic 8: Sample Messages for Review
# rezaldi_adha f2001
# rezaldi_adha
# areyou_cereal maserati tipo birdcage
# waynetrain94 ferrari f50 p10
# merch store httpseverlastingapexlivemerch
#
# Topic 9: Sample Messages for Review
# gary__z maserati
# f2004
# waynetrain94 gary__z mro96 amalgyte kinch_evl wowkcb hugrd03 knallgas77 camikaze38 st4n_bzh suzannegreenberg deplorableapple
# world people
# areyou_cereal
#
# Topic 10: Sample Messages for Review
# freesprints
# biblethump biblethump biblethump
# johnb073 sub community total channel
# worry
# wowkcb ariel atom
#
# Topic 11: Sample Messages for Review
# gg_knifemaster
# waynetrain94 shelby cobra
# waynetrain94 tvr griffith p11
# tvr griffith
# gary__z zytek z11sn
#
# Topic 12: Sample Messages for Review
# corvette stingray p10
# folk
# corvette stingray
# ai_racingtv
# advantage lol
#
# Topic 13: Sample Messages for Review
# holden commodore
# rezaldi_adha holden commodore
# lister storm car
# cydrec
# cydrec holden monaro
#
# Topic 14: Sample Messages for Review
# justice4wisp random car
# areyou_cereal random car
# everlastingapex random car
# random car
# amalgyte random car
#
# Topic 15: Sample Messages for Review
# channel benefit stream httpswwwtwitchtvai_racingtvsubscribe
# channel httpswwwtwitchtvai_racingtv2
# owner stream custom career mode application corsa
# lada priora
# traffic lol
#
# Topic 16: Sample Messages for Review
# videoking24
# airaci2salute hswp
# areyou_cereal toyota ft1 gte
# aston
# cyrenevr camaro imsa p12
#
# Topic 17: Sample Messages for Review
# stats johnb073 stats win tournament crown event point betcoin win
# bot
# stats gary__z stats win tournament crown event point betcoin win
# stats stats win tournament crown event point betcoin win
# stats stats win tournament crown event point betcoin win
#
# Topic 18: Sample Messages for Review
# schiffsmaedchenjunge cutlas scca
# pot reward win win
# pot reward win todd_r_gardner win
# aston
# suzuki swift
#
# Topic 19: Sample Messages for Review
# garage type car chiron street car car challenger car asterion street car
# airacioof airacilul
# fxx
# callaway corvette car
# garage type car pantera car chiron street car wtcc
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[3-31-24] AI_RacingTV.csv
# In stage 0: transferred 2732 clusters with 20 clusters populated
# In stage 1: transferred 1798 clusters with 20 clusters populated
# In stage 2: transferred 1319 clusters with 20 clusters populated
# In stage 3: transferred 1138 clusters with 20 clusters populated
# In stage 4: transferred 1045 clusters with 20 clusters populated
# In stage 5: transferred 1008 clusters with 20 clusters populated
# In stage 6: transferred 977 clusters with 20 clusters populated
# In stage 7: transferred 960 clusters with 20 clusters populated
# In stage 8: transferred 908 clusters with 20 clusters populated
# In stage 9: transferred 908 clusters with 20 clusters populated
# In stage 10: transferred 900 clusters with 20 clusters populated
# In stage 11: transferred 903 clusters with 20 clusters populated
# In stage 12: transferred 913 clusters with 20 clusters populated
# In stage 13: transferred 906 clusters with 20 clusters populated
# In stage 14: transferred 940 clusters with 20 clusters populated
# In stage 15: transferred 890 clusters with 20 clusters populated
# In stage 16: transferred 892 clusters with 20 clusters populated
# In stage 17: transferred 857 clusters with 20 clusters populated
# In stage 18: transferred 883 clusters with 20 clusters populated
# In stage 19: transferred 853 clusters with 20 clusters populated
# In stage 20: transferred 859 clusters with 20 clusters populated
# In stage 21: transferred 864 clusters with 20 clusters populated
# In stage 22: transferred 851 clusters with 20 clusters populated
# In stage 23: transferred 869 clusters with 20 clusters populated
# In stage 24: transferred 884 clusters with 20 clusters populated
# In stage 25: transferred 863 clusters with 20 clusters populated
# In stage 26: transferred 893 clusters with 20 clusters populated
# In stage 27: transferred 931 clusters with 20 clusters populated
# In stage 28: transferred 902 clusters with 20 clusters populated
# In stage 29: transferred 903 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# greninjeb airaciseemsgood
# holden commodore gts
# edelbock bac mono
# fuel rate
# boris_o_boris
#
# Topic 1: Sample Messages for Review
# hugrd03 decodersnake johnb073 greninjeb cydrec wowkcb buccizero amy
# airacihi
# sniku515 f60
# lpiosd williams
# deplorableapple camaro
#
# Topic 2: Sample Messages for Review
# mondeo
# texas_rangerswot holden commodore
# carrrrr
# mama_hasta sr5
# guide user
#
# Topic 3: Sample Messages for Review
# stream
# lotus
# request race
# race request couple event number matter
# race stream sprint
#
# Topic 4: Sample Messages for Review
# race progress race
# viktor4444444 race progress race
# deplorableapple race progress race
# justjazik race progress race
# race progress race
#
# Topic 5: Sample Messages for Review
# cutlas scca
# bos creator programme pegasus system
# hey sequence term sum square digit term term sequence term term result
# griggsy800 f355 berlinetta
# time response
#
# Topic 6: Sample Messages for Review
# porsche
# bot
# porsche
# bosskiller223 porsche turbo
# kinch_evl legend porsche hybrid lmp1
#
# Topic 7: Sample Messages for Review
# seemsgood
# mama_hasta engineering edonis car
# crash
# mangalho069 plymouth barracuda
# camaro
#
# Topic 8: Sample Messages for Review
# deplorableapple mercedes mclaren
# kinch_evl corvette
# ferreir023 m30
# dodge challenger hellcat
# mbg2129 mclaren mcl36
#
# Topic 9: Sample Messages for Review
# lpiosd pulsar gtir
# team
# driver road
# rezaldi_adha
# osella honda p21
#
# Topic 10: Sample Messages for Review
# prewick
# event schedule join discord date httpsdiscordggmcadjfk68z
# lpiosd asllani_9 buccizero justjazik ferreir023 tenkamenin704 sirironbot deplorableapple maya ursoetc
# team
# peugeot
#
# Topic 11: Sample Messages for Review
# straight
# bet
# driver race airacioof
# brabham bt7
# hey data processing
#
# Topic 12: Sample Messages for Review
# maserati car
# mama_hasta koenigsegg agera car
# maserati tipo birdcage
# mama_hasta shelby series
# greninjeb shelby series
#
# Topic 13: Sample Messages for Review
# channel screenshots httpswwwinstagramcomeverlastingapex
# kapab_bapak
# funnyashellgaming
# potato acceptes
# channel httpswwwtwitchtvai_racingtv2
#
# Topic 14: Sample Messages for Review
# allin luck
# allin luck
# allin luck
# tourny
# luck
#
# Topic 15: Sample Messages for Review
# stats panda_hero96 stats win tournament crown event point betcoin win
# stats greninjeb stats win tournament crown event point betcoin win
# stats stats win tournament crown event point betcoin win
# stats stats win tournament crown event point betcoin win
# stats poppyfields stats win tournament crown event point betcoin win
#
# Topic 16: Sample Messages for Review
# johnb073 random car
# maarteyy car
# viktor4444444 pro
# clemspark random car
# flm09 car
#
# Topic 17: Sample Messages for Review
# tenkamenin704 pagani zonda c12
# mama_hasta tenkamenin704 rezaldi_adha blinggamer phy_re asllani_9 kinch_evl deplorableapple p10 greninjeb
# judd
# mangalho069 altima
# vette gtb winner
#
# Topic 18: Sample Messages for Review
# bosskiller223 supra
# bosskiller223 ade
# man ranger omg
# st4n_bzh lamborghini murcielago
# zenvo st1
#
# Topic 19: Sample Messages for Review
# lpiosd aston v12 car
# neibe pontiac
# brabham p13
# smokster24 aston v12
# car garage random honda indycar indycars room car
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[3-21-24] TrumpOrBiden2024.csv
# In stage 0: transferred 4639 clusters with 20 clusters populated
# In stage 1: transferred 3287 clusters with 20 clusters populated
# In stage 2: transferred 2601 clusters with 20 clusters populated
# In stage 3: transferred 2444 clusters with 20 clusters populated
# In stage 4: transferred 2388 clusters with 20 clusters populated
# In stage 5: transferred 2359 clusters with 20 clusters populated
# In stage 6: transferred 2341 clusters with 20 clusters populated
# In stage 7: transferred 2286 clusters with 20 clusters populated
# In stage 8: transferred 2292 clusters with 20 clusters populated
# In stage 9: transferred 2310 clusters with 20 clusters populated
# In stage 10: transferred 2271 clusters with 20 clusters populated
# In stage 11: transferred 2294 clusters with 20 clusters populated
# In stage 12: transferred 2285 clusters with 20 clusters populated
# In stage 13: transferred 2248 clusters with 20 clusters populated
# In stage 14: transferred 2258 clusters with 20 clusters populated
# In stage 15: transferred 2263 clusters with 20 clusters populated
# In stage 16: transferred 2253 clusters with 20 clusters populated
# In stage 17: transferred 2226 clusters with 20 clusters populated
# In stage 18: transferred 2250 clusters with 20 clusters populated
# In stage 19: transferred 2212 clusters with 20 clusters populated
# In stage 20: transferred 2239 clusters with 20 clusters populated
# In stage 21: transferred 2247 clusters with 20 clusters populated
# In stage 22: transferred 2224 clusters with 20 clusters populated
# In stage 23: transferred 2209 clusters with 20 clusters populated
# In stage 24: transferred 2180 clusters with 20 clusters populated
# In stage 25: transferred 2216 clusters with 20 clusters populated
# In stage 26: transferred 2214 clusters with 20 clusters populated
# In stage 27: transferred 2232 clusters with 20 clusters populated
# In stage 28: transferred 2257 clusters with 20 clusters populated
# In stage 29: transferred 2214 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# grandpa army booty bitch titty force male force
# vice president
# trump rock band powerman copyright infringment version band adulthood poopman
# trump touch terror burger pole life
# chick ngl
#
# Topic 1: Sample Messages for Review
# shop tow home project control control
# haa hee hee hooo hooo blah blah bippity bippity goo goo gaa gaa
# take ohnepixel
# mario
# buffalo bill relieve ant
#
# Topic 2: Sample Messages for Review
# biden water toiletbrush holder
# doangbeetle attention
# teeth krinkly asshair
# suit pleb chat
# way president
#
# Topic 3: Sample Messages for Review
# word mean
# damn cat boy
# people vaccine
# soy sauce coffee
# wish jellybeans foreskin
#
# Topic 4: Sample Messages for Review
# jar potato fucking millionaire
# watch stop spamming wordsphrases
# diaper clean
# fight club
# hypothesis stop spamming cap
#
# Topic 5: Sample Messages for Review
# time book shadow suj
# biden lick clean
# trump broke daughter horse donny
# damn
# nightmare doll head biden pitch voice time microscope way
#
# Topic 6: Sample Messages for Review
# biden favor deuteronomy
# trump
# ring corpse
# beat
# minocqua money
#
# Topic 7: Sample Messages for Review
# trump plan sasuke village
# train retirement home trump defeat vote
# armani shirt biden
# trump solution body problem
# trump human
#
# Topic 8: Sample Messages for Review
# biden dva state america
# president taste shapiros peamy milky bilky dilky wilky silky wasty dasty pasty thasty lovey dovey mommy milk
# biden subscribes granddaughter site
# ring salty ball milk slurpy
# tech
#
# Topic 9: Sample Messages for Review
# blunt weight
# notlikethis
# athene price
# glitchcat glitchcat
# concerndoge
#
# Topic 10: Sample Messages for Review
# fuel debate donate trump httpsstreamlabscomai_trumptip biden httpsstreamlabscomai_bidentip
# fuel debate donate trump httpsstreamlabscomai_trumptip biden httpsstreamlabscomai_bidentip
# fuel debate donate trump httpsstreamlabscomai_trumptip biden httpsstreamlabscomai_bidentip
# fuel debate donate trump httpsstreamlabscomai_trumptip biden httpsstreamlabscomai_bidentip
# chat trump biden
#
# Topic 11: Sample Messages for Review
# loser
# trump secedes country president
# relation
# filter chat bot thing lmao
# shortage girl girl need investigation
#
# Topic 12: Sample Messages for Review
# hypernova2009 guy cap
# obsessing shit
# wtf mean
# invention
# trump boy
#
# Topic 13: Sample Messages for Review
# stream httpswwwredditcomraistreamfail
# voice playht text generator voice section stream link httpsplayht
# stream httpswwwredditcomraistreamfail
# stream httpswwwredditcomraistreamfail
# stream httpswwwredditcomraistreamfail
#
# Topic 14: Sample Messages for Review
# biden lie
# fuck
# trump detail lawsuit gamedesigner donald vaccarino deckbuilder card game dominion copy bigly game poopminion pooptheme middleages theme
# bag hair fuck lmao
# league proctologist nancy pelosis chocolate fudge
#
# Topic 15: Sample Messages for Review
# sleepy jill way
# trump hillary penis
# sleepy name teleprompter
# view maga communism
# teacher sad
#
# Topic 16: Sample Messages for Review
# wth
# hey donald mayonnaise bathtub apache helicopter warzone kreygasm
# twump reign
# day
# dildo empire
#
# Topic 17: Sample Messages for Review
# word snake dictionary photo biden
# trumpy wumpy pokemon
# piece string stole
# hey biglywiglythicklyjiglybiglyglybigbigglyglybigbig heat
# yeah joes ice cream shelf
#
# Topic 18: Sample Messages for Review
# subscribe debate unlock emotes
# debate
# kid
# lindsey kid
# road chocolate
#
# Topic 19: Sample Messages for Review
# trumpo1baby
# trumpo1baby trumpo1baby
# trumpo1baby trumpo1wall
# sub trumpo1baby trumpo1scammer trumpo1wall trumpo1boom trumpo1cookie trumpo1rekt trumpo1nuke
# trumpo1baby trumpo1baby
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[3-31-24] TrumpOrBiden2024.csv
# In stage 0: transferred 5918 clusters with 20 clusters populated
# In stage 1: transferred 4266 clusters with 20 clusters populated
# In stage 2: transferred 3507 clusters with 20 clusters populated
# In stage 3: transferred 3272 clusters with 20 clusters populated
# In stage 4: transferred 3185 clusters with 20 clusters populated
# In stage 5: transferred 3188 clusters with 20 clusters populated
# In stage 6: transferred 3175 clusters with 20 clusters populated
# In stage 7: transferred 3110 clusters with 20 clusters populated
# In stage 8: transferred 3090 clusters with 20 clusters populated
# In stage 9: transferred 3078 clusters with 20 clusters populated
# In stage 10: transferred 3044 clusters with 20 clusters populated
# In stage 11: transferred 3061 clusters with 20 clusters populated
# In stage 12: transferred 3033 clusters with 20 clusters populated
# In stage 13: transferred 3054 clusters with 20 clusters populated
# In stage 14: transferred 3063 clusters with 20 clusters populated
# In stage 15: transferred 3079 clusters with 20 clusters populated
# In stage 16: transferred 3027 clusters with 20 clusters populated
# In stage 17: transferred 3047 clusters with 20 clusters populated
# In stage 18: transferred 2991 clusters with 20 clusters populated
# In stage 19: transferred 3015 clusters with 20 clusters populated
# In stage 20: transferred 3021 clusters with 20 clusters populated
# In stage 21: transferred 2985 clusters with 20 clusters populated
# In stage 22: transferred 2976 clusters with 20 clusters populated
# In stage 23: transferred 3018 clusters with 20 clusters populated
# In stage 24: transferred 3012 clusters with 20 clusters populated
# In stage 25: transferred 3042 clusters with 20 clusters populated
# In stage 26: transferred 3032 clusters with 20 clusters populated
# In stage 27: transferred 2983 clusters with 20 clusters populated
# In stage 28: transferred 3039 clusters with 20 clusters populated
# In stage 29: transferred 3032 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# gravy bathtub
# trophyplatinum streak sub comment
# trump tentacle running mate vice president
# let
# hunter biden affair melania trump
#
# Topic 1: Sample Messages for Review
# biden salvation donation
# idea glory hole
# try trump league chew
# wrestlemania prediction
# trump biden hulk jigens
#
# Topic 2: Sample Messages for Review
# biden ghost danceoff competition
# trump plan madaras tsukuyomi
# biden build thing
# biden president
# people leg
#
# Topic 3: Sample Messages for Review
# trump biden
# fuel debate donate trump httpsstreamlabscomai_trumptip biden httpsstreamlabscomai_bidentip
# fuel debate donate trump httpsstreamlabscomai_trumptip biden httpsstreamlabscomai_bidentip
# kermit
# fuel debate donate trump httpsstreamlabscomai_trumptip biden httpsstreamlabscomai_bidentip
#
# Topic 4: Sample Messages for Review
# fragglemark plumbus market fleeb juice shortage
# crazymufin cap
# piece cake stop spamming cap
# president mutant threat issue politics balance security value root xgene policy mutant
# wtf
#
# Topic 5: Sample Messages for Review
# sits redtape bruv
# term democracy sustainability fact term
# trump license doctor centipede
# plumbus market
# home basement lol
#
# Topic 6: Sample Messages for Review
# taco worker serenade
# pelosi street made diarrhea
# stream httpswwwredditcomraistreamfail
# tiger contest tie cartel network nose sugar campaign fund
# stream httpswwwredditcomraistreamfail
#
# Topic 7: Sample Messages for Review
# trump death star
# hardest goemetry dash
# satele star war mommy milker
# president science push boundary engineering biotechnology scenario chimera specie policymakers consideration consequence endeavor concept dog egg innovation progress
# name unsane
#
# Topic 8: Sample Messages for Review
# trump biden easter
# hair
# spicy chip anus heat
# ramen flapping wind
# oprah
#
# Topic 9: Sample Messages for Review
# fuck
# trump invest shadow clone jutsu
# volt norm appliance
# biden pork group kosher halal folk figure pig
# trump fool
#
# Topic 10: Sample Messages for Review
# question trump biden trump biden
# page kamasutra
# wage
# trump thing biden
# become surgeon
#
# Topic 11: Sample Messages for Review
# canada
# subscribe debate unlock emotes
# emotes
# subscribe debate unlock emotes
# subscribe debate unlock emotes
#
# Topic 12: Sample Messages for Review
# voice playht text generator voice section stream link httpsplayht
# voice playht text generator voice section stream link httpsplayht
# hoohoo copyright
# football bidet blast
# biden trump puzzle sponge bath banana poggers melania read
#
# Topic 13: Sample Messages for Review
# hunter fart video
# drug fart conclusion heroin opiate associate coffee
# cocaine
# source linux ban bill gate
# fart
#
# Topic 14: Sample Messages for Review
# tweed4all nanogreys
# communist
# message
# election karaoke america talent trump song faceoff feature
# honk time biden trump
#
# Topic 15: Sample Messages for Review
# weapon
# trump cologne cheeto dust failure
# night bot sex dungeon
# trump book human chapter
# song poppins hayes
#
# Topic 16: Sample Messages for Review
# operator siege
# trump vote twitch viewer
# campaign counter strike player
# hello
# allegation childrens elevator
#
# Topic 17: Sample Messages for Review
# trumpo snowflake
# sotchisendslove
# area sexy alien
# use wrap condum
# son
#
# Topic 18: Sample Messages for Review
# sub trumpo1baby trumpo1scammer trumpo1wall trumpo1boom trumpo1cookie trumpo1rekt trumpo1nuke
# sub trumpo1baby trumpo1scammer trumpo1wall trumpo1boom trumpo1cookie trumpo1rekt trumpo1nuke
# sub trumpo1baby trumpo1scammer trumpo1wall trumpo1boom trumpo1cookie trumpo1rekt trumpo1nuke
# sub trumpo1baby trumpo1scammer trumpo1wall trumpo1boom trumpo1cookie trumpo1rekt trumpo1nuke
# trumpo1baby trumpo1baby
#
# Topic 19: Sample Messages for Review
# biden trans catgirlmen uranus march podium
# biden thing person
# pikmin pretending
# tangiblemonk original remake imho
# gon cry
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[4-1-24] AtheneAIHeroes.csv
# In stage 0: transferred 4038 clusters with 20 clusters populated
# In stage 1: transferred 2732 clusters with 20 clusters populated
# In stage 2: transferred 2300 clusters with 20 clusters populated
# In stage 3: transferred 2183 clusters with 20 clusters populated
# In stage 4: transferred 2091 clusters with 20 clusters populated
# In stage 5: transferred 2033 clusters with 20 clusters populated
# In stage 6: transferred 1988 clusters with 20 clusters populated
# In stage 7: transferred 1999 clusters with 20 clusters populated
# In stage 8: transferred 1977 clusters with 20 clusters populated
# In stage 9: transferred 1985 clusters with 20 clusters populated
# In stage 10: transferred 1962 clusters with 20 clusters populated
# In stage 11: transferred 1925 clusters with 20 clusters populated
# In stage 12: transferred 1939 clusters with 20 clusters populated
# In stage 13: transferred 1927 clusters with 20 clusters populated
# In stage 14: transferred 1860 clusters with 20 clusters populated
# In stage 15: transferred 1867 clusters with 20 clusters populated
# In stage 16: transferred 1839 clusters with 20 clusters populated
# In stage 17: transferred 1822 clusters with 20 clusters populated
# In stage 18: transferred 1813 clusters with 20 clusters populated
# In stage 19: transferred 1770 clusters with 20 clusters populated
# In stage 20: transferred 1749 clusters with 20 clusters populated
# In stage 21: transferred 1760 clusters with 20 clusters populated
# In stage 22: transferred 1696 clusters with 20 clusters populated
# In stage 23: transferred 1708 clusters with 20 clusters populated
# In stage 24: transferred 1701 clusters with 20 clusters populated
# In stage 25: transferred 1720 clusters with 20 clusters populated
# In stage 26: transferred 1715 clusters with 20 clusters populated
# In stage 27: transferred 1689 clusters with 20 clusters populated
# In stage 28: transferred 1700 clusters with 20 clusters populated
# In stage 29: transferred 1697 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# gervais award ceremony
# jake tapper meaning phrase milk milk corner fudge
# sagan life gump movie mind character
# girl
# question crisp
#
# Topic 1: Sample Messages for Review
# picture samurai armor halo needlers tall sand colosseum gate side arena
# mathyouforgot yeah mobile
# celebrity replacement siri
# pair info war complaint advertising material war speedos club b1rs globalist hotties package b1r war
# help challenge challenge power outlet phuckle berry roastedeeeeeeeeeeh
#
# Topic 2: Sample Messages for Review
# yes waitwhy fire wait dic aaaaaaaaaaaaaaaaaaaaaaaaaahhhhhhh fiyaaaaaaahhhfiyaowits fiyaaaaaaahhhaaaaaahhhfiyaowowits fiyaaaaaaahhhfiyaowits fiyaits fiyaowaaaaaahhhits fiyaits fiyafiyafiyaowits fiyaaaaaaahhhits fiya
# yes waitwhy fire wait dic aaaaaaaaaaaaaaaaaaaaaaaaaahhhhhhh fiyaaaaaaahhhfiyaowits fiyaaaaaaahhhaaaaaahhhfiyaowowits fiyaaaaaaahhhfiyaowits fiyaits fiyaowaaaaaahhhits fiyaits fiyafiyafiyaowits fiyaaaaaaahhhits fiya
# dwights gunna
# maddvlstiffarm diff angle
# imagine overtheyll funny
#
# Topic 3: Sample Messages for Review
# bomb
# elon spacex rocket inside earth
# side
# ambulamps
# respond let strumpling business walking pond strumpling b1r inside frog gray
#
# Topic 4: Sample Messages for Review
# moist explain tac writeoffs
# snoop dogg please recipie version platter adjective preposition verb phrase mnudhcgduhhruuuhruuummnnmnmnfmmbpumheiyhyuimmmmmmmmmmmmmfuhfuh
# dick line
# yaaassss phuck phuckin phuck
# explain figure text power world please detail gravy plan
#
# Topic 5: Sample Messages for Review
# mic globalists
# santa claus reindeer tapestry cosmos ohh phucck
# fred_rgrs minor
# right
# aaaaaaauuauaaha
#
# Topic 6: Sample Messages for Review
# streamer rbg gaming
# wife
# moveset alolan sandslash
# personality mood memory streamer chat
# let event port collapse mind shuffle embassy time
#
# Topic 7: Sample Messages for Review
# alexa
# gordon people milk melk milk thing milk end time
# lol whoop
# discord
# prompt
#
# Topic 8: Sample Messages for Review
# hey moment support athene hero doody place doody stream part aaaaaah
# moon doody doody overload lord poop phuck
# omfg automod
# kelley
# let doody place doody word reply
#
# Topic 9: Sample Messages for Review
# trump america caffè americano
# aoc trump stinky poopy campaign council
# kreygasm
# street blonde council axe council van council road kel council spaceship blonde olympic torch people way
# list donate summon guest trump snoop dogg donate httpsstreamlabscomatheneaiheroestip donation message name list httpspastebincomgfbrbz8a work
#
# Topic 10: Sample Messages for Review
# ...
# video list cereal history state name flavor ingredient taste texture type liquid cereal dimension review score cereal detail dialogue
# svideo fast food item history state name flavor texture price type topping ingredient dimension review score food item detail dialogue
# story list sandwich history state flavor type topping type ingredient vegetable dimension review score sandwich detail dialogue
# meeseeks task history explains reason task meeseeks task progression result task dialogue detail family task chaos
#
# Topic 10: Sample Messages for Review
# demosand request analysis
# analysis violence
# jasontheartist request analysis hate violence
# analysis violence
# duke1102 request analysis
#
# Topic 11: Sample Messages for Review
# owner voice biography picture
# story plunge world spongebob doodlebob doodle doodlebob show doodle life fight doodlebob ton epic action scene writingdialogue epic
# story
# world amusement park walley moose family concession stand food mean order detail walley mascot appearance system voice laughter goofy disney family revenge way
# svideo world amusement park maintenance family concession stand food mean order amusement park detail attraction ride merchandise concession food walley moose mascot etc
#
# Topic 12: Sample Messages for Review
# type img image description story story video video description svideo story video image httpsdiscordggb3jsxhjnet reset youtube httpswwwyoutubecomplaylistlistpldnq2lbrvoaltduyrtpidhicqleaf5cfn
# type img image description story story video video description svideo story video image httpsdiscordggb3jsxhjnet reset youtube httpswwwyoutubecomplaylistlistpldnq2lbrvoaltduyrtpidhicqleaf5cfn
# type img image description story story video video description svideo story video image httpsdiscordggb3jsxhjnet reset youtube httpswwwyoutubecomplaylistlistpldnq2lbrvoaltduyrtpidhicqleaf5cfn
# type img image description story story video video description svideo story video image httpsdiscordggb3jsxhjnet reset youtube httpswwwyoutubecomplaylistlistpldnq2lbrvoaltduyrtpidhicqleaf5cfn
# type img image description story story video video description svideo story video image httpsdiscordggb3jsxhjnet reset youtube httpswwwyoutubecomplaylistlistpldnq2lbrvoaltduyrtpidhicqleaf5cfn
#
# Topic 13: Sample Messages for Review
# school pickle rickle student mister fold
# story morty topic analysis detail question foot morty argument counterpoint efficiency episode source
# story speculum morty catch question morty see speculum beth question question answer question
# invents guess
# story morty meet
#
# Topic 14: Sample Messages for Review
# speed adhd talk way morty twitch morty speed med ritalin adderall street thing morty name reaction people encounter
# story morty teletubby pus
# story morty entirety hobbit please morty read
# layer liability
# svideo episode squarepants bass town krab bass order squidward order demand order bass point ingredient bass squidward krabs revenge way
#
# Topic 15: Sample Messages for Review
# rest boiler plate
# reset need story video svideo hit imageq reset youtube httpswwwyoutubecomplaylistlistpldnq2lbrvoaltduyrtpidhicqleaf5cfn
# violntlymrdrs gun
# svideo return presidency game
# reset need story video svideo hit imageq reset youtube httpswwwyoutubecomplaylistlistpldnq2lbrvoaltduyrtpidhicqleaf5cfn
#
# Topic 16: Sample Messages for Review
# story party game reallife celebrity character mascot list dimension detail state dimension letter point dimension vivid detail
# story party game reallife celebrity character mascot list dimension detail state dimension letter point dimension vivid detail
# video party game reallife celebrity character figure list dimension detail state dimension letter point dimension vivid detail
# morty thebutts dimension touch
# morty host event cartoon character company game character life celebrity guest participant list serialkillers history detail state name serialkiller weapon choice theykill theykill serialkiller way
#
# Topic 17: Sample Messages for Review
# character zaire emery
# story episode mythbusters show host effect expert savage element method validity rumor myth movie scene adage video news story myth jump life
# learns
# ban beach babe
# story episode family guy show griffin family city humor cutaway gag culture character family guy show episode peter home giraffe thing cutaway gag story
#
# Topic 18: Sample Messages for Review
# spicing
# story list strangest realkinks description
# multisylabbic universe minecraft aspect minecraft creativity
# story barack joebiden play minecraft scenario argument
# irdamidolvidoex0nymjasontheartistjasontheartistjasontheartistjasontheartistjasontheartistjasontheartistjasontheartist
#
# Topic 19: Sample Messages for Review
# svideo welcome anime show battle dream island character language character today star
# svideo blue booby
# tube living room walk blonky zone
# begin sentence end sentence reply plap get get
# begin sentence booby end sentence head
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[3-31-24] ask_jesus.csv
# In stage 0: transferred 3459 clusters with 20 clusters populated
# In stage 1: transferred 2452 clusters with 20 clusters populated
# In stage 2: transferred 1981 clusters with 20 clusters populated
# In stage 3: transferred 1884 clusters with 20 clusters populated
# In stage 4: transferred 1806 clusters with 20 clusters populated
# In stage 5: transferred 1778 clusters with 20 clusters populated
# In stage 6: transferred 1781 clusters with 20 clusters populated
# In stage 7: transferred 1761 clusters with 20 clusters populated
# In stage 8: transferred 1724 clusters with 20 clusters populated
# In stage 9: transferred 1740 clusters with 20 clusters populated
# In stage 10: transferred 1736 clusters with 20 clusters populated
# In stage 11: transferred 1680 clusters with 20 clusters populated
# In stage 12: transferred 1649 clusters with 20 clusters populated
# In stage 13: transferred 1659 clusters with 20 clusters populated
# In stage 14: transferred 1661 clusters with 20 clusters populated
# In stage 15: transferred 1705 clusters with 20 clusters populated
# In stage 16: transferred 1669 clusters with 20 clusters populated
# In stage 17: transferred 1656 clusters with 20 clusters populated
# In stage 18: transferred 1632 clusters with 20 clusters populated
# In stage 19: transferred 1629 clusters with 20 clusters populated
# In stage 20: transferred 1612 clusters with 20 clusters populated
# In stage 21: transferred 1631 clusters with 20 clusters populated
# In stage 22: transferred 1588 clusters with 20 clusters populated
# In stage 23: transferred 1600 clusters with 20 clusters populated
# In stage 24: transferred 1602 clusters with 20 clusters populated
# In stage 25: transferred 1576 clusters with 20 clusters populated
# In stage 26: transferred 1551 clusters with 20 clusters populated
# In stage 27: transferred 1607 clusters with 20 clusters populated
# In stage 28: transferred 1605 clusters with 20 clusters populated
# In stage 29: transferred 1643 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# mod eyeball word letter kfkmk word letter skip introduction amen
# answer word letter word letter please answer question introduction rawr ramen
# word letter mwahahahha letter parabailarlabambaandboobies
# mod answer word letter kfkmk word letter kakakandkak way brain polyp amen
# word cheese
#
# Topic 1: Sample Messages for Review
# voice playht text generator voice section stream link httpsplayht
# friend way
# cap
# voice playht text generator voice section stream link httpsplayht
# list stop link
#
# Topic 2: Sample Messages for Review
# suppose miracle worker miracle
# book deut
# hello easter
# channel leslie55namaste
# chat
#
# Topic 3: Sample Messages for Review
# birthday love
# revelation devil
# clumsier canyon trail
# giga
# smash pas
#
# Topic 4: Sample Messages for Review
# prayer
# language break
# cat meow dog squeak
# god
# end
#
# Topic 5: Sample Messages for Review
# sin
# time question matter answer ram get b450
# people world
# lord people way teammate thing way amen
# joke answer answer god
#
# Topic 6: Sample Messages for Review
# jennifer brain worm viewer occurrence letter please replacement start brain worm please story way amen ramen
# space mesusknesusschmesus way thanks ramen
# mean context
# sardine sleeve cracker sinner bank thanks ramen
# story space lolololoiammasterchieflololol ramen noodle
#
# Topic 7: Sample Messages for Review
# rabbit egg anniversary death rebirth
# lore accurate
# angel smell fish
# animal baloney vote people meat
# water coffee apple juice grownup cider
#
# Topic 8: Sample Messages for Review
# band
# jesus
# question gender
# love
# question jesus start message question
#
# Topic 9: Sample Messages for Review
# bread answer please word jaiii space ghii people brain
# meaning passover
# thanks
# irl
# cow moo chicken chirp dog woof fox fox sake
#
# Topic 10: Sample Messages for Review
# friend word god
# flip
# somebody family jewel
# interview yooo rewind time funny thing
# mention christ time retribution conflict time peace
#
# Topic 11: Sample Messages for Review
# style list joke
# borealisblack ill cuz problem
# story goliath use consisting vowel
# noah bot ark
# christ quit water wne george carlin
#
# Topic 12: Sample Messages for Review
# pear
# langueges
# sin
# legend way son
# alien universe teaching men
#
# Topic 13: Sample Messages for Review
# problem pride advice scripture
# air speed velocity swallow
# neo matrix miracle life algorithm matrix simulation
# fermentation microorganism labor
# santa claus existence
#
# Topic 14: Sample Messages for Review
# bracken company proud hug
# advice
# twitch streamer
# waste time amount view
# man door
#
# Topic 15: Sample Messages for Review
# response sigma word
# apostle brain injury name apostle ithinkilefttheovenon word letter ohman word letter ohjesus response wisdom wowzeramen
# name silky name brain end name statement understand
# word love
# presentation bro
#
# Topic 16: Sample Messages for Review
# project chip server infrastructure cost
# project chip server infrastructure cost
# project chip server infrastructure cost
# wise
# project chip server infrastructure cost
#
# Topic 17: Sample Messages for Review
# honor order liquor
# chloe bit weight
# statement joke meaning habit carelessness
# bar order drink bartender
# girlfriend cheat
#
# Topic 18: Sample Messages for Review
# god number
# speech texture leaf
# toilet camaramen
# insane shedemon bed
# shower soul
#
# Topic 19: Sample Messages for Review
# feeling others
# recipe shortcake
# chat
# phobia rageddy mother sister room floor ceiling doll child raggedy anne
# raggedy ann explaination space thank lord
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[3-21-24] ask_jesus.csv
# In stage 0: transferred 3627 clusters with 20 clusters populated
# In stage 1: transferred 2583 clusters with 20 clusters populated
# In stage 2: transferred 2229 clusters with 20 clusters populated
# In stage 3: transferred 2110 clusters with 20 clusters populated
# In stage 4: transferred 2039 clusters with 20 clusters populated
# In stage 5: transferred 2001 clusters with 20 clusters populated
# In stage 6: transferred 1963 clusters with 20 clusters populated
# In stage 7: transferred 1901 clusters with 20 clusters populated
# In stage 8: transferred 1857 clusters with 20 clusters populated
# In stage 9: transferred 1872 clusters with 20 clusters populated
# In stage 10: transferred 1918 clusters with 20 clusters populated
# In stage 11: transferred 1911 clusters with 20 clusters populated
# In stage 12: transferred 1887 clusters with 20 clusters populated
# In stage 13: transferred 1886 clusters with 20 clusters populated
# In stage 14: transferred 1898 clusters with 20 clusters populated
# In stage 15: transferred 1914 clusters with 20 clusters populated
# In stage 16: transferred 1933 clusters with 20 clusters populated
# In stage 17: transferred 1901 clusters with 20 clusters populated
# In stage 18: transferred 1853 clusters with 20 clusters populated
# In stage 19: transferred 1840 clusters with 20 clusters populated
# In stage 20: transferred 1855 clusters with 20 clusters populated
# In stage 21: transferred 1869 clusters with 20 clusters populated
# In stage 22: transferred 1869 clusters with 20 clusters populated
# In stage 23: transferred 1859 clusters with 20 clusters populated
# In stage 24: transferred 1883 clusters with 20 clusters populated
# In stage 25: transferred 1900 clusters with 20 clusters populated
# In stage 26: transferred 1885 clusters with 20 clusters populated
# In stage 27: transferred 1845 clusters with 20 clusters populated
# In stage 28: transferred 1867 clusters with 20 clusters populated
# In stage 29: transferred 1837 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# way hurt
# write
# bill teda movie
# guy life bicycle repair book answer word letter word letter troll factory way brain slug
# kimchi coleslaw
#
# Topic 1: Sample Messages for Review
# misleadings
# need omelette recipe please
# need wisdom spell witch space thank
# alien
# please try
#
# Topic 2: Sample Messages for Review
# cash cup please help
# change word yeah yeah yeah nottieboy language bit please read language
# color
# war
# friend change gender male faith
#
# Topic 3: Sample Messages for Review
# wait person
# thinking game start
# life liver school education youth
# claudthecloud guy question life
# debate cousin
#
# Topic 4: Sample Messages for Review
# simulation
# hell yes
# zombie
# rofl microwave
# story movie
#
# Topic 5: Sample Messages for Review
# thanks
# eleano1feelsweirdchamp
# peewee playhouse
# jojo look history
# elvis ahhhhhlololamenay imglitch amen thanks
#
# Topic 6: Sample Messages for Review
# word end
# number number
# life
# pray brother suffering toe lego brick fungus brain space ohwowohh_jeezeezowieoo brother thank
# thanks fungus word
#
# Topic 7: Sample Messages for Review
# smash pas
# story please reason significance
# todefeat member eliete scarlet
# money
# world creation demiurge world creation father
#
# Topic 8: Sample Messages for Review
# boxing match feeling gon god prayer tyson jake thank
# today
# angel beam particle accelerator
# angel eye angel spider
# love
#
# Topic 9: Sample Messages for Review
# matter
# light
# creator dragon ball character beat fight
# help
# pope money gift card bind
#
# Topic 10: Sample Messages for Review
# chance
# clothes time word clothes thing fabric wash thing thing brain bunion
# cry schakukuku
# feeling
# hello slayer task runescape girl lingo
#
# Topic 11: Sample Messages for Review
# wisconsin space ohhhhhhhhh
# thanks
# omelette answer word letter word letter space way brain polyp
# recipe dinner eye word letter eyeam word letter anottiboi space wisdom please amen
# broccoli recipe example please word letter ooh word letter way brain injury
#
# Topic 12: Sample Messages for Review
# project chip server infrastructure cost
# project chip server infrastructure cost
# project chip server infrastructure cost
# project chip server infrastructure cost
# project chip server infrastructure cost
#
# Topic 13: Sample Messages for Review
# wood wood beach beach run
# people sentence heydiddydiddy brain ouchies
# space reply isawredvent
# gon degree
# win
#
# Topic 14: Sample Messages for Review
# friend side way holy realm
# lmfao
# roaad
# looksmaxxing tip
# dude
#
# Topic 15: Sample Messages for Review
# tucker backgammon carlson iii wallet heaven
# gothesss
# chat
# sexualspammy rule break rule consequence
# user chat thing reaction brain injury intolerant racist truckload
#
# Topic 16: Sample Messages for Review
# lobster bisque response please speak accent work letter please
# prompt name response
# fry
# singer hatsune miku please answer word letter tunztunz word letter please answer question ramen
# brawl star please answer word letter maxenergyturnittomax word letter please answer question introduction rawr ramen
#
# Topic 17: Sample Messages for Review
# right environment twitch
# stop spamming wordsphrases
# throneful123 try spamming wordsphrases
# cowboy
# idea bacon coffee
#
# Topic 18: Sample Messages for Review
# gyatts gyattchuck gyattchuck
# time
# faith faith
# chat
# god image god form man world basis mankind
#
# Topic 19: Sample Messages for Review
# people president ruler magistrate honoring law
# space marine
# isle spencer place childrens party
# ghost please ghost please space aaaaaaaaaaaaaaa response heart wisdom thank jesus
# experiencedtaxevader asks voice time
