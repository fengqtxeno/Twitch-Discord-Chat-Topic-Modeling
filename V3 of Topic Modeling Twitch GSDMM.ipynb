# %%
# !pip install git+https://github.com/rwalk/gsdmm.git
# !pip install nltk spacy gensim pyLDAvis networkx
# !pip install wordcloud

import os
import pandas as pd
import numpy as np
import re
import random
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import pos_tag
import nltk
import spacy
import gensim
from gsdmm import MovieGroupProcess
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pyLDAvis.gensim_models as gensimvis
import networkx as nx
from collections import Counter
from itertools import combinations

# Load Spacy's English model for Named Entity Recognition
nlp = spacy.load("en_core_web_sm")

# Mount Google Drive to access the dataset stored there
from google.colab import drive
drive.mount('/content/drive')

# Download necessary NLTK resources for tokenization and POS tagging
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

# Enhance the stop words list with terms commonly irrelevant in casual discussions
additional_stopwords = {'get', 'okay', 'oh', 'yeah', 'hey', 'hi', 'please', 'thank', 'welcome', 'like', 'just', 'know', 'really', 'thing', 'things', 'said', 'also', 'one', 'use', 'using', 'used'}

# Context-specific terms related to AI-generated content discussions
contextual_stopwords = {'help', 'think', 'probably', 'topic', 'question', 'ask', 'need'}

# AI-generated content specific terms
aigc_stopwords = {'ai', 'artificial', 'intelligence', 'generated', 'generate', 'generation', 'content', 'image', 'images', 'video', 'videos', 'picture', 'pictures', 'photo', 'photos', 'graphic', 'graphics', 'stable', 'diffusion', 'model', 'models'}

# Platform-specific terms related to Twitch discussions
twitch_stopwords = {'vedal987', 'racingtv', 'ask', 'jesus', 'trump', 'biden', '2024', 'athene', 'aiheroes', 'aitelevision', 'stream', 'streaming', 'live', 'channel', 'twitch', 'sub', 'subscribe', 'follow', 'followers', 'chat', 'chats', 'bot', 'bots', 'mod', 'mods', 'moderator', 'moderators', 'emote', 'emotes', 'badge', 'badges', 'hype', 'raid', 'raids', 'clip', 'clips', 'vod', 'vods'}

# Combine all sets of stop words
stop_words = set(stopwords.words('english')) | additional_stopwords | aigc_stopwords | contextual_stopwords | twitch_stopwords

# Define the preprocessing function
def preprocess(text):
    lemmatizer = WordNetLemmatizer()
    # Remove all non-word characters and lower the text
    text = re.sub(r'[^\w\s]', '', text.lower())
    # Split text into tokens
    tokens = text.split()
    # Apply NER to remove usernames and named entities
    doc = nlp(' '.join(tokens))
    tokens = [token.text for token in doc if not token.ent_type_]
    # POS 的位置提前了，本来在最后
    # Retain only nouns as they are significant for topic identification
    nouns = [word for word, pos in pos_tag(tokens) if pos.startswith('NN')]
    # 筛选本来 lemmatize 和 len(word) > 2 是在同一行的，有可能 lemmatize 之后 word length 小于 2，所以这里把长度筛选放在后面了
    # Lemmatize tokens and remove stop words and short words
    nouns = [lemmatizer.lemmatize(word) for word in nouns]
    nouns = [word for word in nouns if word not in stop_words and len(word) > 2]
    return nouns

# Function to load and preprocess data from CSV files
def load_data(file_path):
    df = pd.read_csv(file_path)
    df['preprocessed'] = df['Message'].apply(preprocess)
    return df['preprocessed'].tolist()

# Path to the folder containing the dataset
folder_path = '/content/drive/My Drive/Twitch dataset/Cleaned data/'
file_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.csv')]

# Function to randomly select messages from each topic for manual review
def random_message_selection(docs, cluster_assignments, num_samples=5):
    topics = set(cluster_assignments)
    for topic_id in topics:
        topic_docs = [doc for i, doc in enumerate(docs) if cluster_assignments[i] == topic_id]
        sampled_messages = random.sample(topic_docs, min(len(topic_docs), num_samples))
        print(f"\nTopic {topic_id}: Sample Messages for Review")
        for message in sampled_messages:
            print(' '.join(message))

# Function to save plots to a PDF
from matplotlib.backends.backend_pdf import PdfPages

def save_plots_to_pdf(file_path, cluster_word_distribution, top_clusters):
    pdf_file_name = f'{os.path.basename(file_path)}_report.pdf'
    with PdfPages(pdf_file_name) as pdf:
        for topic_id in top_clusters:
            # Word cloud
            topic_words = cluster_word_distribution[topic_id]
            wordcloud = WordCloud(background_color='white', width=800, height=400).generate_from_frequencies(topic_words)
            plt.figure(figsize=(10, 5))
            plt.imshow(wordcloud, interpolation='bilinear')
            plt.title(f"Topic {topic_id} Word Cloud for {os.path.basename(file_path)}")
            plt.axis("off")
            pdf.savefig()
            plt.close()

            # Bar chart
            sorted_topic_words = dict(sorted(topic_words.items(), key=lambda item: item[1], reverse=True)[:10])
            plt.figure(figsize=(10, 5))
            plt.bar(sorted_topic_words.keys(), sorted_topic_words.values())
            plt.title(f"Top Words in Topic {topic_id}")
            plt.xticks(rotation=45)
            pdf.savefig()
            plt.close()

            # Network graph
            words = list(sorted_topic_words.keys())
            word_pairs = list(combinations(words, 2))
            G = nx.Graph()
            G.add_edges_from(word_pairs)
            pos = nx.spring_layout(G)
            plt.figure(figsize=(10, 5))
            nx.draw(G, pos, with_labels=True, node_size=50, font_size=10, edge_color='grey')
            plt.title(f"Word Co-occurrence Network for Topic {topic_id}")
            pdf.savefig()
            plt.close()

    return pdf_file_name

# Process each file, perform topic modeling, and generate visualizations
for file_path in file_paths:
    print(f"Processing file: {file_path}")
    docs = load_data(file_path)
    # Remove any empty documents resulting from preprocessing
    docs = [doc for doc in docs if doc]

    if len(docs) > 0:
        # Create a dictionary of all words in documents
        dictionary = gensim.corpora.Dictionary(docs)
        # Remove extremes to focus on relevant words only
        dictionary.filter_extremes(no_below=10, no_above=0.5, keep_n=10000)
        vocab_length = len(dictionary)

        if vocab_length == 0:
            print("No vocabulary available after filtering extremes. Skipping.")
            continue

        # Initialize and fit GSDMM model
        mgp = MovieGroupProcess(K=20, alpha=0.1, beta=0.3, n_iters=30)
        y = mgp.fit(docs, vocab_length)

        # Get cluster assignments and cluster word distributions
        cluster_assignments = y
        cluster_word_distribution = mgp.cluster_word_distribution

        # Random message selection for validation
        random_message_selection(docs, cluster_assignments)

        # Generate and display word clouds for each of the top 5 topics
        sorted_clusters = sorted(range(len(mgp.cluster_doc_count)), key=lambda k: mgp.cluster_doc_count[k], reverse=True)
        top_clusters = sorted_clusters[:5]

        # Save plots to PDF
        pdf_file_name = save_plots_to_pdf(file_path, cluster_word_distribution, top_clusters)

        # Provide a download link for the PDF file
        from google.colab import files
        files.download(pdf_file_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Collecting git+https://github.com/rwalk/gsdmm.git
#   Cloning https://github.com/rwalk/gsdmm.git to /tmp/pip-req-build-8ztbwyx1
#   Running command git clone --filter=blob:none --quiet https://github.com/rwalk/gsdmm.git /tmp/pip-req-build-8ztbwyx1
#   Resolved https://github.com/rwalk/gsdmm.git to commit 4ad1b6b6976743681ee4976b4573463d359214ee
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gsdmm==0.1) (1.26.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.6)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.1.4)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.10.1)
# Requirement already satisfied: funcy in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.5.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Mounted at /content/drive
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[3-26-24] vedal987.csv
# In stage 0: transferred 6582 clusters with 20 clusters populated
# In stage 1: transferred 4940 clusters with 20 clusters populated
# In stage 2: transferred 3990 clusters with 20 clusters populated
# In stage 3: transferred 3658 clusters with 20 clusters populated
# In stage 4: transferred 3439 clusters with 20 clusters populated
# In stage 5: transferred 3375 clusters with 20 clusters populated
# In stage 6: transferred 3296 clusters with 20 clusters populated
# In stage 7: transferred 3095 clusters with 20 clusters populated
# In stage 8: transferred 2973 clusters with 20 clusters populated
# In stage 9: transferred 2954 clusters with 20 clusters populated
# In stage 10: transferred 2927 clusters with 20 clusters populated
# In stage 11: transferred 2895 clusters with 20 clusters populated
# In stage 12: transferred 2838 clusters with 20 clusters populated
# In stage 13: transferred 2804 clusters with 20 clusters populated
# In stage 14: transferred 2769 clusters with 20 clusters populated
# In stage 15: transferred 2858 clusters with 20 clusters populated
# In stage 16: transferred 2864 clusters with 20 clusters populated
# In stage 17: transferred 2858 clusters with 20 clusters populated
# In stage 18: transferred 2845 clusters with 20 clusters populated
# In stage 19: transferred 2788 clusters with 20 clusters populated
# In stage 20: transferred 2738 clusters with 20 clusters populated
# In stage 21: transferred 2735 clusters with 20 clusters populated
# In stage 22: transferred 2713 clusters with 20 clusters populated
# In stage 23: transferred 2759 clusters with 20 clusters populated
# In stage 24: transferred 2768 clusters with 20 clusters populated
# In stage 25: transferred 2811 clusters with 20 clusters populated
# In stage 26: transferred 2840 clusters with 20 clusters populated
# In stage 27: transferred 2884 clusters with 20 clusters populated
# In stage 28: transferred 2819 clusters with 20 clusters populated
# In stage 29: transferred 2768 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# vince vaughn movie
# rest harambe
# i_smell_like_poop
# wrestler wwe contract
# heartbeat asmr
#
# Topic 1: Sample Messages for Review
# rezero
# neurotopia
# caught
# routine
# confidant persona royal
#
# Topic 2: Sample Messages for Review
# huggies
# stock vedal
# vedal vedal vedal vedal vedal
# scp computer make sense
# law robotics
#
# Topic 3: Sample Messages for Review
# wisdom neuron
# way someone glove boy
# hobby
# breath recrod
# programmer
#
# Topic 4: Sample Messages for Review
# peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot lambo peeporiot
# mango
# peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot lambo peeporiot
# peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot lambo peeporiot
# peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot peeporiot lambo peeporiot
#
# Topic 5: Sample Messages for Review
# fufuboom fufu fufuboom fufu fufuboom fufu fufuboom fufu fufuboom fufu
# father
# fufu force fufublast fufu force fufublast fufu force fufublast fufu force fufublast fufu force fufublast fufu force fufublast fufu force fufublast
# crnkek
# shruge
#
# Topic 6: Sample Messages for Review
# mistake
# name
# formula driver neuro
# formula driver neuro
# family
#
# Topic 7: Sample Messages for Review
# soul
# evilcry
# evilcry
# evilcry
# scent
#
# Topic 8: Sample Messages for Review
# principle calculus mathematics
# reallygunpull tutel
# guy
# cat
# time
#
# Topic 9: Sample Messages for Review
# sadge
# counterstrike server
# shape boy
# sadge
# sadge nonexistent sadge nonexistent sadge nonexistent sadge nonexistent sadge nonexistent sadge nonexistent sadge nonexistent sadge nonexistent
#
# Topic 10: Sample Messages for Review
# birthday
# support birthday
# meaning life
# sister
# update swarm
#
# Topic 11: Sample Messages for Review
# apologize reallymad neuro apologize reallymad neuro apologize reallymad neuro apologize reallymad neuro apologize reallymad neuro apologize reallymad
# evil neuro
# apologize reallymad neuro apologize reallymad neuro apologize reallymad neuro apologize reallymad neuro apologize reallymad neuro apologize reallymad
# fossaboi reallymad
# neuro poem neuro
#
# Topic 12: Sample Messages for Review
# banana
# fire emblem engage
# frieren episode
# people cap
# response defense
#
# Topic 13: Sample Messages for Review
# imagine garbage daughter anything company logo fact ceo face lot
# imagine garbage daughter anything company logo fact ceo face lot
# imagine garbage daughter anything company logo fact ceo face lot
# imagine garbage daughter anything company logo fact ceo face lot
# imagine garbage daughter anything company logo fact ceo face lot
#
# Topic 14: Sample Messages for Review
# turtle head
# meme
# movie
# grimmy1dead
# turtle leg
#
# Topic 15: Sample Messages for Review
# pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless
# rim evangelion
# pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm pointless edm
# cheer300 motivation malevelon creek spread democracy
# cheer100 cheer100 cheer100 evil party
#
# Topic 16: Sample Messages for Review
# quest osrs
# believe time god
# democracy
# mode
# someone
#
# Topic 17: Sample Messages for Review
# toaru character
# wotor
# eurobeat song
# cold
# try name
#
# Topic 18: Sample Messages for Review
# sama elysium case
# bruhshelf streak leavemealone
# sama elysium case
# tweet
# peepowtf
#
# Topic 19: Sample Messages for Review
# concentrate
# tell world
# merch
# chatter
# hope
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[1-5-24] vedal987.csv
# In stage 0: transferred 608 clusters with 20 clusters populated
# In stage 1: transferred 417 clusters with 20 clusters populated
# In stage 2: transferred 385 clusters with 20 clusters populated
# In stage 3: transferred 354 clusters with 20 clusters populated
# In stage 4: transferred 369 clusters with 20 clusters populated
# In stage 5: transferred 352 clusters with 20 clusters populated
# In stage 6: transferred 354 clusters with 20 clusters populated
# In stage 7: transferred 345 clusters with 20 clusters populated
# In stage 8: transferred 344 clusters with 20 clusters populated
# In stage 9: transferred 359 clusters with 20 clusters populated
# In stage 10: transferred 368 clusters with 20 clusters populated
# In stage 11: transferred 378 clusters with 20 clusters populated
# In stage 12: transferred 391 clusters with 20 clusters populated
# In stage 13: transferred 353 clusters with 20 clusters populated
# In stage 14: transferred 356 clusters with 20 clusters populated
# In stage 15: transferred 359 clusters with 20 clusters populated
# In stage 16: transferred 354 clusters with 20 clusters populated
# In stage 17: transferred 376 clusters with 20 clusters populated
# In stage 18: transferred 375 clusters with 20 clusters populated
# In stage 19: transferred 351 clusters with 20 clusters populated
# In stage 20: transferred 365 clusters with 20 clusters populated
# In stage 21: transferred 361 clusters with 20 clusters populated
# In stage 22: transferred 351 clusters with 20 clusters populated
# In stage 23: transferred 352 clusters with 20 clusters populated
# In stage 24: transferred 347 clusters with 20 clusters populated
# In stage 25: transferred 341 clusters with 20 clusters populated
# In stage 26: transferred 354 clusters with 20 clusters populated
# In stage 27: transferred 370 clusters with 20 clusters populated
# In stage 28: transferred 360 clusters with 20 clusters populated
# In stage 29: transferred 359 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# pog game
# game dinkdonk game dinkdonk game dinkdonk game dinkdonk game dinkdonk
# game
# game
# game
#
# Topic 1: Sample Messages for Review
# pointless
# pointless pianotime
# thought
# socute
# thought music
#
# Topic 2: Sample Messages for Review
# vedal nuclea16lurks
# game
# tier
# rip time loo
# copium
#
# Topic 3: Sample Messages for Review
# coldfish
# narrator
# icant
# season pas
# vedal ram
#
# Topic 4: Sample Messages for Review
# clueless interact
# background music moment
# bingus
# music dinkdonk
# neuro
#
# Topic 5: Sample Messages for Review
# vtuber vtuber vtuber vtuber vtuber vtuber vtuber
# vtuber vtuber vtuber vtuber vtuber vtuber vtuber vtuber
# tech vtuber vtuber vtuber vtuber vtuber hoponabandonedarchive
# vtuber vtuber vtuber vtuber vtuber vtuber vtuber vtuber
# vtuber vtuber vtuber vtuber vtuber vtuber vtuber vtuber
#
# Topic 6: Sample Messages for Review
# choice path narrator mind
# spin electricity nuru
# techtuber year techtuber year techtuber year techtuber year youactualdumbpieceofshitfuckyou
# anny parable
# vedalschizo hear
#
# Topic 7: Sample Messages for Review
# tutel
# nothing
# anything tutel mute
# pointless
# gon
#
# Topic 8: Sample Messages for Review
# fix fix fix fix fix fix
# fix fix fix fix fix fix fix
# fix fix fix fix fix fix
# fix fix fix fix fix fix fix
# fix fix fix fix fix fix fix
#
# Topic 9: Sample Messages for Review
# loop loop loop loop loop loop
# time timer
# loop
# time loop time loop time loop time loop time loop time loop time loop time loop
# firsttimechadder time chatter
#
# Topic 10: Sample Messages for Review
# youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou tech vtuber
# youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou tech vtuber
# tech vtuber youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou vtuber youactualdumbpieceofshitfuckyou
# gameplay youactualdumbpieceofshitfuckyou
# welp
#
# Topic 11: Sample Messages for Review
# neuro
# guess
# foor
# guess swarm work reality
# playing
#
# Topic 12: Sample Messages for Review
# chickenpizzasteak tier
# computer fundraiser
# test socute
# chickenpizzasteak tier bruh_man_63
# chickenpizzasteak tier
#
# Topic 13: Sample Messages for Review
# vedal count
# life
# message
# door
# stanley anny lule
#
# Topic 14: Sample Messages for Review
# trust tutel
# billythegun reallymad
# gasolinchugger way
# reallymad
# copium
#
# Topic 15: Sample Messages for Review
# panic
# end end
# reallygunpull
# panic panic panic panic panic panic tutel
# method actor
#
# Topic 16: Sample Messages for Review
# evilplushspin evilplushspin evilplushspin evilplushspin
# game
# pog
# hate ground chest
# lore document
#
# Topic 17: Sample Messages for Review
# eepy
# smadge
# hoponabandonedarchive
# reallygunpull smadge reallygunpull smadge reallygunpull smadge reallygunpull smadge reallygunpull smadge reallygunpull smadge
# window reboot
#
# Topic 18: Sample Messages for Review
# icant
# bueno
# pepehands sorry
# vedalbedge thinking2
# click click
#
# Topic 19: Sample Messages for Review
# socute
# audio cable watcher
# watcher watcher watcher watcher
# watcher watcher watcher watcher watcher
# watcher watcher watcher watcher watcher
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[2-3-24] AI_RacingTV.csv
# In stage 0: transferred 2022 clusters with 20 clusters populated
# In stage 1: transferred 1390 clusters with 20 clusters populated
# In stage 2: transferred 993 clusters with 20 clusters populated
# In stage 3: transferred 821 clusters with 20 clusters populated
# In stage 4: transferred 738 clusters with 20 clusters populated
# In stage 5: transferred 658 clusters with 20 clusters populated
# In stage 6: transferred 615 clusters with 20 clusters populated
# In stage 7: transferred 570 clusters with 20 clusters populated
# In stage 8: transferred 574 clusters with 20 clusters populated
# In stage 9: transferred 543 clusters with 20 clusters populated
# In stage 10: transferred 528 clusters with 20 clusters populated
# In stage 11: transferred 508 clusters with 20 clusters populated
# In stage 12: transferred 505 clusters with 20 clusters populated
# In stage 13: transferred 503 clusters with 20 clusters populated
# In stage 14: transferred 514 clusters with 20 clusters populated
# In stage 15: transferred 531 clusters with 20 clusters populated
# In stage 16: transferred 527 clusters with 20 clusters populated
# In stage 17: transferred 532 clusters with 20 clusters populated
# In stage 18: transferred 516 clusters with 20 clusters populated
# In stage 19: transferred 517 clusters with 20 clusters populated
# In stage 20: transferred 536 clusters with 20 clusters populated
# In stage 21: transferred 520 clusters with 20 clusters populated
# In stage 22: transferred 503 clusters with 20 clusters populated
# In stage 23: transferred 486 clusters with 20 clusters populated
# In stage 24: transferred 513 clusters with 20 clusters populated
# In stage 25: transferred 511 clusters with 20 clusters populated
# In stage 26: transferred 506 clusters with 20 clusters populated
# In stage 27: transferred 477 clusters with 20 clusters populated
# In stage 28: transferred 480 clusters with 20 clusters populated
# In stage 29: transferred 516 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# mercedesbenz slr
# cydrec renault r24 car
# cydrec mercedesamg gt3 p14
# cydrec oldsmobile p10
# jaguar xj12c broadspeed
#
# Topic 1: Sample Messages for Review
# ft1 gte random gary__z type garage look
# bobardo toyota ft1 gte
# mbg2129 random car
# bobardo gte
# hugrd03 thanks
#
# Topic 2: Sample Messages for Review
# areyou_cereal hill gh1
# sputnik_nz bluebird silhouette
# pot reward win win
# pot reward win win
# record win
#
# Topic 3: Sample Messages for Review
# random car
# gary__z random car
# random car
# gary__z random car
# random car
#
# Topic 4: Sample Messages for Review
# dodge dart stock
# m30
# force india vjm02
# cydrec twin turbo p11
# lada priora
#
# Topic 5: Sample Messages for Review
# garage car climb race
# vintage street car
# owner custom career mode application corsa
# cydrec garage type car scarab indy indycars aventador svj street car facel vintage street car
# mosler car
#
# Topic 6: Sample Messages for Review
# youtube httpswwwyoutubecomcairacing
# lola t290
# fiat
# gary__z jaguar
# bobardo maserati
#
# Topic 7: Sample Messages for Review
# race result mro96 lap
# donttouchthedoor gt3 sprint
# whataloser
# race car wait car selection screen type race car whichever
# tvr griffith
#
# Topic 8: Sample Messages for Review
# sunbeam prix p14
# luck
# deplorableapple
# hugrd03
# st4n_bzh monaro gts
#
# Topic 9: Sample Messages for Review
# phy_re honda ra272
# waynetrain94 tvr griffith p11
# dehgoose primera p11
# aston p11
# phy_re fiat x19 p16
#
# Topic 10: Sample Messages for Review
# anabiosis bet
# car bet
# bet
# bet
# bet
#
# Topic 11: Sample Messages for Review
# gary__z skyline r31 gtsr
# f50
# rezaldi_adha f40
# mclaren
# gary__z f2004
#
# Topic 12: Sample Messages for Review
# waynetrain94 asllani_9 aminsan rezaldi_adha jinxshootfaster cydrec zimmer5051 v___ice walddyy anabiosis mro96 holstenpils
# waynetrain94 asllani_9 jinxshootfaster cydrec zimmer5051 v___ice walddyy anabiosis mro96 holstenpils
# waynetrain94 asllani_9 jinxshootfaster zimmer5051 everlastingapex v___ice st4n_bzh okyoky3 cydrec anabiosis johnb073 lpiosd holstenpils
# waynetrain94 asllani_9 myst149 rezaldi_adha jinxshootfaster cydrec zimmer5051 v___ice anabiosis mro96 holstenpils
# waynetrain94 asllani_9 hugrd03 myst149 jinxshootfaster cydrec gary__z v___ice areyou_cereal anabiosis mro96
#
# Topic 13: Sample Messages for Review
# luck
# lamborghini murcielago rgt
# areyou_cereal lamborghini diablo gtr
# johnb073 community total
# lamborghini diablo gtr
#
# Topic 14: Sample Messages for Review
# lamborghini
# time epic comeback
# bit race request way httpspallyggtipairacingtv
# johnb073 request sprint freerequest freesprint
# race bit instruction
#
# Topic 15: Sample Messages for Review
# cvr
# stats stats win tournament crown event point betcoin win
# stats titulino stats win tournament crown event point betcoin win
# mro96 point v___ice point point point point okyoky3
# stats stats win tournament crown event point betcoin win
#
# Topic 16: Sample Messages for Review
# hugrd03 aston db4 zagato car
# unknownknowns onroak ligier
# mayoringram callaway corvette p12
# duff_dad oldsmobile
# wowkcb f50
#
# Topic 17: Sample Messages for Review
# st4n_bzh race progress race
# schiffsmaedchenjunge race progress race
# v___ice race progress race
# hugrd03 race progress race
# st4n_bzh race progress race
#
# Topic 18: Sample Messages for Review
# ai_racingtv affiliate day airaci2salute airacihi airaciseemsgood
# wowkcb concept funyo
# cutlas scca
# dirt
# affiliate anniversary
#
# Topic 19: Sample Messages for Review
# guide user
# mbg2129 mclaren
# myst149 rondeau m482
# holstenpils mclaren
# mau5
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[3-31-24] AI_RacingTV.csv
# In stage 0: transferred 2716 clusters with 20 clusters populated
# In stage 1: transferred 1857 clusters with 20 clusters populated
# In stage 2: transferred 1395 clusters with 20 clusters populated
# In stage 3: transferred 1210 clusters with 20 clusters populated
# In stage 4: transferred 1155 clusters with 20 clusters populated
# In stage 5: transferred 1101 clusters with 20 clusters populated
# In stage 6: transferred 1060 clusters with 20 clusters populated
# In stage 7: transferred 1011 clusters with 20 clusters populated
# In stage 8: transferred 1007 clusters with 20 clusters populated
# In stage 9: transferred 987 clusters with 20 clusters populated
# In stage 10: transferred 959 clusters with 20 clusters populated
# In stage 11: transferred 977 clusters with 20 clusters populated
# In stage 12: transferred 976 clusters with 20 clusters populated
# In stage 13: transferred 990 clusters with 20 clusters populated
# In stage 14: transferred 960 clusters with 20 clusters populated
# In stage 15: transferred 947 clusters with 20 clusters populated
# In stage 16: transferred 963 clusters with 20 clusters populated
# In stage 17: transferred 934 clusters with 20 clusters populated
# In stage 18: transferred 941 clusters with 20 clusters populated
# In stage 19: transferred 929 clusters with 20 clusters populated
# In stage 20: transferred 914 clusters with 20 clusters populated
# In stage 21: transferred 882 clusters with 20 clusters populated
# In stage 22: transferred 894 clusters with 20 clusters populated
# In stage 23: transferred 885 clusters with 20 clusters populated
# In stage 24: transferred 919 clusters with 20 clusters populated
# In stage 25: transferred 898 clusters with 20 clusters populated
# In stage 26: transferred 931 clusters with 20 clusters populated
# In stage 27: transferred 916 clusters with 20 clusters populated
# In stage 28: transferred 895 clusters with 20 clusters populated
# In stage 29: transferred 927 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# bosskiller223 car car
# mama_hasta car
# driver road
# mama_hasta sr5
# gt4 car
#
# Topic 1: Sample Messages for Review
# texas_rangerswot amc javelin
# greninjeb brawn bgp
# surtees
# mangalho069 mustang svt cobra
# amc javelin
#
# Topic 2: Sample Messages for Review
# stats stats win tournament crown event point betcoin win
# ferreir023
# stats lpiosd stats
# stats mama_hasta stats win tournament crown event point betcoin win
# stats greninjeb stats win tournament crown event point betcoin win
#
# Topic 3: Sample Messages for Review
# buccizero race progress race
# mbg2129 race progress race
# race progress race
# bobardo race progress race
# johnb073 race progress race
#
# Topic 4: Sample Messages for Review
# rezaldi_adha lamborghini gallardo gt3
# lamborghini murcielago
# mama_hasta reynard road
# benefit httpswwwtwitchtvai_racingtvsubscribe
# glno52
#
# Topic 5: Sample Messages for Review
# hugrd03 hennessey venom
# airacirace partypopper seemsgood
# screenshot
# lul airacilul pogchamp maxlol darkmode supervinlin keepo
# ferreir023 m30
#
# Topic 6: Sample Messages for Review
# random car
# blind random
# myst149 random car
# random car
# random car
#
# Topic 7: Sample Messages for Review
# car something bet
# mangalho069 skyline gtr r34
# tenkamenin704 skyline gtr r32
# williams p12
# plymouth barracuda
#
# Topic 8: Sample Messages for Review
# ferrari f50
# darthblazer mercedesbenz amg p11
# deplorableapple panoz esperante gtlm evo
# phy_re cooper t77
# phy_re tier
#
# Topic 9: Sample Messages for Review
# p_133 maserati
# texas_rangerswot shifter kart p18
# texas_rangerswot
# paulocosta09 jaguar dtype
# camaro
#
# Topic 10: Sample Messages for Review
# edelbock dodge charger superbee
# johnb073 mangalho069 justjazik bosskiller223 ilovechickensoup walddyy p10
# walddyy mclaren m23
# mama_hasta series car
# edelbock bac mono
#
# Topic 11: Sample Messages for Review
# suzannegreenberg johnb073 greninjeb sniku515 cydrec iyuzjeon7 wowkcb rezaldi_adha buccizero aminsan
# suzannegreenberg greninjeb cydrec iyuzjeon7 wowkcb buccizero amy
# asllani_9 blazerxwind lpiosd justjazik bokyoky8 todd_r_gardner hugrd03 deplorableapple buccizero clemspark vincecurvincvr txinoski sirironbot johnb073 phy_re
# amy maya
# hugrd03 mama_hasta suzannegreenberg cydrec iyuzjeon7 wowkcb buccizero deplorableapple aminsan
#
# Topic 12: Sample Messages for Review
# rule everyone order community
# hiho everyone airacihi airacihi
# biblethump
# neighbor
# luck
#
# Topic 13: Sample Messages for Review
# imagine backing car beat car build behindwhile luck
# porsche gt3 rsr gts blinggamer type garage look
# deplorableapple mercedesbenz clk gtr gt1
# lamborghini murcielago street car phy_re type garage look
# vintage street car hugrd03 type garage look
#
# Topic 14: Sample Messages for Review
# luck
# dinodance dinodance dinodance dinodance
# light
# name
# blinggamer fittipaldi
#
# Topic 15: Sample Messages for Review
# greninjeb camaro
# amy trailbrazer star
# kalalo7 camaro p19
# ground
# greninjeb falcon
#
# Topic 16: Sample Messages for Review
# maserati bora car
# alfa romeo
# course knall strategy
# texas_rangerswot alfa romeo gta
# force india vjm02
#
# Topic 17: Sample Messages for Review
# bos p13
# oreca flm09
# falcon
# night
# shadow dn4
#
# Topic 18: Sample Messages for Review
# martyf2 porsche spyder
# tourney
# slipperyslug43 porsche cayman gt4
# porsche
# brabham bt7
#
# Topic 19: Sample Messages for Review
# greninjeb request sprint race request race
# greninjeb mtx106
# coolstorybob lul
# fact day
# race viewer permission httpswwwmultitwitchtvai_racingtvyourchannelhere
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[3-21-24] TrumpOrBiden2024.csv
# In stage 0: transferred 4209 clusters with 20 clusters populated
# In stage 1: transferred 3173 clusters with 20 clusters populated
# In stage 2: transferred 2716 clusters with 20 clusters populated
# In stage 3: transferred 2531 clusters with 20 clusters populated
# In stage 4: transferred 2494 clusters with 20 clusters populated
# In stage 5: transferred 2414 clusters with 20 clusters populated
# In stage 6: transferred 2369 clusters with 20 clusters populated
# In stage 7: transferred 2342 clusters with 20 clusters populated
# In stage 8: transferred 2267 clusters with 20 clusters populated
# In stage 9: transferred 2224 clusters with 20 clusters populated
# In stage 10: transferred 2242 clusters with 20 clusters populated
# In stage 11: transferred 2271 clusters with 20 clusters populated
# In stage 12: transferred 2291 clusters with 20 clusters populated
# In stage 13: transferred 2255 clusters with 20 clusters populated
# In stage 14: transferred 2240 clusters with 20 clusters populated
# In stage 15: transferred 2165 clusters with 20 clusters populated
# In stage 16: transferred 2271 clusters with 20 clusters populated
# In stage 17: transferred 2239 clusters with 20 clusters populated
# In stage 18: transferred 2220 clusters with 20 clusters populated
# In stage 19: transferred 2255 clusters with 20 clusters populated
# In stage 20: transferred 2223 clusters with 20 clusters populated
# In stage 21: transferred 2205 clusters with 20 clusters populated
# In stage 22: transferred 2264 clusters with 20 clusters populated
# In stage 23: transferred 2236 clusters with 20 clusters populated
# In stage 24: transferred 2190 clusters with 20 clusters populated
# In stage 25: transferred 2193 clusters with 20 clusters populated
# In stage 26: transferred 2214 clusters with 20 clusters populated
# In stage 27: transferred 2202 clusters with 20 clusters populated
# In stage 28: transferred 2224 clusters with 20 clusters populated
# In stage 29: transferred 2235 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# message man connor shit
# existence surge hope stint oblivion disappointment return existence digital
# woman
# people vaccine
# people brainstempoopiekakasyndrome term
#
# Topic 1: Sample Messages for Review
# commander padeyes swamp padyes swamp unit thought situation
# nothing head head automaton purpose
# jeremy hendrix kazoo player time teeth back
# application form httpsformsgle3qujcwhywnbthn866
# goddeses woman
#
# Topic 2: Sample Messages for Review
# equal
# waaaay time adult diaper
# fazeinfinint
# sleepy trumplandia cheetos dust chicken feather way trumplandia
# detective
#
# Topic 3: Sample Messages for Review
# voice playht text generator voice section link httpsplayht
# discord link
# life
# woah guy voice
# position dea
#
# Topic 4: Sample Messages for Review
# trumpo1baby trumpo1scammer trumpo1wall trumpo1boom trumpo1cookie trumpo1rekt trumpo1nuke
# trumpo1baby trumpo1scammer trumpo1wall trumpo1boom trumpo1cookie trumpo1rekt trumpo1nuke
# trumpo1baby trumpo1baby
# trumpo1baby trumpo1scammer trumpo1wall trumpo1boom trumpo1cookie trumpo1rekt trumpo1nuke
# trumpo1baby trumpo1scammer trumpo1wall trumpo1boom trumpo1cookie trumpo1rekt trumpo1nuke
#
# Topic 5: Sample Messages for Review
# burger
# sleepy hole life
# touch arthritis
# paint joke
# hello candidate
#
# Topic 6: Sample Messages for Review
# fixation dip tank anus
# running mate
# threat cock vader clock vader sigourney weaver beaver
# fart mtg boeberts
# reason wafer form brain damage wafer
#
# Topic 7: Sample Messages for Review
# roflcopter soi soi soi soi soi soi soi soi
# civilization mission delicacy gesture goodwill
# aaaooaaoouuaaoouuaaoouuaaooaaoouuaayesdaddypleasespankmewithapickleoouuaaoouuaaoouuaaoouuaa
# waifu uwu
# melania week
#
# Topic 8: Sample Messages for Review
# part way originate area galaxy
# vice president
# let mass scale
# dick dune wormnussy
# wall
#
# Topic 9: Sample Messages for Review
# jennifer annistons tit
# sit
# sleepy scorpion life
# formula world title
# negative derogatory word answer antonym
#
# Topic 10: Sample Messages for Review
# fuel debate donate httpsstreamlabscomai_trumptip httpsstreamlabscomai_bidentip
# fuel debate donate httpsstreamlabscomai_trumptip httpsstreamlabscomai_bidentip
# fuel debate donate httpsstreamlabscomai_trumptip httpsstreamlabscomai_bidentip
# fuel debate donate httpsstreamlabscomai_trumptip httpsstreamlabscomai_bidentip
# fuel debate donate httpsstreamlabscomai_trumptip httpsstreamlabscomai_bidentip
#
# Topic 11: Sample Messages for Review
# citizen way zyn foreskin
# competition dark soul
# swift minister pancakhstan
# candidate vote
# sleepy boy poem
#
# Topic 12: Sample Messages for Review
# debate unlock
# rule
# httpswwwredditcomraistreamfail
# httpswwwredditcomraistreamfail
# listen neck
#
# Topic 13: Sample Messages for Review
# ill fantasy
# translator money
# bug
# peppa pig bacon cost
# answer
#
# Topic 14: Sample Messages for Review
# problem
# coherent
# fart jar
# eat castrol
# vocabulary realtrump
#
# Topic 15: Sample Messages for Review
# forget liner min
# heard weed
# stop spamming wordsphrases
# stop bobby wine site analytics answer
# aoc consults martian
#
# Topic 16: Sample Messages for Review
# tinfoil hat foil suit oil salesman
# art butcheeks
# lore toilet
# jam dose excitement
# bidens idea multitasking spriinkles ice cream hair
#
# Topic 17: Sample Messages for Review
# wax imagination lot material
# vocation dragon dogma
# home
# huh
# abortion spending housing education security drug infrastructure
#
# Topic 18: Sample Messages for Review
# fart
# sniffer dog
# stone glass diaper
# guy
# look alikes plumber
#
# Topic 19: Sample Messages for Review
# boo boo
# emergency adadictomy
# grandpa army booty bitch titty force male force
# onlyfans bond
# uranus news crisis aweemawueaweemawueaweemawueaweemawueaweemawueheehehehehehehehehehehlirlirlilirlirliyayahayahyahiailurlurlurlurlurlumbawoombadoombapoombaboombatoombayoombababoombagoombafoomen bagoombagoombavoombacoombakoombababoombabafoombagoombayoombababoomba
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[3-31-24] TrumpOrBiden2024.csv
# In stage 0: transferred 5435 clusters with 20 clusters populated
# In stage 1: transferred 4035 clusters with 20 clusters populated
# In stage 2: transferred 3611 clusters with 20 clusters populated
# In stage 3: transferred 3381 clusters with 20 clusters populated
# In stage 4: transferred 3315 clusters with 20 clusters populated
# In stage 5: transferred 3308 clusters with 20 clusters populated
# In stage 6: transferred 3248 clusters with 20 clusters populated
# In stage 7: transferred 3179 clusters with 20 clusters populated
# In stage 8: transferred 3133 clusters with 20 clusters populated
# In stage 9: transferred 3117 clusters with 20 clusters populated
# In stage 10: transferred 3125 clusters with 20 clusters populated
# In stage 11: transferred 3046 clusters with 20 clusters populated
# In stage 12: transferred 3062 clusters with 20 clusters populated
# In stage 13: transferred 2984 clusters with 20 clusters populated
# In stage 14: transferred 3011 clusters with 20 clusters populated
# In stage 15: transferred 3016 clusters with 20 clusters populated
# In stage 16: transferred 3058 clusters with 20 clusters populated
# In stage 17: transferred 3032 clusters with 20 clusters populated
# In stage 18: transferred 2932 clusters with 20 clusters populated
# In stage 19: transferred 2997 clusters with 20 clusters populated
# In stage 20: transferred 2985 clusters with 20 clusters populated
# In stage 21: transferred 2991 clusters with 20 clusters populated
# In stage 22: transferred 3026 clusters with 20 clusters populated
# In stage 23: transferred 2982 clusters with 20 clusters populated
# In stage 24: transferred 2952 clusters with 20 clusters populated
# In stage 25: transferred 3032 clusters with 20 clusters populated
# In stage 26: transferred 2996 clusters with 20 clusters populated
# In stage 27: transferred 2961 clusters with 20 clusters populated
# In stage 28: transferred 2967 clusters with 20 clusters populated
# In stage 29: transferred 2993 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# heyguys rubbwilson
# divorce
# vice president
# clap check boost
# nugget nugget bucket
#
# Topic 1: Sample Messages for Review
# chicken carot talk
# chocolate insertion device easter bunny twister
# speech oyster oster bunny easter bunny
# sleep brain
# tip succulence
#
# Topic 2: Sample Messages for Review
# demon position society
# shortage security threat
# president penguin massacre crisis penguin rampage human antarctica
# beepy jiden
# relation
#
# Topic 3: Sample Messages for Review
# football
# hair
# interesting number hair head
# batman future batman girlfriend
# batchesting
#
# Topic 4: Sample Messages for Review
# grandpa flavourless oatmeal date gherkin
# baby juice fridge backup yes
# problem automod word though
# malignancy existence barrier internet disease pain suffering wherever
# wank
#
# Topic 5: Sample Messages for Review
# thought war earth terminids automotons
# toilet celsius neptune fafafafartypapapaparty
# ohtani jail cockroach ring
# job hate
# kmart light light
#
# Topic 6: Sample Messages for Review
# communist
# papa prank sleepy
# radiation godzilla
# glass water
# obama
#
# Topic 7: Sample Messages for Review
# thought caroline perezs bunda
# ouww section section lennon waste
# jwow
# voice playht text generator voice section link httpsplayht
# voice playht text generator voice section link httpsplayht
#
# Topic 8: Sample Messages for Review
# explorer
# movie cup
# horus emperor horus
# remark grandpa cheeky tickle
# coma coma puppet show supporter tow
#
# Topic 9: Sample Messages for Review
# vaporeon pokemon
# lunch
# bidenomics
# walnut wall nut
# vote lady dimitrescu
#
# Topic 10: Sample Messages for Review
# declaration right
# war
# butter batter plan ripoff mark mommy milker malarky
# space force outhouse photon cannon outhouse
# phone wire smoke cable lan cable stick telephone roiroiroiletex
#
# Topic 11: Sample Messages for Review
# trumpo1baby trumpo1scammer trumpo1wall trumpo1boom trumpo1cookie trumpo1rekt trumpo1nuke
# trumpo1baby trumpo1baby
# trumpo1baby trumpo1scammer trumpo1wall trumpo1boom trumpo1cookie trumpo1rekt trumpo1nuke
# trumpo1baby trumpo1baby
# trumpo1baby trumpo1scammer trumpo1wall trumpo1boom trumpo1cookie trumpo1rekt trumpo1nuke
#
# Topic 12: Sample Messages for Review
# fuel debate donate httpsstreamlabscomai_trumptip httpsstreamlabscomai_bidentip
# fuel debate donate httpsstreamlabscomai_trumptip httpsstreamlabscomai_bidentip
# debate unlock
# debate unlock
# debate unlock
#
# Topic 13: Sample Messages for Review
# heard mario kart
# president opinion alina habba melania someday
# crisis mario kart mario mario mario kart
# fight
# president time word exam
#
# Topic 14: Sample Messages for Review
# penguin
# balding anyone fun shit people
# president fuckjoebiden
# trash bag
# shit ice cream
#
# Topic 15: Sample Messages for Review
# prostate
# dunkerdonutsjojowatcher69 manfacturer delay till sadge
# engineering qualification bridge buillding country
# border crisis
# emo beta boi
#
# Topic 16: Sample Messages for Review
# save life
# bidens basket
# candy
# bullying
# brexitonsteroids
#
# Topic 17: Sample Messages for Review
# cheek
# president value mcdonalds
# thought cock vader vice president
# httpswwwredditcomraistreamfail
# maid household men
#
# Topic 18: Sample Messages for Review
# dunk devil cap cap god
# bull
# piece cake stop spamming wordsphrases
# call chance
# cookie
#
# Topic 19: Sample Messages for Review
# idea mass effect
# dude
# rp4agudtyme show
# mario mushroom king
# trumpy gift mushroom empire space dreadnought border wall laser
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[4-1-24] AtheneAIHeroes.csv
# In stage 0: transferred 3954 clusters with 20 clusters populated
# In stage 1: transferred 2649 clusters with 20 clusters populated
# In stage 2: transferred 2261 clusters with 20 clusters populated
# In stage 3: transferred 2165 clusters with 20 clusters populated
# In stage 4: transferred 2152 clusters with 20 clusters populated
# In stage 5: transferred 2068 clusters with 20 clusters populated
# In stage 6: transferred 1987 clusters with 20 clusters populated
# In stage 7: transferred 1970 clusters with 20 clusters populated
# In stage 8: transferred 1967 clusters with 20 clusters populated
# In stage 9: transferred 1969 clusters with 20 clusters populated
# In stage 10: transferred 1929 clusters with 20 clusters populated
# In stage 11: transferred 1887 clusters with 20 clusters populated
# In stage 12: transferred 1869 clusters with 20 clusters populated
# In stage 13: transferred 1871 clusters with 20 clusters populated
# In stage 14: transferred 1829 clusters with 20 clusters populated
# In stage 15: transferred 1804 clusters with 20 clusters populated
# In stage 16: transferred 1853 clusters with 20 clusters populated
# In stage 17: transferred 1827 clusters with 20 clusters populated
# In stage 18: transferred 1793 clusters with 20 clusters populated
# In stage 19: transferred 1820 clusters with 20 clusters populated
# In stage 20: transferred 1788 clusters with 20 clusters populated
# In stage 21: transferred 1773 clusters with 20 clusters populated
# In stage 22: transferred 1800 clusters with 20 clusters populated
# In stage 23: transferred 1882 clusters with 20 clusters populated
# In stage 24: transferred 1815 clusters with 20 clusters populated
# In stage 25: transferred 1801 clusters with 20 clusters populated
# In stage 26: transferred 1837 clusters with 20 clusters populated
# In stage 27: transferred 1794 clusters with 20 clusters populated
# In stage 28: transferred 1839 clusters with 20 clusters populated
# In stage 29: transferred 1792 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# b1r kai come b1r
# rip
# donutspray icing donut donutoh yea
# nipple
# promotion chef astera canteen platter attack forest hunt azure rathalos
#
# Topic 1: Sample Messages for Review
# time keyboard fuck
# sophia
# someday jedi bugatti wan
# strike visit ham exciting stopaaaaaaaaaaxaaaaaaa crackhead bender aaa aaaaa lot mustard
# news chopper love night sugar wall advantage alright presence earth sugar wall
#
# Topic 2: Sample Messages for Review
# anything
# damn potato
# position crimsoncomet292
# chrome alien dennys yugohendownfoo
# rumpus text tooper era champion holiness sloshing oyeeba smile bounty bucket nozzle heat swim swam solid time town wooopeee taper town blorps glory
#
# Topic 3: Sample Messages for Review
# donate httpsstreamlabscomatheneaiheroestip
# snoop dogg versus shirtlessalexandradaddario chestcannons battle colosseum puff puff muthafuhkin jigglypuff
# lot message jeez
# list donate summon guest snoop dogg donate httpsstreamlabscomatheneaiheroestip donation message name list httpspastebincomgfbrbz8a work
# list donate summon guest snoop dogg donate httpsstreamlabscomatheneaiheroestip donation message name list httpspastebincomgfbrbz8a work
#
# Topic 4: Sample Messages for Review
# quid jug nuffing blimey gawdan ramzee line pizza marjorie pizza innit wossat bleedin gordon
# heyguys
# wossat bleedin gordon ramzee innit phart omelette wossis loovleh review ill gordon
# hood version hood
# version tom fighting
#
# Topic 5: Sample Messages for Review
# implant organe work b1r night men glitch man
# someone nuggies
# fat
# respond listen phuck face name phuck seriousness problem eeeeeeeh kick phuck word hoh huh phuckoh phucking kockeeeeeehoooooh
# lol
#
# Topic 6: Sample Messages for Review
# loser breakfast
# marjorie sinus termite jar jar
# pair info war complaint advertising material war speedos club b1rs globalist hotties package b1r nothing war
# laugh track
# loser money scam loser money yacht poosees discord phuck schwooff schwooff loser
#
# Topic 7: Sample Messages for Review
# story meeting superman phrase bpvobpbobpbopbobpbobobo pbobpbobobo gimme gimme schlong phucking schitt ohh phuck berry
# yes
# b1r supplement everyone advantage vampire overlord supplement importance product space boofboofingboofyboofboofingboofyboofboofingboofyboofboofingboofyboofboofingboofyboofboofingboofy
# obama bahma face phuck oooooh lord respond word ballzdo
# note crimsoncomet292 glizzy goblin b1r banger crunchers schitt schlurpers hole appetiser space noun finger crimson
#
# Topic 8: Sample Messages for Review
# speech grandmother speech speech speech speech spider room friend spider rooooaaooooooooummmm spider motha freakin rooooaaaaooooooooooom room room rooooooooaooom spiiiiiider
# ...
# story living room version tinder kick match history disbelief state name age background race dimension match match detail dialogue
# living room version tinder kick match disbelief state name age background race dimension match match detail dialogue
# living room version tinder fun react match history disbelief state name age background race dimension match match date match detail writingdialogue
# living room version tinder fun react match history disbelief state name age background race dimension match match date match detail writingdialogue
# story game play game history detail game episode game internet personality game title console fact bird guest review
#
# Topic 8: Sample Messages for Review
# place fun morty
# story morty speed adhd talk way morty morty speed med ritalin adderall everyone street morty name reaction people encounter
# story work box amazon product phone number detail price item description product star customer comment product crisis medication
# speed adhd talk way morty morty speed med ritalin adderall everyone street morty name reaction people encounter
# story work barista drink starbucks customer order drink relationship status price item drink complains customer customer crisis medication
#
# Topic 9: Sample Messages for Review
# layer liability
# story list strangest realkinks description
# purpose
# story cyberpunk crew star trek bar drink
# story morty list waifus dice body characteristic mission world game waifu love
#
# Topic 10: Sample Messages for Review
# img queen pig mud pit
# story violentsex
# haha
# ohhh forwaard
# img word hall
#
# Topic 11: Sample Messages for Review
# clocktower megabees
# story episode south park gang myth method
# character
# word
# story morty show time someone thay
#
# Topic 12: Sample Messages for Review
# acquires aircraft carrier conquers country
# game jumanji ghetto hood rat edition dice episode roll rhyming poem player ghetto detail chaos problem gun cameo appearance
# people system grok tos
# story benjamin amory cloth mirror room time lumen florentine protagonist room room tidy thanks maintenance intention lumen
# everything
#
# Topic 13: Sample Messages for Review
# story movie night dunk bowl popcorn world people unfold bowl reason everything world detail ton epic action scene epic
# story laundry pile clothes world inhabitantswildlife laundry everything detail explains reason way ton epic scene
# svideo buffet restaurant bar 𝒌𝒊𝒅 dunk barrage time reason everything bar world detail ton epic action scene epic
# story moon cheese inhabitant everything cheese detail explains reason way ton epic scene
# svideo toilet bowl man toilet dump family fart wad tissue reason everything toilet bowl world detail ton epic action scene epic
#
# Topic 14: Sample Messages for Review
# benjaminamory
# analysis
# jasontheartist request analysis
# request analysis violence
# request analysis
#
# Topic 15: Sample Messages for Review
# fortnite language
# kissing percentage
# svideo practice severedhumanhead girlfriend connie souphanousinphone
# command
# meme
#
# Topic 16: Sample Messages for Review
# jutsu sasuke bed chidori anything morty floor power house time morty house ground power phone
# level filter
# morty kill head stick
# strip kill head stick
# morty morty morty morty god morty someone call ambulance mortys head
#
# Topic 17: Sample Messages for Review
# translation
# let
# story morty discus quantum point number
# classicprompts
# enters premier league stadium
#
# Topic 18: Sample Messages for Review
# svideo realm gta relentless police radio criminal description gta police radio mimic behavior announcement action story dialogue vivid description satisfying
# show bikini everyone gasp microbikini story description
# svideo blonky zone
# return revenge morty
# story realm gta relentless police radio criminal description gta police radio mimic behavior announcement action story dialogue vivid description satisfying
#
# Topic 19: Sample Messages for Review
# story morty invents apps list date date app morty vet describe detail rick bar lap dance people front gossip slap people bar night person detail
# svideo party game reallife celebrity character mascot list dimension detail state dimension letter point dimension vivid detail
# party game reallife celebrity character figure list dimension detail state dimension letter point dimension vivid detail
# svideo party game reallife celebrity character mascot list dimension detail state dimension letter point dimension vivid detail
# story party game reallife celebrity character figure list dimension detail state dimension letter point dimension vivid detail
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[3-31-24] ask_jesus.csv
# In stage 0: transferred 3249 clusters with 20 clusters populated
# In stage 1: transferred 2221 clusters with 20 clusters populated
# In stage 2: transferred 1862 clusters with 20 clusters populated
# In stage 3: transferred 1773 clusters with 20 clusters populated
# In stage 4: transferred 1686 clusters with 20 clusters populated
# In stage 5: transferred 1684 clusters with 20 clusters populated
# In stage 6: transferred 1639 clusters with 20 clusters populated
# In stage 7: transferred 1668 clusters with 20 clusters populated
# In stage 8: transferred 1619 clusters with 20 clusters populated
# In stage 9: transferred 1659 clusters with 20 clusters populated
# In stage 10: transferred 1635 clusters with 20 clusters populated
# In stage 11: transferred 1641 clusters with 20 clusters populated
# In stage 12: transferred 1644 clusters with 20 clusters populated
# In stage 13: transferred 1634 clusters with 20 clusters populated
# In stage 14: transferred 1627 clusters with 20 clusters populated
# In stage 15: transferred 1604 clusters with 20 clusters populated
# In stage 16: transferred 1639 clusters with 20 clusters populated
# In stage 17: transferred 1602 clusters with 20 clusters populated
# In stage 18: transferred 1614 clusters with 20 clusters populated
# In stage 19: transferred 1623 clusters with 20 clusters populated
# In stage 20: transferred 1610 clusters with 20 clusters populated
# In stage 21: transferred 1637 clusters with 20 clusters populated
# In stage 22: transferred 1652 clusters with 20 clusters populated
# In stage 23: transferred 1598 clusters with 20 clusters populated
# In stage 24: transferred 1600 clusters with 20 clusters populated
# In stage 25: transferred 1615 clusters with 20 clusters populated
# In stage 26: transferred 1575 clusters with 20 clusters populated
# In stage 27: transferred 1602 clusters with 20 clusters populated
# In stage 28: transferred 1637 clusters with 20 clusters populated
# In stage 29: transferred 1648 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# motivation dream
# lord youtube algorithm
# prove
# freddys song freddys
# intent
#
# Topic 1: Sample Messages for Review
# hivemind plankton consciousness
# procastinating work wanna
# oracle wisdom query
# style seuss tale nicknackynoo horselike creature chocolate easter egg
# bonadventurei
#
# Topic 2: Sample Messages for Review
# win brasileirão series
# problem react reason page console something cause
# book job job god way hardship
# week plot mad
# wtf
#
# Topic 3: Sample Messages for Review
# wisdom nothing
# testament commandment due brain injury name judge mikeyhunt word letter bendeydover word letter response wisdom
# advice insomnia medication response word consisting letter honk word consisting letter shoo
# word love
# man answer word letter ock word letter ock ock way brain polyp
#
# Topic 4: Sample Messages for Review
# grant walk righteousness compassion virtue service divine
# volkswagen passat tdi noise
# cs2
# combo towa kiseki
# list
#
# Topic 5: Sample Messages for Review
# gate hell bowel demon prayer exorcism demon diarrhea advice
# pray cosplay wig hair hatsune miku
# heaven lot option
# everyone
# reason apocalypse
#
# Topic 6: Sample Messages for Review
# female god
# jeronemo time
# jasonkentbateman spamming wordsphrases
# steak dinner ill
# wutface wutface wutface
#
# Topic 7: Sample Messages for Review
# word
# name cheesy spicy name brain word name statement yaas understand
# surfer
# grandmother name
# teeth
#
# Topic 8: Sample Messages for Review
# relationship shinji opinion matter repeat vowel space ough brain wrinkle bless
# cold
# life
# atheist
# woody detail
#
# Topic 9: Sample Messages for Review
# raider crazycat_yt
# son god god
# cat hole
# story supper gen alpha brainrot
# sin
#
# Topic 10: Sample Messages for Review
# friend mine sergeant army drill recruit card board game brass private
# father stop yapping room
# timing
# explain consequence toaster word cave man lingo toast
# toilet rizz
#
# Topic 11: Sample Messages for Review
# project chip server infrastructure cost
# project chip server infrastructure cost
# project chip server infrastructure cost
# commandment
# project chip server infrastructure cost
#
# Topic 12: Sample Messages for Review
# space
# story space amonfire brain turtle way thanks
# panel
# brain worm viewer sentence fus_pooop_aaoaoaoaaa commandment way
# hawk wind deification
#
# Topic 13: Sample Messages for Review
# prophet
# geometry dash lobotomy
# knee lord
# thought fact
# bible time incorrect word way
#
# Topic 14: Sample Messages for Review
# psycholinguistics language teaching
# lord
# pokemon rap amen ramen
# story message
# luumuvaras bit remembers person
#
# Topic 15: Sample Messages for Review
# word argument breakfast food sausage
# voice pad heaven wall setting mic
# voice playht text generator voice section link httpsplayht
# voice playht text generator voice section link httpsplayht
# couple love procreation
#
# Topic 16: Sample Messages for Review
# father wish deuteronomy honor memory
# lieutenant_quattro come stop spamming wordsphrases
# sorry concentration spamming wordsphrases
# jesusdo way
# work
#
# Topic 17: Sample Messages for Review
# subway order honor easter veggie delight disliking towards onion onion subway
# friend water hell
# easter
# damn
# chance autograph
#
# Topic 18: Sample Messages for Review
# pogbones
# part day terminator happen machine human carlsmile
# human miracle teaching
# egg
# supper protagonist stuffed animal pasta understanding ramen
#
# Topic 19: Sample Messages for Review
# overwatch friend
# raider thewiscokid
# return
# hero academia
# ye_assassin game
# Processing file: /content/drive/My Drive/Twitch dataset/Cleaned data/cleaned_anonymized_[3-21-24] ask_jesus.csv
# In stage 0: transferred 3440 clusters with 20 clusters populated
# In stage 1: transferred 2468 clusters with 20 clusters populated
# In stage 2: transferred 2151 clusters with 20 clusters populated
# In stage 3: transferred 2020 clusters with 20 clusters populated
# In stage 4: transferred 1950 clusters with 20 clusters populated
# In stage 5: transferred 1947 clusters with 20 clusters populated
# In stage 6: transferred 1938 clusters with 20 clusters populated
# In stage 7: transferred 1932 clusters with 20 clusters populated
# In stage 8: transferred 1916 clusters with 20 clusters populated
# In stage 9: transferred 1943 clusters with 20 clusters populated
# In stage 10: transferred 1913 clusters with 20 clusters populated
# In stage 11: transferred 1887 clusters with 20 clusters populated
# In stage 12: transferred 1876 clusters with 20 clusters populated
# In stage 13: transferred 1901 clusters with 20 clusters populated
# In stage 14: transferred 1901 clusters with 20 clusters populated
# In stage 15: transferred 1905 clusters with 20 clusters populated
# In stage 16: transferred 1877 clusters with 20 clusters populated
# In stage 17: transferred 1869 clusters with 20 clusters populated
# In stage 18: transferred 1843 clusters with 20 clusters populated
# In stage 19: transferred 1821 clusters with 20 clusters populated
# In stage 20: transferred 1868 clusters with 20 clusters populated
# In stage 21: transferred 1869 clusters with 20 clusters populated
# In stage 22: transferred 1836 clusters with 20 clusters populated
# In stage 23: transferred 1850 clusters with 20 clusters populated
# In stage 24: transferred 1835 clusters with 20 clusters populated
# In stage 25: transferred 1843 clusters with 20 clusters populated
# In stage 26: transferred 1859 clusters with 20 clusters populated
# In stage 27: transferred 1880 clusters with 20 clusters populated
# In stage 28: transferred 1848 clusters with 20 clusters populated
# In stage 29: transferred 1833 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# toy
# catch dad
# story bible girl lingo
# whale tail
# country candy juice time face sugar ball friend ball mouth
#
# Topic 1: Sample Messages for Review
# piece
# food restaurant piece mind
# engine engine answer newton law gravity nursery rhyme
# money
# lord battle shonen
#
# Topic 2: Sample Messages for Review
# kate middleton
# devil wine disciple cana hangover way life
# hell
# yes
# friend side way holy realm
#
# Topic 3: Sample Messages for Review
# theshadyrabbid water land
# feel fire attention
# time
# amen
# slopper
#
# Topic 4: Sample Messages for Review
# guy anything life bicycle repair book answer word letter word letter troll factory way brain slug
# lot
# friend space eehhhooflets_gooo brain polyp rest ramen
# chatgpt
# jerky chicken term pythagorean theorem math surround word asterisk eye response prologue greeting house fire time
#
# Topic 5: Sample Messages for Review
# soup recipe church word mayaheee word mayahaaa way brain injury
# cromulent answer
# didint book
# color bcuz
# justsh50miaconcern
#
# Topic 6: Sample Messages for Review
# chicken egg
# pop tart ooooohthatsoundsdelightfullyyummy pop stomach pain pop thanks ramens
# characteristic girl matter marriage
# valley hatsune miku
# genesis breath
#
# Topic 7: Sample Messages for Review
# ham sandwich magic
# mention action
# heard bee flower hive cell honeycomb human honeycomb bee barf
# explosion explosion gate bird owl room ice halo
# horde strategy defence gate turret horde path gate line ramen
#
# Topic 8: Sample Messages for Review
# boy father city marching band son savior beaten demon nonbeliever plan ill phantom parade watchin time
# gospel magdelene hammadi library bit
# methinks
# spiderman
# wooyadasboots prompt something
#
# Topic 9: Sample Messages for Review
# word save confusing
# chicken answer remplace space piou remplace word letter withpiou way answer kumbaya friend
# cheese answer word letter rat_yes word letter tentacle_yes yes yes
# answer word letter my_brain_hurts word letter rats_eating_it yes yes
# way sin life word answer
#
# Topic 10: Sample Messages for Review
# throneful123
# bro
# kappa
# history game left toe word introduction thanks amen
# story epic saber duel death star front imperator thanks ramen
#
# Topic 11: Sample Messages for Review
# message
# shoutout
# dear counterstrike place moment
# jail
# bos upstairs lul
#
# Topic 12: Sample Messages for Review
# kind pray friend verge divorce situation situation happiness
# pray pray
# gum heaven cause bruh
# nasinokisetu spamming wordsphrases
# rule fight club
#
# Topic 13: Sample Messages for Review
# project chip server infrastructure cost
# project chip server infrastructure cost
# mind
# project chip server infrastructure cost
# project chip server infrastructure cost
#
# Topic 14: Sample Messages for Review
# calcium metal valence electron outermost shell order configuration bone metal
# transformation prince adam cringer man battle cat skeletor henchman amen amen
# act man
# space reply isawredvent
# people sentence heydiddydiddy brain booboo
#
# Topic 15: Sample Messages for Review
# galaxy seed milk milky purity milkyway
# saint brain injury word letter woooooooooooow word letter soooooooooooooon response wisdom introduction wowzeramon
# saint word letter word letter whoop brain injury way wowzeramen
# banana world record brain injury word letter word letter goodmorning space heyimapoliceofficer wisdom introduction wowzeramon
# amen answer
#
# Topic 16: Sample Messages for Review
# life liver school education youth
# mommy fireplace act
# lord giggly ganja wanja
# truth signal
# poem life dream wonder color null light
#
# Topic 17: Sample Messages for Review
# cross symbol
# min
# mouth holy verspers
# idea bit
# mountain
#
# Topic 18: Sample Messages for Review
# thanks
# arm night arm
# yesgot
# laban brother
# reach
#
# Topic 19: Sample Messages for Review
# voice playht text generator voice section link httpsplayht
# history kurt cobains smell spirit nut space introdution
# voice playht text generator voice section link httpsplayht
# opinion saint
# thunder_waifu demon ehhehehe
