# %%
# !pip install git+https://github.com/rwalk/gsdmm.git
# !pip install nltk spacy gensim pyLDAvis networkx
# !pip install wordcloud

import os
import pandas as pd
import numpy as np
import re
import random
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import pos_tag
import nltk
import spacy
import gensim
from gsdmm import MovieGroupProcess
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pyLDAvis.gensim_models as gensimvis
import networkx as nx
from collections import Counter
from itertools import combinations

# Load Spacy's English model for Named Entity Recognition
nlp = spacy.load("en_core_web_sm")

# Mount Google Drive to access the dataset stored there
from google.colab import drive
drive.mount('/content/drive')

# Download necessary NLTK resources for tokenization and POS tagging
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

# Enhance the stop words list with terms commonly irrelevant in casual discussions
additional_stopwords = {'get', 'okay', 'oh', 'yeah', 'hey', 'hi', 'please', 'thank', 'welcome', 'like', 'just', 'know', 'really', 'thing', 'things', 'said', 'also', 'one', 'use', 'using', 'used'}

# Context-specific terms related to AI-generated content discussions
contextual_stopwords = {'help', 'think', 'probably', 'topic', 'question', 'ask', 'need'}

# AI-generated content specific terms
aigc_stopwords = {'ai', 'artificial', 'intelligence', 'generated', 'generate', 'generation', 'content', 'image', 'images', 'video', 'videos', 'picture', 'pictures', 'photo', 'photos', 'graphic', 'graphics', 'stable', 'diffusion', 'model', 'models'}

# Platform-specific terms related to Discord discussions
discord_stopwords = {'discord', 'server', 'midjourney', 'limewire', 'womboverse', 'maze', 'guru', 'prompthero', 'stablediffusion'}

# Combine all sets of stop words
stop_words = set(stopwords.words('english')) | additional_stopwords | aigc_stopwords | contextual_stopwords | discord_stopwords

# Define the preprocessing function
def preprocess(text):
    lemmatizer = WordNetLemmatizer()
    # Remove all non-word characters and lower the text
    text = re.sub(r'[^\w\s]', '', text.lower())
    # Split text into tokens
    tokens = text.split()
    # Apply NER to remove usernames and named entities
    doc = nlp(' '.join(tokens))
    tokens = [token.text for token in doc if not token.ent_type_]
    # POS 的位置提前了，本来在最后
    # Retain only nouns as they are significant for topic identification
    nouns = [word for word, pos in pos_tag(tokens) if pos.startswith('NN')]
    # 筛选本来 lemmatize 和 len(word) > 2 是在同一行的，有可能 lemmatize 之后 word length 小于 2，所以这里把长度筛选放在后面了
    # Lemmatize tokens and remove stop words and short words
    nouns = [lemmatizer.lemmatize(word) for word in nouns]
    nouns = [word for word in nouns if word not in stop_words and len(word) > 2]
    return nouns

# Function to load and preprocess data from CSV files
def load_data(file_path):
    df = pd.read_csv(file_path)
    df['preprocessed'] = df['Content'].apply(preprocess)
    return df['preprocessed'].tolist()

# Path to the folder containing the dataset
folder_path = '/content/drive/My Drive/Discord dataset/Cleaned data/'
file_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.csv')]

# Function to randomly select messages from each topic for manual review
def random_message_selection(docs, cluster_assignments, num_samples=5):
    topics = set(cluster_assignments)
    for topic_id in topics:
        topic_docs = [doc for i, doc in enumerate(docs) if cluster_assignments[i] == topic_id]
        sampled_messages = random.sample(topic_docs, min(len(topic_docs), num_samples))
        print(f"\nTopic {topic_id}: Sample Messages for Review")
        for message in sampled_messages:
            print(' '.join(message))

# Function to save plots to a PDF
from matplotlib.backends.backend_pdf import PdfPages

def save_plots_to_pdf(file_path, cluster_word_distribution, top_clusters):
    pdf_file_name = f'{os.path.basename(file_path)}_report.pdf'
    with PdfPages(pdf_file_name) as pdf:
        for topic_id in top_clusters:
            # Word cloud
            topic_words = cluster_word_distribution[topic_id]
            wordcloud = WordCloud(background_color='white', width=800, height=400).generate_from_frequencies(topic_words)
            plt.figure(figsize=(10, 5))
            plt.imshow(wordcloud, interpolation='bilinear')
            plt.title(f"Topic {topic_id} Word Cloud for {os.path.basename(file_path)}")
            plt.axis("off")
            pdf.savefig()
            plt.close()

            # Bar chart
            sorted_topic_words = dict(sorted(topic_words.items(), key=lambda item: item[1], reverse=True)[:10])
            plt.figure(figsize=(10, 5))
            plt.bar(sorted_topic_words.keys(), sorted_topic_words.values())
            plt.title(f"Top Words in Topic {topic_id}")
            plt.xticks(rotation=45)
            pdf.savefig()
            plt.close()

            # Network graph
            words = list(sorted_topic_words.keys())
            word_pairs = list(combinations(words, 2))
            G = nx.Graph()
            G.add_edges_from(word_pairs)
            pos = nx.spring_layout(G)
            plt.figure(figsize=(10, 5))
            nx.draw(G, pos, with_labels=True, node_size=50, font_size=10, edge_color='grey')
            plt.title(f"Word Co-occurrence Network for Topic {topic_id}")
            pdf.savefig()
            plt.close()

    return pdf_file_name

# Process each file, perform topic modeling, and generate visualizations
for file_path in file_paths:
    print(f"Processing file: {file_path}")
    docs = load_data(file_path)
    # Remove any empty documents resulting from preprocessing
    docs = [doc for doc in docs if doc]

    if len(docs) > 0:
        # Create a dictionary of all words in documents
        dictionary = gensim.corpora.Dictionary(docs)
        # Remove extremes to focus on relevant words only
        dictionary.filter_extremes(no_below=10, no_above=0.5, keep_n=10000)
        vocab_length = len(dictionary)

        if vocab_length == 0:
            print("No vocabulary available after filtering extremes. Skipping.")
            continue

        # Initialize and fit GSDMM model
        mgp = MovieGroupProcess(K=20, alpha=0.1, beta=0.3, n_iters=30)
        y = mgp.fit(docs, vocab_length)

        # Get cluster assignments and cluster word distributions
        cluster_assignments = y
        cluster_word_distribution = mgp.cluster_word_distribution

        # Random message selection for validation
        random_message_selection(docs, cluster_assignments)

        # Generate and display word clouds for each of the top 5 topics
        sorted_clusters = sorted(range(len(mgp.cluster_doc_count)), key=lambda k: mgp.cluster_doc_count[k], reverse=True)
        top_clusters = sorted_clusters[:5]

        # Save plots to PDF
        pdf_file_name = save_plots_to_pdf(file_path, cluster_word_distribution, top_clusters)

        # Provide a download link for the PDF file
        from google.colab import files
        files.download(pdf_file_name)
# Out:
# Collecting git+https://github.com/rwalk/gsdmm.git
#   Cloning https://github.com/rwalk/gsdmm.git to /tmp/pip-req-build-pmpokfv2
#   Running command git clone --filter=blob:none --quiet https://github.com/rwalk/gsdmm.git /tmp/pip-req-build-pmpokfv2
#   Resolved https://github.com/rwalk/gsdmm.git to commit 4ad1b6b6976743681ee4976b4573463d359214ee
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gsdmm==0.1) (1.26.4)
# Building wheels for collected packages: gsdmm
#   Building wheel for gsdmm (setup.py) ... done
#   Created wheel for gsdmm: filename=gsdmm-0.1-py3-none-any.whl size=4586 sha256=2bd06af7801a736e0439ec0e02c6b44bb9aac57bcfb1a6c2a24e914a35db4f80
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5obojgl7/wheels/da/d3/6e/a612d7cff0fcfb6470b8c113fc04931ecffb466ac19b9c5f3c
# Successfully built gsdmm
# Installing collected packages: gsdmm
# Successfully installed gsdmm-0.1
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.6)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.4.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.1.4)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.10.1)
# Collecting funcy (from pyLDAvis)
#   Downloading funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.5.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 25.1 MB/s eta 0:00:00
# Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-2.0 pyLDAvis-3.4.1
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Mounted at /content/drive
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_Midjourney - Chat - discussion [938713143759216720] (2022-01-01 to 2022-07-01)_anonymized.csv
# In stage 0: transferred 54536 clusters with 20 clusters populated
# In stage 1: transferred 49632 clusters with 20 clusters populated
# In stage 2: transferred 45627 clusters with 20 clusters populated
# In stage 3: transferred 41825 clusters with 20 clusters populated
# In stage 4: transferred 38985 clusters with 20 clusters populated
# In stage 5: transferred 37380 clusters with 20 clusters populated
# In stage 6: transferred 36393 clusters with 20 clusters populated
# In stage 7: transferred 35666 clusters with 20 clusters populated
# In stage 8: transferred 35224 clusters with 20 clusters populated
# In stage 9: transferred 34941 clusters with 20 clusters populated
# In stage 10: transferred 34519 clusters with 20 clusters populated
# In stage 11: transferred 34464 clusters with 20 clusters populated
# In stage 12: transferred 34179 clusters with 20 clusters populated
# In stage 13: transferred 33962 clusters with 20 clusters populated
# In stage 14: transferred 33866 clusters with 20 clusters populated
# In stage 15: transferred 33738 clusters with 20 clusters populated
# In stage 16: transferred 33592 clusters with 20 clusters populated
# In stage 17: transferred 33609 clusters with 20 clusters populated
# In stage 18: transferred 33570 clusters with 20 clusters populated
# In stage 19: transferred 33455 clusters with 20 clusters populated
# In stage 20: transferred 33304 clusters with 20 clusters populated
# In stage 21: transferred 33254 clusters with 20 clusters populated
# In stage 22: transferred 33145 clusters with 20 clusters populated
# In stage 23: transferred 33126 clusters with 20 clusters populated
# In stage 24: transferred 33193 clusters with 20 clusters populated
# In stage 25: transferred 33063 clusters with 20 clusters populated
# In stage 26: transferred 33070 clusters with 20 clusters populated
# In stage 27: transferred 32926 clusters with 20 clusters populated
# In stage 28: transferred 32840 clusters with 20 clusters populated
# In stage 29: transferred 32812 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# helpful time job
# oml lol
# goal
# job someone priority group
# value
#
# Topic 1: Sample Messages for Review
# planet
# idea sex addict room word sex
# guy future
# ippity farfuture game alien something
# slur word feel body
#
# Topic 2: Sample Messages for Review
# anyone input delay upvariation button
# press report fact
# samei box bit reluctantlyand arrow sequencebut page prompt
# creation website button people creation mine
# mar prompt
#
# Topic 3: Sample Messages for Review
# marathon race right
# wait init imagesor multi weight
# comp
# word
# prompt
#
# Topic 4: Sample Messages for Review
# lot tho
# amount lifetime pas form davidh ceo rainbow
# look cloud
# roids rage
# anything march behavior
#
# Topic 5: Sample Messages for Review
# thread
# sincarnate thread default kind showandtell
# search
# support way
# bot adult
#
# Topic 6: Sample Messages for Review
# slash command httpscdndiscordappcomattachments938956907031457862967087444472246312unknownpng faq information
# post notification
# logo patch experience
# hold release lot user system
# upscaler blur gigapixel
#
# Topic 7: Sample Messages for Review
# way eye torso
# wow
# camera technique effect
# scientist shoe result
# part matter matter person animal variation head yes
#
# Topic 8: Sample Messages for Review
# anyone midjourneys littlemore coherent line
# idea gpu power pool expansion
# hand everything
# database persepective perspective row database state starttime database enqueue time change bot database change percentage complete start tiem
# trend data source httpstrendsgooglecomtrendsexploregeousqmidjourneydalle202ai20artai20art20generator
#
# Topic 9: Sample Messages for Review
# time creation photoshop
# idea reference
# kind interesting story character prompt continuation style
# photobash
# others tool
#
# Topic 10: Sample Messages for Review
# prisoner
# google collab setting varying init_image
# access container run bunch http container
# fun movie poster pulp fiction batman etc
# earth quick
#
# Topic 11: Sample Messages for Review
# random
# art style
# anyone way belly
# name text
# variation core prompt characterseries automaton character yorha type name automaton prerequisite couple manner way description style etc
#
# Topic 12: Sample Messages for Review
# community team outlier vibe
# honor system repercussion basis something case style derivative business issue
# watermark ownership side
# version certainty court agreement party right output clause market
# care anything ketamine
#
# Topic 13: Sample Messages for Review
# invite pass standard plan
# life lie
# bot
# sad_pepe credit
# name tiktoks queue
#
# Topic 14: Sample Messages for Review
# release
# fair
# future work
# beta
# possibility
#
# Topic 15: Sample Messages for Review
# result lol amirkerr
# imagine lot cost backing
# way webpage purpose
# artstation result software
# fun
#
# Topic 16: Sample Messages for Review
# show lexx lead show show ship version specific kind
# statistician boardbut cash
# queen queen
# people counting fine
# shot charlize theron
#
# Topic 17: Sample Messages for Review
# something idea artist student form anything
# folk
# artist skill premium something
# refrence
# paint
#
# Topic 18: Sample Messages for Review
# word hyper texture fabric shiny metal coarse rock
# thanx
# stuff night
# withdrawal whiplash
# car car colorstones
#
# Topic 19: Sample Messages for Review
# stardew house pimple end progress
# variation
# react grid
# quality output lot time parameter observation
# size parameter presets size composition room experience
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_PromptHero - PromptHero - 🗨│general [1030178486398234684] (2022-10-13 to 2023-01-01)_anonymized.csv
# In stage 0: transferred 710 clusters with 20 clusters populated
# In stage 1: transferred 623 clusters with 20 clusters populated
# In stage 2: transferred 569 clusters with 20 clusters populated
# In stage 3: transferred 563 clusters with 20 clusters populated
# In stage 4: transferred 557 clusters with 20 clusters populated
# In stage 5: transferred 539 clusters with 20 clusters populated
# In stage 6: transferred 544 clusters with 20 clusters populated
# In stage 7: transferred 565 clusters with 20 clusters populated
# In stage 8: transferred 556 clusters with 20 clusters populated
# In stage 9: transferred 559 clusters with 20 clusters populated
# In stage 10: transferred 563 clusters with 20 clusters populated
# In stage 11: transferred 572 clusters with 20 clusters populated
# In stage 12: transferred 565 clusters with 20 clusters populated
# In stage 13: transferred 562 clusters with 20 clusters populated
# In stage 14: transferred 601 clusters with 20 clusters populated
# In stage 15: transferred 598 clusters with 20 clusters populated
# In stage 16: transferred 575 clusters with 20 clusters populated
# In stage 17: transferred 567 clusters with 20 clusters populated
# In stage 18: transferred 559 clusters with 20 clusters populated
# In stage 19: transferred 537 clusters with 20 clusters populated
# In stage 20: transferred 558 clusters with 20 clusters populated
# In stage 21: transferred 593 clusters with 20 clusters populated
# In stage 22: transferred 576 clusters with 20 clusters populated
# In stage 23: transferred 589 clusters with 20 clusters populated
# In stage 24: transferred 592 clusters with 20 clusters populated
# In stage 25: transferred 585 clusters with 20 clusters populated
# In stage 26: transferred 572 clusters with 20 clusters populated
# In stage 27: transferred 551 clusters with 20 clusters populated
# In stage 28: transferred 567 clusters with 20 clusters populated
# In stage 29: transferred 567 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# heard
# racheys introduction tech guess ogs veteran feel lot
# result
# thx bro
# bit humor httpstwittercomasciidiegostatus1583181296305508353s46tsnkkorrk0i3y38xgisk8w
#
# Topic 1: Sample Messages for Review
# guy nothing
# generatorsapplications codeweights
# access product end process
# alot nsfw
# redownload upscalers
#
# Topic 2: Sample Messages for Review
# interface product
# ckpt lot
# thanks start seed couple setting seed token prompt token keyword start position elsa end placement front style cherrypicking output work answer feature civitai
# f222 token keyword list idea
# interesting stuff
#
# Topic 3: Sample Messages for Review
# hello everyone challenge something challengeinfo information
# something
# design lot art issue
# form
# channel share 12mins
#
# Topic 4: Sample Messages for Review
# engagement right
# secret bunch
# dreambooth friend
# amount control freedom dreambooth
# charge indie art animation httpshuggingfacecoonodofthenorthsd_pixelart_spritesheet_generator
#
# Topic 5: Sample Messages for Review
# portrait anything
# gpu
# embedding difference comparison result
# seed anything
# result select ckpt
#
# Topic 6: Sample Messages for Review
# front page
# head limb
# rachey13x a1111 generatorsapplication support
# community tab bias httpspromptherocomcommunity
# ytbrs revolution
#
# Topic 7: Sample Messages for Review
# httpshuggingfacecoenvviinkpunkdiffusion
# shift composition threshold step
# prompt quality result time cost flexibility control
# hmm
# way site prompt lookstyle prompt time reserve google search prompt job prompt support community
#
# Topic 8: Sample Messages for Review
# checksum auth system invokeai system database comparison
# inversion
# time batch step rtx
# showcase pro lot information
# majority people automatic1111 gui list software httpspromptherocomresourcescategoryuser_interfaces
#
# Topic 9: Sample Messages for Review
# dunno way
# yes
# difference version
# news something mention runway quote news subset laion5b dataset deepfloyd team stability adult laions
# decision
#
# Topic 10: Sample Messages for Review
# people openjourney httpshuggingfacecopromptheroopenjourneydiscussions10 anyone openjourney
# anyone embeddings httpswwwredditcomrstablediffusioncommentsyy2i5ai_created_a_negative_embedding_textual_inversion
# beginning prompt style beginning
# style openjourney
# situation pickle object eval example
#
# Topic 11: Sample Messages for Review
# bunch extension httpsgithubcomhe1coautofillpromptherouploads lifesaver rate rate
# art
# change
# prompt love
# warning
#
# Topic 12: Sample Messages for Review
# yep cpu lool notebook bunch
# thanks
# creator answer creator waste time
# fuck
# httpspromptherocomprompt92df9f749f4 builder
#
# Topic 13: Sample Messages for Review
# link a1111 repo httpsgithubcomautomatic1111stablediffusionwebui
# mistake
# trick character hair head body work case
# detail breakdown lot artist celebrity stabilityai issue mindset game developer base mod game company userscustomers bethesda game player game httpswwwyoutubecomwatchvx_r9jj8mszk
# folder
#
# Topic 14: Sample Messages for Review
# yoda graffiti haha
# time people artist hell school art world artist painting tool layer artist
# minor history gatekeeping art time antiai community villain history book year
# guess movie
# artist impressionist art world
#
# Topic 15: Sample Messages for Review
# info
# exempel
# guy invokeai idea
# bunch quality input dataset output quality pikao
# someone runtimeerror tensor device device cpu cuda0 argument argument method wrapper_addmm promptheroopenjourney editor invokeai default error
#
# Topic 16: Sample Messages for Review
# heck synthwavepunk haha
# concept dream booth
# resolution
# pickle scanner
# kickstarter patron
#
# Topic 17: Sample Messages for Review
# handful embeddings prompt magic
# simple option prompt feature replacement a1111 option savvy individual install
# wow speedup
# woot fork night repo
# night process movie
#
# Topic 18: Sample Messages for Review
# ckpts folder
# time gui output folder
# work
# f222 right
# extension
#
# Topic 19: Sample Messages for Review
# pormpt
# way game asset fantasygame element sword skull gun job line
# yep upvotes violate community guideline people mod
# process
# outcome
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 128488 (\N{LEFT SPEECH BUBBLE}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_Maze Guru - AI Art, Anime & Social - Chat - 💬｜english-discussion [1037291441434677268] (2024-01-01 to 2024-03-01)_anonymized.csv
# In stage 0: transferred 314 clusters with 20 clusters populated
# In stage 1: transferred 265 clusters with 20 clusters populated
# In stage 2: transferred 275 clusters with 20 clusters populated
# In stage 3: transferred 272 clusters with 20 clusters populated
# In stage 4: transferred 248 clusters with 20 clusters populated
# In stage 5: transferred 259 clusters with 20 clusters populated
# In stage 6: transferred 237 clusters with 20 clusters populated
# In stage 7: transferred 256 clusters with 20 clusters populated
# In stage 8: transferred 252 clusters with 20 clusters populated
# In stage 9: transferred 247 clusters with 20 clusters populated
# In stage 10: transferred 259 clusters with 20 clusters populated
# In stage 11: transferred 240 clusters with 20 clusters populated
# In stage 12: transferred 243 clusters with 20 clusters populated
# In stage 13: transferred 261 clusters with 20 clusters populated
# In stage 14: transferred 247 clusters with 20 clusters populated
# In stage 15: transferred 247 clusters with 20 clusters populated
# In stage 16: transferred 240 clusters with 20 clusters populated
# In stage 17: transferred 233 clusters with 20 clusters populated
# In stage 18: transferred 245 clusters with 20 clusters populated
# In stage 19: transferred 250 clusters with 20 clusters populated
# In stage 20: transferred 245 clusters with 20 clusters populated
# In stage 21: transferred 230 clusters with 20 clusters populated
# In stage 22: transferred 244 clusters with 20 clusters populated
# In stage 23: transferred 264 clusters with 20 clusters populated
# In stage 24: transferred 245 clusters with 20 clusters populated
# In stage 25: transferred 253 clusters with 20 clusters populated
# In stage 26: transferred 254 clusters with 20 clusters populated
# In stage 27: transferred 250 clusters with 20 clusters populated
# In stage 28: transferred 251 clusters with 20 clusters populated
# In stage 29: transferred 250 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# bud nudity buff santa pool
# bomber
# style
# ghost bomber carrier megaton warhead
# thanks
#
# Topic 1: Sample Messages for Review
# sorry word admins rhyme reason case pervert word
# channel size example ping response
# define advice
# conversation
# opinion
#
# Topic 2: Sample Messages for Review
# issue post newbie benefit mod art platform support
# art minute anyone httpswwwyoutubecomwatchv7uryffyohec
# art copy pointsin sdxl anime art point error rest option
# bot
# nothing friend
#
# Topic 3: Sample Messages for Review
# something interface return
# tool httpswwwyoutubecomwatchvdhxlliyw8s
# username
# account
# custom dimension tool photoroomhttpsphotoroomcom
#
# Topic 4: Sample Messages for Review
# movie trailer chatgpt script chat gpt4 access star mission cut scene ship city laser people scene force scientist survivor communicate escape voiceover battle fate world cut scene brave hero leader hero power spirit cut title invasion invasion war lab scene music playing shadow earth narrator star force shot alien spacecraft panic chaos narrator humanity threat everything leader crisis force civilian arrival narrator sky alliance fate world hang balance cut scene scientist technology group people threat narrator battle survival resilience humanity test montage action sequence explosion glimpse alien invader prepare invasion screen message narrator trailer shot spacecraft hovering city audience narrator
#
# Topic 5: Sample Messages for Review
# app web subgenres
# point contest
# soooo
# point web app point contest
# access repair app
#
# Topic 6: Sample Messages for Review
# promotion channel chat thanks
# mean stuff bit newbie lol
# sorry computer thanks ping
# request mod thanks alert someone
# snout wolf ear
#
# Topic 7: Sample Messages for Review
# cyanfirewolf person
# waitlist website sora background
# contest membership
# girl skirt jdm car guess wht
# lol nutshell couple engine
#
# Topic 8: Sample Messages for Review
# palestine weapon peace face
# announcement httpsdiscordcomchannels100716691480143463410354724385338327141202511819437113364
# look
# zionism ideology palestine valley tigris river peace excuse power peace interest zionist peace part power subjugation party
# mode
#
# Topic 9: Sample Messages for Review
# website
# prompt website
# website
# stuff job child pedo
# web version
#
# Topic 10: Sample Messages for Review
# care
# time everyone report feature thanks
# heaven
# anyone
# result way
#
# Topic 11: Sample Messages for Review
# choir list word way mod radio silence agape person time trash
# imagine christmas tree
# yes sililarity setting
# peace politic government destroyed resist zionist day sheikh jarrah neighborhood incident example weapon zionist stop army land settlement day day till
# wait minute site till
#
# Topic 12: Sample Messages for Review
# yes
# control net
# thread
# thread
# click back version button left
#
# Topic 13: Sample Messages for Review
# pant amount prompt
# example someone jean pant pant
# nonskid
# channel
# channel
#
# Topic 14: Sample Messages for Review
# copy
# tactic hope bomb lot expense chip loosing battle battle type65b kamikazer bomb wire wood medal strut side wing fuselage rocket engine speed range rail system type65b kamikazer objective hell pain enemy kamikaze tactic
# gidrakos lot channel stuff
# place
#
# Topic 15: Sample Messages for Review
# people mod timezones someone mod kind
# earth people someone folk lol someone weird
# people credit
# try
# someone reply ticket
#
# Topic 16: Sample Messages for Review
# yea error
# time reporting method user
# nothing
# sorry time
# app nothing
#
# Topic 17: Sample Messages for Review
# reason style
# decision style
# come amount style function
# kind stuf stuf
# system style
#
# Topic 18: Sample Messages for Review
# info newbie point
# people
# guy partnership
# detail
# version style
#
# Topic 19: Sample Messages for Review
# thanks response
# power ranger helmet feature
# power ranger someone
# coke music hand let
# power ranger demon prompt
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 65372 (\N{FULLWIDTH VERTICAL LINE}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_Maze Guru - AI Art, Anime & Social - Chat - 💬｜english-discussion [1037291441434677268] (2022-11-01 to 2023-04-01)_anonymized.csv
# In stage 0: transferred 1257 clusters with 20 clusters populated
# In stage 1: transferred 1086 clusters with 20 clusters populated
# In stage 2: transferred 1001 clusters with 20 clusters populated
# In stage 3: transferred 957 clusters with 20 clusters populated
# In stage 4: transferred 945 clusters with 20 clusters populated
# In stage 5: transferred 944 clusters with 20 clusters populated
# In stage 6: transferred 973 clusters with 20 clusters populated
# In stage 7: transferred 926 clusters with 20 clusters populated
# In stage 8: transferred 921 clusters with 20 clusters populated
# In stage 9: transferred 917 clusters with 20 clusters populated
# In stage 10: transferred 941 clusters with 20 clusters populated
# In stage 11: transferred 948 clusters with 20 clusters populated
# In stage 12: transferred 953 clusters with 20 clusters populated
# In stage 13: transferred 955 clusters with 20 clusters populated
# In stage 14: transferred 938 clusters with 20 clusters populated
# In stage 15: transferred 900 clusters with 20 clusters populated
# In stage 16: transferred 910 clusters with 20 clusters populated
# In stage 17: transferred 922 clusters with 20 clusters populated
# In stage 18: transferred 897 clusters with 20 clusters populated
# In stage 19: transferred 936 clusters with 20 clusters populated
# In stage 20: transferred 932 clusters with 20 clusters populated
# In stage 21: transferred 922 clusters with 20 clusters populated
# In stage 22: transferred 922 clusters with 20 clusters populated
# In stage 23: transferred 946 clusters with 20 clusters populated
# In stage 24: transferred 941 clusters with 20 clusters populated
# In stage 25: transferred 911 clusters with 20 clusters populated
# In stage 26: transferred 924 clusters with 20 clusters populated
# In stage 27: transferred 948 clusters with 20 clusters populated
# In stage 28: transferred 935 clusters with 20 clusters populated
# In stage 29: transferred 934 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# part machine training
# training part prompt
# word filter
# bit
# understanding hand
#
# Topic 1: Sample Messages for Review
# right
# skin
# share url
# style
# morning everyone
#
# Topic 2: Sample Messages for Review
# shame paywall
# hello style hypernetwork keywords
# sunset style dora explorer warm inviting picturesque
# username
# job company
#
# Topic 3: Sample Messages for Review
# bot monster pornography smoke monster idea smoke monster pornography bot
# heh generator
# idea
# app colleague mine tigerill pic
# hmmm curiousity course clue word
#
# Topic 4: Sample Messages for Review
# rando bot
# qdaddypuffin sorry time
# mtgs norn propts diva featureless face headcrest something result negative featureless face work cuz diva
# try prompt breast
# man face
#
# Topic 5: Sample Messages for Review
# check lot
# idea
# someone ticket
# filter system
# pay slothrofl
#
# Topic 6: Sample Messages for Review
# thread
# text generator coherent text
# wifi result
# something
# something
#
# Topic 7: Sample Messages for Review
# mean
# site
# quality
# guy criterion pornography show cleavage villainess
# care guy
#
# Topic 8: Sample Messages for Review
# soooo something example mickeymouse gon mouse mickey
# mecha journey
# prompt
# thanks bot
# pay subscribe
#
# Topic 9: Sample Messages for Review
# thanks
# wow friend
# post
# point prince
# thanks tip tomorrow point
#
# Topic 10: Sample Messages for Review
# point challenge weeklytheme
# abadomazeguru
# guy doubt point understand spending work message
# point
# point operation cost
#
# Topic 11: Sample Messages for Review
# message
# yep
# newbie
# post
# feature
#
# Topic 12: Sample Messages for Review
# team research upscalers
# shape
# character
# screenshot
# diligence time stuff download page
#
# Topic 13: Sample Messages for Review
# something
# everyone
# puffin
# glad sorry
# prompt woman eye face eye eye face eye
#
# Topic 14: Sample Messages for Review
# place stuff
# way
# people way work
# install
# thanks
#
# Topic 15: Sample Messages for Review
# anyone fun
# anyone stuff
# somone theme person
# game job
# case instruction
#
# Topic 16: Sample Messages for Review
# friend
# anyone job
# jeeez thanks
# expert art reference writing fun friend classmate
# time people girl study online browser girl symbol stuff
#
# Topic 17: Sample Messages for Review
# employee game development company detail contact
# gay
# place invite invite everyone
# site moderator generator
# art generator struggle skin tone
#
# Topic 18: Sample Messages for Review
# someone gon
# anything post gen
# try
# newbie network latency issue
# hello
#
# Topic 19: Sample Messages for Review
# sorry experience
# nothing happens
# piece
# blocking issue system user problem website
# sorry support web httpsmazeguru log account thanks feedback function
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 65372 (\N{FULLWIDTH VERTICAL LINE}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_👽 WOMBOVERSE 👽 - 《 👽》LOUNGE - 💬│general-chat [774124295524712480] (2024-01-01 to 2024-03-01)_anonymized.csv
# In stage 0: transferred 6555 clusters with 20 clusters populated
# In stage 1: transferred 5772 clusters with 20 clusters populated
# In stage 2: transferred 5442 clusters with 20 clusters populated
# In stage 3: transferred 5206 clusters with 20 clusters populated
# In stage 4: transferred 5074 clusters with 20 clusters populated
# In stage 5: transferred 4987 clusters with 20 clusters populated
# In stage 6: transferred 4857 clusters with 20 clusters populated
# In stage 7: transferred 4909 clusters with 20 clusters populated
# In stage 8: transferred 4835 clusters with 20 clusters populated
# In stage 9: transferred 4818 clusters with 20 clusters populated
# In stage 10: transferred 4755 clusters with 20 clusters populated
# In stage 11: transferred 4785 clusters with 20 clusters populated
# In stage 12: transferred 4770 clusters with 20 clusters populated
# In stage 13: transferred 4714 clusters with 20 clusters populated
# In stage 14: transferred 4682 clusters with 20 clusters populated
# In stage 15: transferred 4654 clusters with 20 clusters populated
# In stage 16: transferred 4632 clusters with 20 clusters populated
# In stage 17: transferred 4744 clusters with 20 clusters populated
# In stage 18: transferred 4715 clusters with 20 clusters populated
# In stage 19: transferred 4686 clusters with 20 clusters populated
# In stage 20: transferred 4638 clusters with 20 clusters populated
# In stage 21: transferred 4614 clusters with 20 clusters populated
# In stage 22: transferred 4571 clusters with 20 clusters populated
# In stage 23: transferred 4656 clusters with 20 clusters populated
# In stage 24: transferred 4653 clusters with 20 clusters populated
# In stage 25: transferred 4580 clusters with 20 clusters populated
# In stage 26: transferred 4591 clusters with 20 clusters populated
# In stage 27: transferred 4612 clusters with 20 clusters populated
# In stage 28: transferred 4601 clusters with 20 clusters populated
# In stage 29: transferred 4577 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# work tho
# work premium user wombot nsfw ban nsfw room ban information click note march app httpswombotai
# anyone wombot
# work premium user wombot nsfw ban nsfw room ban information click note march app httpswombotai
# work premium user wombot nsfw ban nsfw room ban information click note march app httpswombotai
#
# Topic 1: Sample Messages for Review
# tat
# pfp grey
# reason page post something link page
# captn app bed page ill
# difference website httpsdreamaicreate
#
# Topic 2: Sample Messages for Review
# lol
# let reference
# artwork
# music feature
# slow connection
#
# Topic 3: Sample Messages for Review
# bun
# update style
# afternoon way prompt
# sticker v3s design water bottle sticker border
# share art channel
#
# Topic 4: Sample Messages for Review
# sorry
# tho gon die drop dunno tho
# work
# gosh
# type disguise company anything bloke thick moustache
#
# Topic 5: Sample Messages for Review
# bot issue
# beckons time shop
# wombot dream people plusone track accumulates rank
# post stuff lol
# dream
#
# Topic 6: Sample Messages for Review
# morning
# happens
# spud carbs others
# glad
# thanks
#
# Topic 7: Sample Messages for Review
# hella art cuz guide link gng
# mop goblin share
# daft
# captain flirt
# elbow fun party trick everything kneecap dislocates
#
# Topic 8: Sample Messages for Review
# quote
# computer moment typing crime
# captn alpine_butterfly bubble anyone
# captn mod removal
# morning
#
# Topic 9: Sample Messages for Review
# language
# dream app
# style
# account google apple
# bot channel
#
# Topic 10: Sample Messages for Review
# crow
# yrah treatment
# biscuit
# lemme look
# heard everything beatles fan lol
#
# Topic 11: Sample Messages for Review
# wassup
# womboi
# hole
# werewolf
# thanks hug
#
# Topic 12: Sample Messages for Review
# alcohol something
# character game style mean information internet example
# bit everything
# place kid
# bet game
#
# Topic 13: Sample Messages for Review
# week
# fire exchange
# guess
# weather cycle wind gust
# company logo right
#
# Topic 14: Sample Messages for Review
# stuff
# change something api setting
# luck
# option
# time
#
# Topic 15: Sample Messages for Review
# oooh machine cry
# appointment wing january
# man
# vanilla starbucks
# granddaughter slime
#
# Topic 16: Sample Messages for Review
# lol
# reference people
# lot art
# room
# glad
#
# Topic 17: Sample Messages for Review
# mind complain
# anything room
# mod team
# enigmasculptor post evening time lot emojis work gallery emojis validate thread banje answer art channel chance message hope participation existence date time
# yes thanks
#
# Topic 18: Sample Messages for Review
# background
# see anyone clue
# greeting
# pat rub
# stir fry
#
# Topic 19: Sample Messages for Review
# nope helper mute
# something room
# birthday reminder
# superb timing
# tattoo design lol
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 128125 (\N{EXTRATERRESTRIAL ALIEN}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 12298 (\N{LEFT DOUBLE ANGLE BRACKET}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 12299 (\N{RIGHT DOUBLE ANGLE BRACKET}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_👽 WOMBOVERSE 👽 - 《 👽》LOUNGE - 💬│general-chat [774124295524712480] (2020-11-01 to 2021-12-01)_anonymized.csv
# In stage 0: transferred 9851 clusters with 20 clusters populated
# In stage 1: transferred 8714 clusters with 20 clusters populated
# In stage 2: transferred 8180 clusters with 20 clusters populated
# In stage 3: transferred 7827 clusters with 20 clusters populated
# In stage 4: transferred 7693 clusters with 20 clusters populated
# In stage 5: transferred 7503 clusters with 20 clusters populated
# In stage 6: transferred 7449 clusters with 20 clusters populated
# In stage 7: transferred 7320 clusters with 20 clusters populated
# In stage 8: transferred 7235 clusters with 20 clusters populated
# In stage 9: transferred 7163 clusters with 20 clusters populated
# In stage 10: transferred 7115 clusters with 20 clusters populated
# In stage 11: transferred 7060 clusters with 20 clusters populated
# In stage 12: transferred 7152 clusters with 20 clusters populated
# In stage 13: transferred 7074 clusters with 20 clusters populated
# In stage 14: transferred 7035 clusters with 20 clusters populated
# In stage 15: transferred 7016 clusters with 20 clusters populated
# In stage 16: transferred 6996 clusters with 20 clusters populated
# In stage 17: transferred 7007 clusters with 20 clusters populated
# In stage 18: transferred 6961 clusters with 20 clusters populated
# In stage 19: transferred 6990 clusters with 20 clusters populated
# In stage 20: transferred 7092 clusters with 20 clusters populated
# In stage 21: transferred 7023 clusters with 20 clusters populated
# In stage 22: transferred 6991 clusters with 20 clusters populated
# In stage 23: transferred 7011 clusters with 20 clusters populated
# In stage 24: transferred 6993 clusters with 20 clusters populated
# In stage 25: transferred 6981 clusters with 20 clusters populated
# In stage 26: transferred 6940 clusters with 20 clusters populated
# In stage 27: transferred 6959 clusters with 20 clusters populated
# In stage 28: transferred 6880 clusters with 20 clusters populated
# In stage 29: transferred 6814 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# furry
# work
# gon tear eye fall ground cry blood eye floor
# rickroll
# door
#
# Topic 1: Sample Messages for Review
# game
# money game stuff
# fire
# official moment family guy sus
# prepare business
#
# Topic 2: Sample Messages for Review
# insane
# penguin
# song
# ladder mistake
# invite beta
#
# Topic 3: Sample Messages for Review
# nope
# stuff
# shtposts
# source source cashmoney
# test gui
#
# Topic 4: Sample Messages for Review
# pointclouds octomaps
# color
# thanks lot
# everyo
# milanesa boy
#
# Topic 5: Sample Messages for Review
# money
# ping
# ping dammit
# lot ping
# tongue mark wall
#
# Topic 6: Sample Messages for Review
# boy
# min
# fart
# exit wombo
# bout
#
# Topic 7: Sample Messages for Review
# everyones plan
# course
# watermark good wombo
# devs
# wombo team money
#
# Topic 8: Sample Messages for Review
# everyone
# womboers chat
# hello friend
# man amrit
# watermark
#
# Topic 9: Sample Messages for Review
# hru chillin
# everyone
# rule name
# everyone
# incorrect
#
# Topic 10: Sample Messages for Review
# app
# channals
# face2face paper
# employee account
# tech savvy
#
# Topic 11: Sample Messages for Review
# live
# send
# friend
# profanity
# mode vscode bit
#
# Topic 12: Sample Messages for Review
# version song
# fun people
# text voice
# song
# friend minecraft shaders fps
#
# Topic 13: Sample Messages for Review
# connection
# shoe
# group nothing
# father office lmfao
# lady
#
# Topic 14: Sample Messages for Review
# evaxephon
# app emulator ldplayer bluestacks version app result
# app emulator ldplayer bluestacks version app result
# app emulator ldplayer bluestacks version app result httpsyoutubevgbycvwdina
# app
#
# Topic 15: Sample Messages for Review
# peepohey
# yanderify
# song
# world
# trolley
#
# Topic 16: Sample Messages for Review
# official possibility app
# pay phone
# curiosity song
# something
# custom song wombo
#
# Topic 17: Sample Messages for Review
# people
# dream
# download wombo app chromebook
# wassup
# support
#
# Topic 18: Sample Messages for Review
# bug
# donald
# breaking rule
# loooooot load right vivo sorry demand
# resolution sound
#
# Topic 19: Sample Messages for Review
# twitter
# sht meme
# amleft
# wsl2 abuse hyperv stuff
# twitter
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 128125 (\N{EXTRATERRESTRIAL ALIEN}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 12298 (\N{LEFT DOUBLE ANGLE BRACKET}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 12299 (\N{RIGHT DOUBLE ANGLE BRACKET}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_Midjourney - Chat - discussion [938713143759216720] (2022-02-01 to 2022-04-01)_anonymized.csv
# In stage 0: transferred 6864 clusters with 20 clusters populated
# In stage 1: transferred 5823 clusters with 20 clusters populated
# In stage 2: transferred 5276 clusters with 20 clusters populated
# In stage 3: transferred 5017 clusters with 20 clusters populated
# In stage 4: transferred 4778 clusters with 20 clusters populated
# In stage 5: transferred 4779 clusters with 20 clusters populated
# In stage 6: transferred 4657 clusters with 20 clusters populated
# In stage 7: transferred 4676 clusters with 20 clusters populated
# In stage 8: transferred 4626 clusters with 20 clusters populated
# In stage 9: transferred 4526 clusters with 20 clusters populated
# In stage 10: transferred 4507 clusters with 20 clusters populated
# In stage 11: transferred 4543 clusters with 20 clusters populated
# In stage 12: transferred 4481 clusters with 20 clusters populated
# In stage 13: transferred 4443 clusters with 20 clusters populated
# In stage 14: transferred 4432 clusters with 20 clusters populated
# In stage 15: transferred 4374 clusters with 20 clusters populated
# In stage 16: transferred 4443 clusters with 20 clusters populated
# In stage 17: transferred 4433 clusters with 20 clusters populated
# In stage 18: transferred 4403 clusters with 20 clusters populated
# In stage 19: transferred 4402 clusters with 20 clusters populated
# In stage 20: transferred 4474 clusters with 20 clusters populated
# In stage 21: transferred 4468 clusters with 20 clusters populated
# In stage 22: transferred 4407 clusters with 20 clusters populated
# In stage 23: transferred 4403 clusters with 20 clusters populated
# In stage 24: transferred 4393 clusters with 20 clusters populated
# In stage 25: transferred 4436 clusters with 20 clusters populated
# In stage 26: transferred 4400 clusters with 20 clusters populated
# In stage 27: transferred 4370 clusters with 20 clusters populated
# In stage 28: transferred 4378 clusters with 20 clusters populated
# In stage 29: transferred 4390 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# revolution code
# subtext bio
# hmm
# placebo quality upscales anyone something result difference check
# style prompt number default test grid word position
#
# Topic 1: Sample Messages for Review
# sauce term imho
# friend
# others
# way idea friend
# bit
#
# Topic 2: Sample Messages for Review
# term
# experiment bro
# tuning
# level everyone compute
# issue tho
#
# Topic 3: Sample Messages for Review
# bucket daniel feature
# safety concern people slip
# cyan pic handful cyan
# repeat offender
# tool people decision tool cut people
#
# Topic 4: Sample Messages for Review
# slash command rate limit fyi
# cluster run capacity
# role permission dev bot command
# imagine work error
# queue
#
# Topic 5: Sample Messages for Review
# haha
# tool people number
# day
# platform people art work royalty rate
# medium
#
# Topic 6: Sample Messages for Review
# people kind join channel community signup form category channel
# shock channel shock channel
# feedback guy
# survey option option
# bot thread person
#
# Topic 7: Sample Messages for Review
# feedback time team work launch day beta spent prompt ability favorite wait mean creation thanks spin_heart_yellow
# wait job
# ability idea
# group anyone guide people
# people doc
#
# Topic 8: Sample Messages for Review
# way word url example word night prompt commonality color word time pool word hope sense
# word nonsense prompt
# example surgery people
# test prompt measure variability embeddings battle list nonetheless
# issue intent
#
# Topic 9: Sample Messages for Review
# twitter bot handle
# twitter bot guess term post spam
# machine library channel atm
# job
# url prompt
#
# Topic 10: Sample Messages for Review
# result case
# yes
# case
# option issue default size size
# algorithm
#
# Topic 11: Sample Messages for Review
# danielrussruss somnai share file name default
# log
# voting submission poster advantage
# coltond
# desktop version
#
# Topic 12: Sample Messages for Review
# area data
# failure mode part experience atm
# error anything
# engine
# lot hahah
#
# Topic 13: Sample Messages for Review
# art piece vanilla katherine
# artist example
# wonder artstation artist
# art
# bloodbank
#
# Topic 14: Sample Messages for Review
# character limit
# sign antichrist
# dash character prompt
# somehow
# end world
#
# Topic 15: Sample Messages for Review
# realize
# cool
# davidh vitl box autocorrection sylvanas
# issue app
# tie wwwvirtualpsychedelicscom hap leonard
#
# Topic 16: Sample Messages for Review
# course haha
# folk care
# gotcha
# ill something
# haha possum something
#
# Topic 17: Sample Messages for Review
# style parameter style channel
# prompt request difference variation params resolution
# see message
# ability
# upscales
#
# Topic 18: Sample Messages for Review
# start
# lab medium cost resource stuff people
# speaking
# ...
# In stage 14: transferred 2084 clusters with 20 clusters populated
# In stage 15: transferred 2076 clusters with 20 clusters populated
# In stage 16: transferred 2083 clusters with 20 clusters populated
# In stage 17: transferred 2085 clusters with 20 clusters populated
# In stage 18: transferred 2101 clusters with 20 clusters populated
# In stage 19: transferred 2141 clusters with 20 clusters populated
# In stage 20: transferred 2119 clusters with 20 clusters populated
# In stage 21: transferred 2112 clusters with 20 clusters populated
# In stage 22: transferred 2135 clusters with 20 clusters populated
# In stage 23: transferred 2095 clusters with 20 clusters populated
# In stage 24: transferred 2101 clusters with 20 clusters populated
# In stage 25: transferred 2100 clusters with 20 clusters populated
# In stage 26: transferred 2074 clusters with 20 clusters populated
# In stage 27: transferred 2096 clusters with 20 clusters populated
# In stage 28: transferred 2072 clusters with 20 clusters populated
# In stage 29: transferred 2058 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# thanks lol
# moderator racist way report report proof way
# report
# user
# yourhighlights
#
# Topic 1: Sample Messages for Review
# limit time day
# btw hammersbattlehammerswarhammers character hand
# everyone reminder gallery style showcase community game game tag
# depth bug stripe button file
# limit
#
# Topic 2: Sample Messages for Review
# feature list
# prompt
# imagine command prompt
# look deletedchannel
# rookie channel command imagine link prompt
#
# Topic 3: Sample Messages for Review
# practice result
# prompt command
# guy link word link sbwrun
# space prompt prompt
# problem
#
# Topic 4: Sample Messages for Review
# ricrkoll
# share friend list artist name style information youtube promptdiscussion style people
# yes style
# reference character sketch
# description
#
# Topic 5: Sample Messages for Review
# right
# word inappropriate annoying
# christmas guy
# problem thanks
# user role mod
#
# Topic 6: Sample Messages for Review
# bot
# way willow result dalle quality
# nvm body mod care
# thanks course answer confusing
# thanks
#
# Topic 7: Sample Messages for Review
# idk
# stuff cool
# stuff ngl
# fect
# cool pretty imagination blank anything lol ill
#
# Topic 8: Sample Messages for Review
# click bluewillow bot unblock
# quin
# handle
# invite role something
# rush
#
# Topic 9: Sample Messages for Review
# rank
# bot issue calm
# bot level
# dragon
# bot
#
# Topic 10: Sample Messages for Review
# working
# phone
# start
# ri8
# bot
#
# Topic 11: Sample Messages for Review
# import
# detail thanks feedback detail
# thunderfury blade windseeker sword world warcraft male assassin rogue shadow body cloak dark
# httpsdaocentralcomdaonostalgiafbclidpaaaa8gfaefrl67rxcw3p9gnxpymfvwvk7vpv6h16xqodknbt9tl0lsor3aqu answer dao
# detail picturei searche forest animal
#
# Topic 12: Sample Messages for Review
# result specific
# mod something bot pls
# yes something update
# hello instruction
# tree
#
# Topic 13: Sample Messages for Review
# cat girl hand foot kind hairy spaghetti face photorealistic
# sarrailh
# thirdparty site processing request
# detail
# click version click copy address example almond color image2image httpsdiscordcomchannels104697930454795472810634999027531776901065534523862958160
#
# Topic 14: Sample Messages for Review
# alot
# something anytime idea bit sus
# wording term side term state facebook deviantart etc
# symbol language keyboard font right space
# tree
#
# Topic 15: Sample Messages for Review
# computer haha
# software quality time
# dalles
# home
# speak software time
#
# Topic 16: Sample Messages for Review
# vivian
# body
# generator textbook
# try keywords
# computer
#
# Topic 17: Sample Messages for Review
# creation
# program sfw
# bot
# look
# nothing wrong
#
# Topic 18: Sample Messages for Review
# tool
# feel art
# tool
# art
# sound
#
# Topic 19: Sample Messages for Review
# share link
# mod
# guy link bot
# bird name
# click name drop menu invite people
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 127968 (\N{HOUSE BUILDING}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-0f28636a53e4>:104: UserWarning: Glyph 65073 (\N{PRESENTATION FORM FOR VERTICAL EM DASH}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_r_StableDiffusion - SD Main - general [1031106064776712226] (2022-12-01 to 2023-02-01)_anonymized.csv
# In stage 0: transferred 4714 clusters with 20 clusters populated
# In stage 1: transferred 4011 clusters with 20 clusters populated
# In stage 2: transferred 3646 clusters with 20 clusters populated
# In stage 3: transferred 3482 clusters with 20 clusters populated
# In stage 4: transferred 3361 clusters with 20 clusters populated
# In stage 5: transferred 3340 clusters with 20 clusters populated
# In stage 6: transferred 3296 clusters with 20 clusters populated
# In stage 7: transferred 3277 clusters with 20 clusters populated
# In stage 8: transferred 3128 clusters with 20 clusters populated
# In stage 9: transferred 3166 clusters with 20 clusters populated
# In stage 10: transferred 3148 clusters with 20 clusters populated
# In stage 11: transferred 3128 clusters with 20 clusters populated
# In stage 12: transferred 3135 clusters with 20 clusters populated
# In stage 13: transferred 3084 clusters with 20 clusters populated
# In stage 14: transferred 3130 clusters with 20 clusters populated
# In stage 15: transferred 3110 clusters with 20 clusters populated
# In stage 16: transferred 3059 clusters with 20 clusters populated
# In stage 17: transferred 3106 clusters with 20 clusters populated
# In stage 18: transferred 3071 clusters with 20 clusters populated
# In stage 19: transferred 3073 clusters with 20 clusters populated
# In stage 20: transferred 3118 clusters with 20 clusters populated
# In stage 21: transferred 3027 clusters with 20 clusters populated
# In stage 22: transferred 2990 clusters with 20 clusters populated
# In stage 23: transferred 3040 clusters with 20 clusters populated
# In stage 24: transferred 3076 clusters with 20 clusters populated
# In stage 25: transferred 3077 clusters with 20 clusters populated
# In stage 26: transferred 3067 clusters with 20 clusters populated
# In stage 27: transferred 3043 clusters with 20 clusters populated
# In stage 28: transferred 3037 clusters with 20 clusters populated
# In stage 29: transferred 3043 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# ofen resolution
# dam upscaling lot
# option condition difference sampler something option fluctuation background reason window gpu time
# setting choice aprox something
# fix
#
# Topic 1: Sample Messages for Review
# book jackass code syntax language people everything idiot everything
# mess letter word coherent meaning lot noise medium goal language
# time
# picklesenor
# hassle inconvenience scraper traffic footprint scraper human
#
# Topic 2: Sample Messages for Review
# anyone bit toss webuiuser
# section auto people chat home people
# problem people something
# commits
# guide
#
# Topic 3: Sample Messages for Review
# dpm2 sampler
# press inspiring launch alchemist expectation expectation battlemage corner leap alchemist shortcoming key sprint face wall time lead
# life upscales type tab lot resolution detail process time time resource
# halill mod
# computer
#
# Topic 4: Sample Messages for Review
# artist
# people
# idea
# fine till
# knollingcase imo
#
# Topic 5: Sample Messages for Review
# anyone detail beautify element
# lawsuit meta suit metas department provider practice
# practice build process
# alright
# stability multiple
#
# Topic 6: Sample Messages for Review
# someone
# automatic1111 life
# tensorflow
# someone life
# day way prompt chaos text anyone something extension
#
# Topic 7: Sample Messages for Review
# rabbit hole specific
# guild
# cargo cult effect
# way
# anyone anyone inversion output concept finger eye vocab inversion vocab hidden output quality junky combination negative
#
# Topic 8: Sample Messages for Review
# well
# sick
# code core conversion overhead performance loss core core conversion
# rocm gpus accelerator driver linux
# pytorch xformers version answer
#
# Topic 9: Sample Messages for Review
# crap
# aws cost gpu provider lol
# amd nvidia room tyrion lannister mountain fist figg
# shenanigan evga bankruptcy shit nothing beat performance seamlessnessbut card reason k80s circle cuda cake hypocritical product instance cloud cut cloud instance instance month money
# reason quadro tesla towards corporation research university budget instance blessing cursethey compute time gpu compute monopoly cloud provider business bat eye quadro a100 multiple datacenter
#
# Topic 10: Sample Messages for Review
# megagrid upscalers way quality format
# hahaha post resource look
# let example step img2img console progress
# option knowledge
# artstation intern layer psd label
#
# Topic 11: Sample Messages for Review
# anyone crash sketch
# file internet gon
# anyone
# inversion embeddings file filename prompt hypernetworks file training
# work degree
#
# Topic 12: Sample Messages for Review
# community something line
# install extension purpose command line utility library stuff command line stuff
# spaceship generalization
# message command line embeddings bin file file
# tryign webui easyinstaller
#
# Topic 13: Sample Messages for Review
# update
# thanks
# advice
# extension
# launcher way way
#
# Topic 14: Sample Messages for Review
# author extension
# exemple way
# anythingv3 vae
# checkpoint
# hell
#
# Topic 15: Sample Messages for Review
# sample highsat opacity middlegray
# sample post
# img2img something anyone
# garbage
# set
#
# Topic 16: Sample Messages for Review
# variant training inversion hypernetworks training scroll bottom axis option select hypernetwork atm megagrid none anime_3 difference support hypernetworks furry others
# example data set test embedding
# anything exif
# month grid lexica time grid
# stability lot base
#
# Topic 17: Sample Messages for Review
# style look prompt brush stroke edges13 brush stroke look
# style lighting term term lighting contrast lighting
# yep parameter street f14 square film portrait hair pose composition cartoon art limb color sketch repetitive hand signature text color step cfg scale seed size hash
# collab
# photorealism
#
# Topic 18: Sample Messages for Review
# analogy
# embed architecture etc
# part art community level anti art people side
# follower artist dustup look
# storm lot power outage water pipe death
#
# Topic 19: Sample Messages for Review
# ban
# mod serv admin responsibility
# ipmy port userpass prompt ill
# gorge washinmachine
# ban
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_r_StableDiffusion - SD Main - general [1031106064776712226] (2024-01-01 to 2024-03-01)_anonymized.csv
# In stage 0: transferred 3151 clusters with 20 clusters populated
# In stage 1: transferred 2613 clusters with 20 clusters populated
# In stage 2: transferred 2431 clusters with 20 clusters populated
# In stage 3: transferred 2365 clusters with 20 clusters populated
# In stage 4: transferred 2328 clusters with 20 clusters populated
# In stage 5: transferred 2307 clusters with 20 clusters populated
# In stage 6: transferred 2278 clusters with 20 clusters populated
# In stage 7: transferred 2216 clusters with 20 clusters populated
# In stage 8: transferred 2182 clusters with 20 clusters populated
# In stage 9: transferred 2193 clusters with 20 clusters populated
# In stage 10: transferred 2142 clusters with 20 clusters populated
# In stage 11: transferred 2191 clusters with 20 clusters populated
# In stage 12: transferred 2213 clusters with 20 clusters populated
# In stage 13: transferred 2204 clusters with 20 clusters populated
# In stage 14: transferred 2252 clusters with 20 clusters populated
# In stage 15: transferred 2180 clusters with 20 clusters populated
# In stage 16: transferred 2162 clusters with 20 clusters populated
# In stage 17: transferred 2183 clusters with 20 clusters populated
# In stage 18: transferred 2164 clusters with 20 clusters populated
# In stage 19: transferred 2178 clusters with 20 clusters populated
# In stage 20: transferred 2188 clusters with 20 clusters populated
# In stage 21: transferred 2178 clusters with 20 clusters populated
# In stage 22: transferred 2136 clusters with 20 clusters populated
# In stage 23: transferred 2153 clusters with 20 clusters populated
# In stage 24: transferred 2152 clusters with 20 clusters populated
# In stage 25: transferred 2124 clusters with 20 clusters populated
# In stage 26: transferred 2144 clusters with 20 clusters populated
# In stage 27: transferred 2157 clusters with 20 clusters populated
# In stage 28: transferred 2123 clusters with 20 clusters populated
# In stage 29: transferred 2181 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# step
# something adapter
# ipadapter anime faceid nonanime
# try
# controlnet hand mesh fixer img2img photoreal hand way inpainting controlnets
#
# Topic 1: Sample Messages for Review
# clue
# right
# guy httpsyoutubemkxt0kxd5c0t409 timestamp point
# anybody dwpose age everything
# supercomputer gosh supercomputer send rtx series
#
# Topic 2: Sample Messages for Review
# reality check lot player training inference cost
# thanks screenshot
# stuff
# price
# sdxl track mean lot anything lot capability
#
# Topic 3: Sample Messages for Review
# thanks checkpoint folder
# anyone
# frame base
# xadapter controlnets loras checkpoint
# lady gentleman sdxl quality legacy sdxl
#
# Topic 4: Sample Messages for Review
# abomination
# vae
# nvidia cpu
# matter though option
# beat mistake brain
#
# Topic 5: Sample Messages for Review
# tool crop face faceswaplab
# anyone couple webui comfy
# foooocus thyeve system prompt detail kind lot prompt processing scene prompt comfy fooocus attempt something end way
# anime studio
# bard
#
# Topic 6: Sample Messages for Review
# character civitai art test checkpoint loras vision something dream
# explicity vae
# nickname check
# look estimation loss anything discussion anything speedflexibility httpsgithubcomkohyasssdscriptspull889
# marvel leto
#
# Topic 7: Sample Messages for Review
# strange multimode result setting result outcome result others web result time attempt seed etc
# braindead
# wait arrives
# rule software
# node
#
# Topic 8: Sample Messages for Review
# factorio
# understanding
# background play random background bunch object place
# anyone architecture stuff
# way halfbody woman viewer photograph resolution highdefinition clarity vibrant color saturation texture quality focus fidelity depth field truetolife range immaculate composition precision quality sharpness contrast definition perfection detail prompt resolution blurry detail lowdefinition grainy color texture focus fidelity range composition quality sharpness contrast definition quality detail
#
# Topic 9: Sample Messages for Review
# error time beginner answer a111 comfyui plugin matter time error
# anyone
# prompting latents case latents spot prompt
# python dependency hell comer
# impl core
#
# Topic 10: Sample Messages for Review
# merging
# state dreamshaper merge
# anyone run docker container dockerfiles dependency problem
# python version suspect syrup
# lemonparty
#
# Topic 11: Sample Messages for Review
# a1111 vae none
# controlnet webui extension
# dev version webuiuserbat
# issue
# someone plugandplay solution version
#
# Topic 12: Sample Messages for Review
# limb
# something flow algorithm
# chatgpt copillot scripting
# resource someone custom artwork motion visuals example httpswwwyoutubecomwatchvg8yx1jfq8k4
# basic comfyui
#
# Topic 13: Sample Messages for Review
# dunno
# reddit bot httpswwwredditcomuserstablehorde ticket httpslemmydbzer0compost13211160
# reddit
# similarity
# example onpage tool
#
# Topic 14: Sample Messages for Review
# cig
# keyframes
# anyone guide tensorrt automatic1111s
# time tiling option
# system package
#
# Topic 15: Sample Messages for Review
# controlnets phone
# difference amateur cover blanked whip fucker blanket
# complication
# character animation training data rig match
# space let
#
# Topic 16: Sample Messages for Review
# idea outfit
# name
# blip2
# none
# scamstore httpschatopenaicomgpts
#
# Topic 17: Sample Messages for Review
# repd hoax
# haha boomer
# show head tail
# download htis prefix name
# nitrowhore
#
# Topic 18: Sample Messages for Review
# position couple
# anyone bulk opposition
# practice tile asset
# way nevernedingdream
# tutorial json
#
# Topic 19: Sample Messages for Review
# people reddit
# someone bit
# nope
# youtube channel creation interaction
# back
