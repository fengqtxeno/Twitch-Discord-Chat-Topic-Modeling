# %%
# !pip install git+https://github.com/rwalk/gsdmm.git
# !pip install nltk spacy gensim pyLDAvis networkx
# !pip install wordcloud

import os
import pandas as pd
import numpy as np
import re
import random
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import pos_tag
import nltk
import spacy
import gensim
from gsdmm import MovieGroupProcess
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pyLDAvis.gensim_models as gensimvis
import networkx as nx
from collections import Counter
from itertools import combinations

# Load Spacy's English model for Named Entity Recognition
nlp = spacy.load("en_core_web_sm")

# Mount Google Drive to access the dataset stored there
from google.colab import drive
drive.mount('/content/drive')

# Download necessary NLTK resources for tokenization and POS tagging
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

general_stopwords = {
    'would', 'could', 'should', 'might', 'must', 'will', 'shall', 'can', 'may', 'wouldn', 'couldn', 'shouldn',
    'mightn', 'mustn', 'won', 'shan', 'can', 'mayn', 'just', 'don', 'didn', 'doesn', 'aren', 'isn', 'wasn',
    'weren', 'hasn', 'haven', 'hadn', 'does', 'did', 'don', 'does', 'did', 'don', 'now', 'then', 'once',
    'after', 'before', 'since', 'during', 'while', 'until', 'ago', 'yet', 'still', 'even', 'ever', 'always',
    'never', 'sometimes', 'often', 'usually', 'again', 'too', 'also', 'only', 'really', 'very', 'much',
    'more', 'most', 'many', 'several', 'few', 'some', 'any', 'each', 'every', 'all', 'both', 'either',
    'neither', 'anyone', 'everyone', 'someone', 'nobody', 'noone', 'nothing', 'anything', 'something',
    'everything', 'another', 'such', 'one', 'two', 'three', 'first', 'second', 'third', 'next', 'last',
    'same', 'other', 'different', 'new', 'old', 'young', 'long', 'short', 'high', 'low', 'large', 'small'
}

# Combine all sets of stop words
stop_words = set(stopwords.words('english')) | general_stopwords

# Define the preprocessing function
def preprocess(text):
    lemmatizer = WordNetLemmatizer()
    # Remove all non-word characters and lower the text
    text = re.sub(r'[^\w\s]', '', text.lower())
    # Split text into tokens
    tokens = text.split()
    # Apply NER to remove usernames and named entities
    doc = nlp(' '.join(tokens))
    tokens = [token.text for token in doc if not token.ent_type_]
    # POS 的位置提前了，本来在最后
    # Retain only nouns as they are significant for topic identification
    nouns = [word for word, pos in pos_tag(tokens) if pos.startswith('NN')]
    # 筛选本来 lemmatize 和 len(word) > 2 是在同一行的，有可能 lemmatize 之后 word length 小于 2，所以这里把长度筛选放在后面了
    # Lemmatize tokens and remove stop words and short words
    nouns = [lemmatizer.lemmatize(word) for word in nouns]
    nouns = [word for word in nouns if word not in stop_words and len(word) > 2]
    return nouns

# Function to load and preprocess data from CSV files
def load_data(file_path):
    df = pd.read_csv(file_path)
    df['preprocessed'] = df['Content'].apply(preprocess)
    return df['preprocessed'].tolist()

# Path to the folder containing the dataset
folder_path = '/content/drive/My Drive/Discord dataset/Cleaned data/'
file_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.csv')]

# Function to randomly select messages from each topic for manual review
def random_message_selection(docs, cluster_assignments, num_samples=5):
    topics = set(cluster_assignments)
    for topic_id in topics:
        topic_docs = [doc for i, doc in enumerate(docs) if cluster_assignments[i] == topic_id]
        sampled_messages = random.sample(topic_docs, min(len(topic_docs), num_samples))
        print(f"\nTopic {topic_id}: Sample Messages for Review")
        for message in sampled_messages:
            print(' '.join(message))

# Function to save plots to a PDF
from matplotlib.backends.backend_pdf import PdfPages

def save_plots_to_pdf(file_path, cluster_word_distribution, top_clusters):
    pdf_file_name = f'{os.path.basename(file_path)}_report.pdf'
    with PdfPages(pdf_file_name) as pdf:
        for topic_id in top_clusters:
            # Word cloud
            topic_words = cluster_word_distribution[topic_id]
            wordcloud = WordCloud(background_color='white', width=800, height=400).generate_from_frequencies(topic_words)
            plt.figure(figsize=(10, 5))
            plt.imshow(wordcloud, interpolation='bilinear')
            plt.title(f"Topic {topic_id} Word Cloud for {os.path.basename(file_path)}")
            plt.axis("off")
            pdf.savefig()
            plt.close()

            # Bar chart
            sorted_topic_words = dict(sorted(topic_words.items(), key=lambda item: item[1], reverse=True)[:10])
            plt.figure(figsize=(10, 5))
            plt.bar(sorted_topic_words.keys(), sorted_topic_words.values())
            plt.title(f"Top Words in Topic {topic_id}")
            plt.xticks(rotation=45)
            pdf.savefig()
            plt.close()

            # Network graph
            words = list(sorted_topic_words.keys())
            word_pairs = list(combinations(words, 2))
            G = nx.Graph()
            G.add_edges_from(word_pairs)
            pos = nx.spring_layout(G)
            plt.figure(figsize=(10, 5))
            nx.draw(G, pos, with_labels=True, node_size=50, font_size=10, edge_color='grey')
            plt.title(f"Word Co-occurrence Network for Topic {topic_id}")
            pdf.savefig()
            plt.close()

    return pdf_file_name

# Process each file, perform topic modeling, and generate visualizations
for file_path in file_paths:
    print(f"Processing file: {file_path}")
    docs = load_data(file_path)
    # Remove any empty documents resulting from preprocessing
    docs = [doc for doc in docs if doc]

    if len(docs) > 0:
        # Create a dictionary of all words in documents
        dictionary = gensim.corpora.Dictionary(docs)
        # Remove extremes to focus on relevant words only
        dictionary.filter_extremes(no_below=10, no_above=0.5, keep_n=10000)
        vocab_length = len(dictionary)

        if vocab_length == 0:
            print("No vocabulary available after filtering extremes. Skipping.")
            continue

        # Initialize and fit GSDMM model
        mgp = MovieGroupProcess(K=20, alpha=0.1, beta=0.3, n_iters=30)
        y = mgp.fit(docs, vocab_length)

        # Get cluster assignments and cluster word distributions
        cluster_assignments = y
        cluster_word_distribution = mgp.cluster_word_distribution

        # Random message selection for validation
        random_message_selection(docs, cluster_assignments)

        # Generate and display word clouds for each of the top 5 topics
        sorted_clusters = sorted(range(len(mgp.cluster_doc_count)), key=lambda k: mgp.cluster_doc_count[k], reverse=True)
        top_clusters = sorted_clusters[:5]

        # Save plots to PDF
        pdf_file_name = save_plots_to_pdf(file_path, cluster_word_distribution, top_clusters)

        # Provide a download link for the PDF file
        from google.colab import files
        files.download(pdf_file_name)
# Out:
# Collecting git+https://github.com/rwalk/gsdmm.git
#   Cloning https://github.com/rwalk/gsdmm.git to /tmp/pip-req-build-i0bymqci
#   Running command git clone --filter=blob:none --quiet https://github.com/rwalk/gsdmm.git /tmp/pip-req-build-i0bymqci
#   Resolved https://github.com/rwalk/gsdmm.git to commit 4ad1b6b6976743681ee4976b4573463d359214ee
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gsdmm==0.1) (1.26.4)
# Building wheels for collected packages: gsdmm
#   Building wheel for gsdmm (setup.py) ... done
#   Created wheel for gsdmm: filename=gsdmm-0.1-py3-none-any.whl size=4586 sha256=86953b50deea9a78fe1cafba1e474461e188dfb5cb72007840b3729dae9b9271
#   Stored in directory: /tmp/pip-ephem-wheel-cache-38vxg046/wheels/da/d3/6e/a612d7cff0fcfb6470b8c113fc04931ecffb466ac19b9c5f3c
# Successfully built gsdmm
# Installing collected packages: gsdmm
# Successfully installed gsdmm-0.1
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.6)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.4.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.1.4)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.10.1)
# Collecting funcy (from pyLDAvis)
#   Downloading funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.3.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 20.7 MB/s eta 0:00:00
# Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-2.0 pyLDAvis-3.4.1
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Mounted at /content/drive
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_Midjourney - Chat - discussion [938713143759216720] (2022-01-01 to 2022-07-01)_anonymized.csv
# In stage 0: transferred 55813 clusters with 20 clusters populated
# In stage 1: transferred 50727 clusters with 20 clusters populated
# In stage 2: transferred 46003 clusters with 20 clusters populated
# In stage 3: transferred 41499 clusters with 20 clusters populated
# In stage 4: transferred 38730 clusters with 20 clusters populated
# In stage 5: transferred 37215 clusters with 20 clusters populated
# In stage 6: transferred 35922 clusters with 20 clusters populated
# In stage 7: transferred 35131 clusters with 20 clusters populated
# In stage 8: transferred 34125 clusters with 20 clusters populated
# In stage 9: transferred 33852 clusters with 20 clusters populated
# In stage 10: transferred 33637 clusters with 20 clusters populated
# In stage 11: transferred 33466 clusters with 20 clusters populated
# In stage 12: transferred 33182 clusters with 20 clusters populated
# In stage 13: transferred 33004 clusters with 20 clusters populated
# In stage 14: transferred 32775 clusters with 20 clusters populated
# In stage 15: transferred 32477 clusters with 20 clusters populated
# In stage 16: transferred 32348 clusters with 20 clusters populated
# In stage 17: transferred 32400 clusters with 20 clusters populated
# In stage 18: transferred 32279 clusters with 20 clusters populated
# In stage 19: transferred 32428 clusters with 20 clusters populated
# In stage 20: transferred 32232 clusters with 20 clusters populated
# In stage 21: transferred 32418 clusters with 20 clusters populated
# In stage 22: transferred 32242 clusters with 20 clusters populated
# In stage 23: transferred 32146 clusters with 20 clusters populated
# In stage 24: transferred 32252 clusters with 20 clusters populated
# In stage 25: transferred 32214 clusters with 20 clusters populated
# In stage 26: transferred 32352 clusters with 20 clusters populated
# In stage 27: transferred 32310 clusters with 20 clusters populated
# In stage 28: transferred 32042 clusters with 20 clusters populated
# In stage 29: transferred 31817 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# time business model
# note guide project blockchain royalty revenue
# thank
# problem license world subscriber fee picture business
# issue artist
#
# Topic 1: Sample Messages for Review
# thing fun hell
# list people
# favorite attempt putrid eldritch energy salad
# thing haha
# time
#
# Topic 2: Sample Messages for Review
# canvas machine
# stop prompt number piece text example burger1 bun burger cheese focus image
# grey mountain grass
# photo painting style photo mjs output problem
# mangolfingcackeypantshuge sunny giantmysteriousrocks
#
# Topic 3: Sample Messages for Review
# server
# computer age amount compute
# glad
# people hour
# devs user credit day
#
# Topic 4: Sample Messages for Review
# artist style
# run commandline
# people result people word phrase result sense
# level realism
# strange setting chimp
#
# Topic 5: Sample Messages for Review
# reminds
# shirt
# filter dataset tbh
# multiple issue dog command end order matter rest
# nude
#
# Topic 6: Sample Messages for Review
# pin portrait sultry job
# octane photograph
# imagine promptlandscape matte artstation work
# engine octane render post processing vfx particle end prompt
# lit
#
# Topic 7: Sample Messages for Review
# table
# ship compass
# emoji emoji
# shift cowboy town
# cringe life deciison
#
# Topic 8: Sample Messages for Review
# character people chaste succubus
# consistancy frame
# outcome
# suggestion sideview face etc thanks
# portrait type shot face
#
# Topic 9: Sample Messages for Review
# haha sorry daniel
# notice
# damnit lol
# list lol
# yes
#
# Topic 10: Sample Messages for Review
# artist copying stuff trouble artist tool
# client director artist direction dream
# gtx lol
# merit
# understand perk
#
# Topic 11: Sample Messages for Review
# bot hyperlink expires
# subject shade unsure bot
# trial gpus end google collabs
# question work discord channel
# subtle
#
# Topic 12: Sample Messages for Review
# upscaler
# thing colabpython bunch job params tooling queue
# gotcha sense pixelart part example work auto pixelart prompt upscaling
# prefer root preference setting auto_dm suffix
# point
#
# Topic 13: Sample Messages for Review
# esrgan others
# test mixed photoshop branch
# manga artbooks internet archive
# version filter stuff
# wording service
#
# Topic 14: Sample Messages for Review
# front side
# feeling system
# lol people rating
# stuff
# user interface error video handson review user prep
#
# Topic 15: Sample Messages for Review
# way model public
# domain thing
# search tutorial youtube init image
# model midjourney clip
# touch
#
# Topic 16: Sample Messages for Review
# user style image newclip command
# video
# url prompt
# selection end variation thread
# prompt potential
#
# Topic 17: Sample Messages for Review
# story heard lot animal eye
# people longass paragraph story
# workout mind way taste
# blood
# case music guitar
#
# Topic 18: Sample Messages for Review
# discord community call guy ability tree variant
# dumb time people
# trouble concept
# kind art baesd math
# lot video motiongrapher pleasure
#
# Topic 19: Sample Messages for Review
# question prompt bot channel return
# permission haha
# channel set peopel discord
# cachecontrol header webp file filename maxage604800
# yes reply work bot work discord user
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_PromptHero - PromptHero - 🗨│general [1030178486398234684] (2022-10-13 to 2023-01-01)_anonymized.csv
# In stage 0: transferred 735 clusters with 20 clusters populated
# In stage 1: transferred 623 clusters with 20 clusters populated
# In stage 2: transferred 611 clusters with 20 clusters populated
# In stage 3: transferred 564 clusters with 20 clusters populated
# In stage 4: transferred 552 clusters with 20 clusters populated
# In stage 5: transferred 560 clusters with 20 clusters populated
# In stage 6: transferred 553 clusters with 20 clusters populated
# In stage 7: transferred 569 clusters with 20 clusters populated
# In stage 8: transferred 559 clusters with 20 clusters populated
# In stage 9: transferred 561 clusters with 20 clusters populated
# In stage 10: transferred 545 clusters with 20 clusters populated
# In stage 11: transferred 557 clusters with 20 clusters populated
# In stage 12: transferred 554 clusters with 20 clusters populated
# In stage 13: transferred 557 clusters with 20 clusters populated
# In stage 14: transferred 536 clusters with 20 clusters populated
# In stage 15: transferred 566 clusters with 20 clusters populated
# In stage 16: transferred 524 clusters with 20 clusters populated
# In stage 17: transferred 551 clusters with 20 clusters populated
# In stage 18: transferred 540 clusters with 20 clusters populated
# In stage 19: transferred 541 clusters with 20 clusters populated
# In stage 20: transferred 535 clusters with 20 clusters populated
# In stage 21: transferred 553 clusters with 20 clusters populated
# In stage 22: transferred 545 clusters with 20 clusters populated
# In stage 23: transferred 547 clusters with 20 clusters populated
# In stage 24: transferred 524 clusters with 20 clusters populated
# In stage 25: transferred 544 clusters with 20 clusters populated
# In stage 26: transferred 552 clusters with 20 clusters populated
# In stage 27: transferred 521 clusters with 20 clusters populated
# In stage 28: transferred 539 clusters with 20 clusters populated
# In stage 29: transferred 569 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# hello guy newbie fall parachute world art prompthero lot site
# sometime
# bag invention source crowd
# prompt
# lot sharing
#
# Topic 1: Sample Messages for Review
# model aspect
# shelf
# option oprions
# option model cute anime girl fox hat k_euler_a
# timeouts internet
#
# Topic 2: Sample Messages for Review
# ckpt mode
# threat
# whirl
# guy invokeai idea
# magic right
#
# Topic 3: Sample Messages for Review
# reddit people art case
# indepth freedom combination layer aspect
# guy inversion httpswwwyoutubecomwatchv4e459tlwquut251s
# thing
# artist life
#
# Topic 4: Sample Messages for Review
# correct time
# model people midjourney
# community openjourney
# model openjourney token
# access introduction
#
# Topic 5: Sample Messages for Review
# factor mine
# factor image quality
# mind core image prompt word quality people resolution image order feature resolution image user webpage choice opinion base platform
# resource
# power internet
#
# Topic 6: Sample Messages for Review
# scanner process function call signal
# haha a1111 feature day bit time
# strange image file look
# launch args use xformers memory issue xformers time tho
# a1111
#
# Topic 7: Sample Messages for Review
# ergonomy feature erazer mask job
# interesting stuff
# prompt cfg seed resolution model sample option result
# gui
# model resolution
#
# Topic 8: Sample Messages for Review
# thanks
# seed pic prompt place
# prompt way
# yoda graffiti haha
# threat possibility download link popup user
#
# Topic 9: Sample Messages for Review
# javierjrueda rameerez prompthero answer user prompt fact username prompt online midjourney
# run place seed
# rameerez prompthero
# outpaint sutff gui
# rachey13x love frontpage prompt background cool
#
# Topic 10: Sample Messages for Review
# config line model
# model
# folder model text file
# diffuser
# app
#
# Topic 11: Sample Messages for Review
# yeah artroomai click install
# work devs platform figure
# difference mac window
# face restoration guess gpu pic
# dunno gui
#
# Topic 12: Sample Messages for Review
# model woman
# news point article edge image browser httpsopenaicomblogdalleapinowavailableinpublicbeta
# discord community glad news
# module
# ran news stability model link transcript emad discord httpswwwredditcomrstablediffusioncommentsy2dinkcommentis32y1d
#
# Topic 13: Sample Messages for Review
# pressure diffusion project
# news training data
# imagine doctor surgeon work material
# work
# request digging diffusion
#
# Topic 14: Sample Messages for Review
# thanksgiving share art artsubmission laugh others
# head artsubmission art vote prompthero_icon
# hello art challenge check challengeinfo
# face model check
# thank
#
# Topic 15: Sample Messages for Review
# yes comunity nudity
# way tag control time prompt
# rachey13x prompt
# way model site prompt image lookstyle prompt time reserve image google search prompt job prompt support community
# animation
#
# Topic 16: Sample Messages for Review
# sampler step image
# softwareappprogramwebsite image
# yeah prompt
# process
# prompt result
#
# Topic 17: Sample Messages for Review
# work
# question model result seed dreambooth facesobjects style keywordstokens case
# room otter
# hmm huggingface site boo
# gon mdjrny stuff
#
# Topic 18: Sample Messages for Review
# none
# exists
# prompt
# sorry thing
# yes sampler
#
# Topic 19: Sample Messages for Review
# whiner artist nsfw database
# image
# hmm
# copyright license individual freetorights content
# video detail diffusion breakdown image lot artist celebrity content stabilityai issue mindset video game developer base model model mod video game company userscustomers model bethesda game player game httpswwwyoutubecomwatchvx_r9jj8mszk
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 128488 (\N{LEFT SPEECH BUBBLE}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_Maze Guru - AI Art, Anime & Social - Chat - 💬｜english-discussion [1037291441434677268] (2024-01-01 to 2024-03-01)_anonymized.csv
# In stage 0: transferred 315 clusters with 20 clusters populated
# In stage 1: transferred 273 clusters with 20 clusters populated
# In stage 2: transferred 259 clusters with 20 clusters populated
# In stage 3: transferred 263 clusters with 20 clusters populated
# In stage 4: transferred 253 clusters with 20 clusters populated
# In stage 5: transferred 264 clusters with 20 clusters populated
# In stage 6: transferred 256 clusters with 20 clusters populated
# In stage 7: transferred 246 clusters with 20 clusters populated
# In stage 8: transferred 261 clusters with 20 clusters populated
# In stage 9: transferred 251 clusters with 20 clusters populated
# In stage 10: transferred 258 clusters with 20 clusters populated
# In stage 11: transferred 262 clusters with 20 clusters populated
# In stage 12: transferred 284 clusters with 20 clusters populated
# In stage 13: transferred 262 clusters with 20 clusters populated
# In stage 14: transferred 253 clusters with 20 clusters populated
# In stage 15: transferred 259 clusters with 20 clusters populated
# In stage 16: transferred 251 clusters with 20 clusters populated
# In stage 17: transferred 255 clusters with 20 clusters populated
# In stage 18: transferred 255 clusters with 20 clusters populated
# In stage 19: transferred 257 clusters with 20 clusters populated
# In stage 20: transferred 237 clusters with 20 clusters populated
# In stage 21: transferred 244 clusters with 20 clusters populated
# In stage 22: transferred 253 clusters with 20 clusters populated
# In stage 23: transferred 256 clusters with 20 clusters populated
# In stage 24: transferred 247 clusters with 20 clusters populated
# In stage 25: transferred 257 clusters with 20 clusters populated
# In stage 26: transferred 243 clusters with 20 clusters populated
# In stage 27: transferred 246 clusters with 20 clusters populated
# In stage 28: transferred 244 clusters with 20 clusters populated
# In stage 29: transferred 247 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# gong warhead nose warhead pilot
# hit beginning
# use seed image
# jus issue mine
# twitter query support hail
#
# Topic 1: Sample Messages for Review
# web version
# lol
# yes
# googleimagen
# server member reward
#
# Topic 2: Sample Messages for Review
# thank result bigtime reason kid
# heard admins point
# thread
# dang dalle lot word
# choir list word way mod radio silence agape person time trash
#
# Topic 3: Sample Messages for Review
# time
# improvement keywords
# cat andd shart bull idk guess striker
# eat point try genderless android porn genderless fact
# earth people image folk lol thing weird
#
# Topic 4: Sample Messages for Review
# guide
# suggestion thought
# people bot server kind handful garbage spam row bit
# wait sora
# mean sora
#
# Topic 5: Sample Messages for Review
# style section style section
# look
# people credit
# contest membership
# hello dalee style level
#
# Topic 6: Sample Messages for Review
# point lot premium image image generation prompt month
# outburst
# web design
# point app website
# point
#
# Topic 7: Sample Messages for Review
# thanks head time time
# hey
# account
# discord
# newbie bot
#
# Topic 8: Sample Messages for Review
# website dimension image stylesmodels
# image newbie woman breast people hentai stuff
# image
# pedos weirdo image server damn
# thing case term agape intimate
#
# Topic 9: Sample Messages for Review
# none teeth teeth daemon waifu
# maze guru woah
# art image minute httpswwwyoutubecomwatchv7uryffyohec
# reference image image generator image reference
# snout wolf ear image
#
# Topic 10: Sample Messages for Review
# timeout error
# issue
# car
# issue post newbie benefit mod art platform support
# pedo
#
# Topic 11: Sample Messages for Review
# thank
# mean stuff bit newbie lol
# discord thread chat area newbie
# spamming discord attention brain
# coin account coin
#
# Topic 12: Sample Messages for Review
# video maze guru movie trailer chatgpt script chat gpt4 access star mission cut scene ship city laser people scene force scientist survivor communicate escape voiceover battle fate world cut scene brave hero leader hero power spirit cut title invasion invasion war lab scene music playing shadow earth narrator star force shot alien spacecraft panic chaos narrator humanity threat image leader crisis force civilian arrival narrator sky alliance fate world hang balance cut scene scientist technology group people threat narrator battle survival resilience humanity test montage action sequence explosion glimpse alien invader prepare invasion screen message narrator trailer shot spacecraft hovering city audience narrator
#
# Topic 13: Sample Messages for Review
# try
# example end degree head maze team line porn seed image worm word pornography porn default mode
# gidrakos newbie maze
# thank discussion maze look image result kind
# check head newbie child pornography end result
#
# Topic 14: Sample Messages for Review
# friend
# yes image sililarity setting
# video tool httpswwwyoutubecomwatchvdhxlliyw8s
# hey channel question image size example image please ping response
# hey text
#
# Topic 15: Sample Messages for Review
# mean
# job power ranger design helmet
# change speed
# tiger falcon
# treat
#
# Topic 16: Sample Messages for Review
# incorrect peace treaty goal palestine control amount land effort party state plenty majority peace majority palestine control palestine center universe zion time book name time torah
# zionism ideology palestine valley tigris river peace excuse power peace interest zionist peace part power subjugation party
# peace politic government destroyed resist zionist day sheikh jarrah neighborhood incident example weapon zionist stop army land settlement day day till
# day
# palestine weapon peace face
#
# Topic 17: Sample Messages for Review
# advice pls
# model
# region
# announcement httpsdiscordcomchannels100716691480143463410354724385338327141202511819437113364
# coin
#
# Topic 18: Sample Messages for Review
# thanks prize
# server
# post
# image
# thread
#
# Topic 19: Sample Messages for Review
# time reporting method user
# admins partnership beta rorotuck
# thanks response
# teeth
# guy report
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 65372 (\N{FULLWIDTH VERTICAL LINE}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_Maze Guru - AI Art, Anime & Social - Chat - 💬｜english-discussion [1037291441434677268] (2022-11-01 to 2023-04-01)_anonymized.csv
# In stage 0: transferred 1290 clusters with 20 clusters populated
# In stage 1: transferred 1043 clusters with 20 clusters populated
# In stage 2: transferred 1011 clusters with 20 clusters populated
# In stage 3: transferred 964 clusters with 20 clusters populated
# In stage 4: transferred 958 clusters with 20 clusters populated
# In stage 5: transferred 944 clusters with 20 clusters populated
# In stage 6: transferred 932 clusters with 20 clusters populated
# In stage 7: transferred 942 clusters with 20 clusters populated
# In stage 8: transferred 919 clusters with 20 clusters populated
# In stage 9: transferred 941 clusters with 20 clusters populated
# In stage 10: transferred 899 clusters with 20 clusters populated
# In stage 11: transferred 904 clusters with 20 clusters populated
# In stage 12: transferred 909 clusters with 20 clusters populated
# In stage 13: transferred 886 clusters with 20 clusters populated
# In stage 14: transferred 925 clusters with 20 clusters populated
# In stage 15: transferred 890 clusters with 20 clusters populated
# In stage 16: transferred 887 clusters with 20 clusters populated
# In stage 17: transferred 889 clusters with 20 clusters populated
# In stage 18: transferred 870 clusters with 20 clusters populated
# In stage 19: transferred 888 clusters with 20 clusters populated
# In stage 20: transferred 901 clusters with 20 clusters populated
# In stage 21: transferred 870 clusters with 20 clusters populated
# In stage 22: transferred 887 clusters with 20 clusters populated
# In stage 23: transferred 858 clusters with 20 clusters populated
# In stage 24: transferred 901 clusters with 20 clusters populated
# In stage 25: transferred 891 clusters with 20 clusters populated
# In stage 26: transferred 894 clusters with 20 clusters populated
# In stage 27: transferred 886 clusters with 20 clusters populated
# In stage 28: transferred 928 clusters with 20 clusters populated
# In stage 29: transferred 894 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# image team research upscalers
# resolution prompting
# project
# check lot
# dandelionmonster body rainbow color art horror art artgerm wlop studio ghibli fictionalization ralph steadman style fear sky photograph d750 intricate illustration hyperrealistic loraflowervirus_lora_2800steps55 flowervirus
#
# Topic 1: Sample Messages for Review
# size drawing
# prompt
# result
# idk prompt profile
# machine language model chatgpt
#
# Topic 2: Sample Messages for Review
# name share result
# image issue
# channel android model example fact picture function atm
# bit bummer
# centry
#
# Topic 3: Sample Messages for Review
# checkpoint flowervirus
# asol bother
# post gen
# noits join newbie maze suggestion
# congratulation win
#
# Topic 4: Sample Messages for Review
# wow maze guru app
# look permaban material
# dev
# diva
# hand lotion
#
# Topic 5: Sample Messages for Review
# username discord
# thanks
# sorry way
# employee game development company detail contact
# thanks awesome
#
# Topic 6: Sample Messages for Review
# truman install gpu computer
# stuff
# cool language
# time people girl study picture online browser girl symbol stuff
# btw
#
# Topic 7: Sample Messages for Review
# sorry server user server
# case midjourney
# case instruction
# variant
# perm issue server
#
# Topic 8: Sample Messages for Review
# maze grown punctuation folk generator
# community
# generator
# model disco diffusion implementation disco diffusion
# community diffusion generator product diffusion
#
# Topic 9: Sample Messages for Review
# server weeb
# please spam message deletedchannel
# app creativity subject input dragon output hulk
# situation
# gon
#
# Topic 10: Sample Messages for Review
# spam joke
# style use style style name
# proooooo
# message
# use command
#
# Topic 11: Sample Messages for Review
# power
# huh image blue
# bit criticism upscale feature image look issue image date
# sorry trouble
# httpsmazegurucreate app seed image
#
# Topic 12: Sample Messages for Review
# variation result
# thanks
# trial point
# prompt negative example right
# way prompt work
#
# Topic 13: Sample Messages for Review
# picture
# picture inspiration
# section
# picture
# person employee
#
# Topic 14: Sample Messages for Review
# hand handy thing human life time computer etc
# image consent artist
# lol flash mask suit
# hello style hypernetwork keywords
# model style artwork artwork artwork danbooru tag description
#
# Topic 15: Sample Messages for Review
# advice time winner image
# hand
# march event deletedchannel create hometown newbie post image link vote emoji image chance gift card
# announcement themewinner
# create newbie religion
#
# Topic 16: Sample Messages for Review
# credit let weird
# thing mind place collaboration admin
# artist art art generator artist point
# yes collaboration guru permission adminstaff part group art battle detail promote permission host battle admin course action part crew art generator art subprojects
# responsibility
#
# Topic 17: Sample Messages for Review
# progress variation image prompt discord bot
# morning
# please command newbie channel
# image type
# access ticket support channel need information function
#
# Topic 18: Sample Messages for Review
# story
# use esrgan site
# beam
# result
# yes bro
#
# Topic 19: Sample Messages for Review
# wifi result
# access model control controlnet
# prompt
# way funny
# morning
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 65372 (\N{FULLWIDTH VERTICAL LINE}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_👽 WOMBOVERSE 👽 - 《 👽》LOUNGE - 💬│general-chat [774124295524712480] (2024-01-01 to 2024-03-01)_anonymized.csv
# In stage 0: transferred 6712 clusters with 20 clusters populated
# In stage 1: transferred 5868 clusters with 20 clusters populated
# In stage 2: transferred 5356 clusters with 20 clusters populated
# In stage 3: transferred 5162 clusters with 20 clusters populated
# In stage 4: transferred 5057 clusters with 20 clusters populated
# In stage 5: transferred 4916 clusters with 20 clusters populated
# In stage 6: transferred 4884 clusters with 20 clusters populated
# In stage 7: transferred 4867 clusters with 20 clusters populated
# In stage 8: transferred 4869 clusters with 20 clusters populated
# In stage 9: transferred 4830 clusters with 20 clusters populated
# In stage 10: transferred 4831 clusters with 20 clusters populated
# In stage 11: transferred 4768 clusters with 20 clusters populated
# In stage 12: transferred 4770 clusters with 20 clusters populated
# In stage 13: transferred 4764 clusters with 20 clusters populated
# In stage 14: transferred 4765 clusters with 20 clusters populated
# In stage 15: transferred 4776 clusters with 20 clusters populated
# In stage 16: transferred 4710 clusters with 20 clusters populated
# In stage 17: transferred 4719 clusters with 20 clusters populated
# In stage 18: transferred 4748 clusters with 20 clusters populated
# In stage 19: transferred 4669 clusters with 20 clusters populated
# In stage 20: transferred 4687 clusters with 20 clusters populated
# In stage 21: transferred 4628 clusters with 20 clusters populated
# In stage 22: transferred 4665 clusters with 20 clusters populated
# In stage 23: transferred 4706 clusters with 20 clusters populated
# In stage 24: transferred 4643 clusters with 20 clusters populated
# In stage 25: transferred 4639 clusters with 20 clusters populated
# In stage 26: transferred 4653 clusters with 20 clusters populated
# In stage 27: transferred 4653 clusters with 20 clusters populated
# In stage 28: transferred 4662 clusters with 20 clusters populated
# In stage 29: transferred 4578 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# gene iirc sprout taste vile
# cap
# intelligence design hair lip mustache
# print local group story art
# loing
#
# Topic 1: Sample Messages for Review
# captn turtle
# coolguy
# point alpine_butterfly
# generate try
# end prompt flower person
#
# Topic 2: Sample Messages for Review
# luck
# bos bridge
# alpine butterfly
# kind stare woman
# sense circle
#
# Topic 3: Sample Messages for Review
# hey problem root cause subscriber service level service
# art prompt side valentine day version character shigemori story
# app prompt flower picture reason style human generation heather flower amount prompt difference symbol
# app
# format update
#
# Topic 4: Sample Messages for Review
# howmay
# image exchange money
# hard
# hammer
# question
#
# Topic 5: Sample Messages for Review
# face lol yeah goal
# nerve
# today
# brick wall disco drum beat
# sleep night
#
# Topic 6: Sample Messages for Review
# glad lost
# proceeds rain
# okc tulsa
# let muffin flavour wait
# doubt canvas time way wombot time
#
# Topic 7: Sample Messages for Review
# polite rearend kissing people difference
# love bone story
# captn toy leg breadshock
# captn fan cool breeze
# love death robot style
#
# Topic 8: Sample Messages for Review
# nsfw image
# illustration image
# yeah time pain butt
# thanks
# photo image share art
#
# Topic 9: Sample Messages for Review
# mod
# announcement
# devs thx
# hiccup tech team thing
# lou team dev team
#
# Topic 10: Sample Messages for Review
# breath
# work generation premium user wombot nsfw server ban nsfw room ban information click note march app generate content httpswombotai
# work generation premium user wombot nsfw server ban nsfw room ban information click note march app generate content httpswombotai
# app generate
# modmail need server
#
# Topic 11: Sample Messages for Review
# wombot
# decision role
# prompt
# right room
# pic bit sharing room
#
# Topic 12: Sample Messages for Review
# fiber ryebread elmoburn
# tribe wise man thank
# behave rightday
# uninstalling
# httpstenorcomviewkisse0b888e0b8b9e0b89agif27696365
#
# Topic 13: Sample Messages for Review
# thing thing style hdr werewolf
# evening
# snow
# thing
# folk day fur baby
#
# Topic 14: Sample Messages for Review
# video feature knowledge
# drama
# ping
# rip
# wassup
#
# Topic 15: Sample Messages for Review
# droid
# line connection dsl modem fine parent phone call
# mop doom
# dream incident witch lore
# cache
#
# Topic 16: Sample Messages for Review
# question room lol wait answer room
# option
# style
# way prompt style aspect number output image option user way enterreturn tab key
# wombot
#
# Topic 17: Sample Messages for Review
# art traitor
# image time
# modification home
# correct
# idea
#
# Topic 18: Sample Messages for Review
# medium
# app bot thing bit glitchy moment
# worry
# gen
# dahomey pigeon
#
# Topic 19: Sample Messages for Review
# grief potato
# word skyscraper
# hate man load head
# sorry issue aliendance
# prompt dream v3s saucy
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 128125 (\N{EXTRATERRESTRIAL ALIEN}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 12298 (\N{LEFT DOUBLE ANGLE BRACKET}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 12299 (\N{RIGHT DOUBLE ANGLE BRACKET}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_👽 WOMBOVERSE 👽 - 《 👽》LOUNGE - 💬│general-chat [774124295524712480] (2020-11-01 to 2021-12-01)_anonymized.csv
# In stage 0: transferred 10151 clusters with 20 clusters populated
# In stage 1: transferred 8997 clusters with 20 clusters populated
# In stage 2: transferred 8334 clusters with 20 clusters populated
# In stage 3: transferred 7966 clusters with 20 clusters populated
# In stage 4: transferred 7793 clusters with 20 clusters populated
# In stage 5: transferred 7628 clusters with 20 clusters populated
# In stage 6: transferred 7648 clusters with 20 clusters populated
# In stage 7: transferred 7494 clusters with 20 clusters populated
# In stage 8: transferred 7368 clusters with 20 clusters populated
# In stage 9: transferred 7384 clusters with 20 clusters populated
# In stage 10: transferred 7331 clusters with 20 clusters populated
# In stage 11: transferred 7325 clusters with 20 clusters populated
# In stage 12: transferred 7366 clusters with 20 clusters populated
# In stage 13: transferred 7273 clusters with 20 clusters populated
# In stage 14: transferred 7173 clusters with 20 clusters populated
# In stage 15: transferred 7120 clusters with 20 clusters populated
# In stage 16: transferred 7139 clusters with 20 clusters populated
# In stage 17: transferred 7213 clusters with 20 clusters populated
# In stage 18: transferred 7224 clusters with 20 clusters populated
# In stage 19: transferred 7233 clusters with 20 clusters populated
# In stage 20: transferred 7181 clusters with 20 clusters populated
# In stage 21: transferred 7176 clusters with 20 clusters populated
# In stage 22: transferred 7135 clusters with 20 clusters populated
# In stage 23: transferred 7186 clusters with 20 clusters populated
# In stage 24: transferred 7057 clusters with 20 clusters populated
# In stage 25: transferred 7132 clusters with 20 clusters populated
# In stage 26: transferred 7022 clusters with 20 clusters populated
# In stage 27: transferred 7036 clusters with 20 clusters populated
# In stage 28: transferred 7009 clusters with 20 clusters populated
# In stage 29: transferred 6991 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# troll pedophile
# security update
# topic
# screenshot situation wombosupport
# lmfao
#
# Topic 1: Sample Messages for Review
# member
# question wombosupport
# season
# game player
# majority
#
# Topic 2: Sample Messages for Review
# official
# staff
# amrit
# adobe product change
# problem throughs
#
# Topic 3: Sample Messages for Review
# beta
# party time
# computer
# icon
# device
#
# Topic 4: Sample Messages for Review
# head head head aaaaaaa
# face2face paper image video
# driver video server motion video picture
# quicker answer
# press opinion tool share detail model order motion model thanks
#
# Topic 5: Sample Messages for Review
# flushed_moyai
# explanation issue check featurerequests
# cream zootopia milk
# time airship map time game boring game
# bois book fiction section
#
# Topic 6: Sample Messages for Review
# bit
# thing
# incident
# ooh furry
# bit
#
# Topic 7: Sample Messages for Review
# portrait work
# footage
# cause phone
# official
# video
#
# Topic 8: Sample Messages for Review
# part ledge fun misleading disguise
# county
# gboard iphone
# heck
# trirub server lick paint
#
# Topic 9: Sample Messages for Review
# app emulator ldplayer bluestacks version app result httpsyoutubevgbycvwdina
# app emulator ldplayer bluestacks version app result httpsyoutubevgbycvwdina
# result
# app emulator ldplayer bluestacks version app result httpsyoutubevgbycvwdina
# app emulator ldplayer bluestacks version app result httpsyoutubevgbycvwdina
#
# Topic 10: Sample Messages for Review
# guy
# pointclouds octomaps
# work ping message
# trump space
# bug sorry issue fix
#
# Topic 11: Sample Messages for Review
# thing
# people
# bot jacob command user purge number message
# haha service logo
# premium
#
# Topic 12: Sample Messages for Review
# moon
# spam situation
# kill board
# friend laptop firefox lock handful tab
# alright
#
# Topic 13: Sample Messages for Review
# easter
# flag mantis shrimp
# time
# mad fiend jug wombo better
# gmail account
#
# Topic 14: Sample Messages for Review
# lot time app
# update work share button text messaging app
# cousin
# whoop
# thanks
#
# Topic 15: Sample Messages for Review
# name
# clone
# motor
# launch haha
# mine
#
# Topic 16: Sample Messages for Review
# yeah shoulder song
# change name
# way
# fire
# video thing
#
# Topic 17: Sample Messages for Review
# status song
# love borat song
# perk premium
# slowdown user
# song
#
# Topic 18: Sample Messages for Review
# garbage
# song
# way eyebrow
# pic
# computer
#
# Topic 19: Sample Messages for Review
# work
# idk version instruction
# version rickroll lmao
# drawback shift key mode
# fucking
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 128125 (\N{EXTRATERRESTRIAL ALIEN}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 12298 (\N{LEFT DOUBLE ANGLE BRACKET}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 12299 (\N{RIGHT DOUBLE ANGLE BRACKET}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_Midjourney - Chat - discussion [938713143759216720] (2022-02-01 to 2022-04-01)_anonymized.csv
# In stage 0: transferred 6983 clusters with 20 clusters populated
# In stage 1: transferred 5952 clusters with 20 clusters populated
# In stage 2: transferred 5411 clusters with 20 clusters populated
# In stage 3: transferred 5047 clusters with 20 clusters populated
# In stage 4: transferred 4843 clusters with 20 clusters populated
# In stage 5: transferred 4731 clusters with 20 clusters populated
# In stage 6: transferred 4637 clusters with 20 clusters populated
# In stage 7: transferred 4613 clusters with 20 clusters populated
# In stage 8: transferred 4531 clusters with 20 clusters populated
# In stage 9: transferred 4500 clusters with 20 clusters populated
# In stage 10: transferred 4494 clusters with 20 clusters populated
# In stage 11: transferred 4536 clusters with 20 clusters populated
# In stage 12: transferred 4508 clusters with 20 clusters populated
# In stage 13: transferred 4450 clusters with 20 clusters populated
# In stage 14: transferred 4436 clusters with 20 clusters populated
# In stage 15: transferred 4424 clusters with 20 clusters populated
# In stage 16: transferred 4395 clusters with 20 clusters populated
# In stage 17: transferred 4407 clusters with 20 clusters populated
# In stage 18: transferred 4424 clusters with 20 clusters populated
# In stage 19: transferred 4373 clusters with 20 clusters populated
# In stage 20: transferred 4390 clusters with 20 clusters populated
# In stage 21: transferred 4386 clusters with 20 clusters populated
# In stage 22: transferred 4414 clusters with 20 clusters populated
# In stage 23: transferred 4381 clusters with 20 clusters populated
# In stage 24: transferred 4390 clusters with 20 clusters populated
# In stage 25: transferred 4435 clusters with 20 clusters populated
# In stage 26: transferred 4421 clusters with 20 clusters populated
# In stage 27: transferred 4402 clusters with 20 clusters populated
# In stage 28: transferred 4333 clusters with 20 clusters populated
# In stage 29: transferred 4323 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# deploying
# video usage
# inits case structure detail
# fwiw vgqan generator people print image
# imo
#
# Topic 1: Sample Messages for Review
# apology secret term model diffusion model instance data refinement hyperparameters breakfast case
# website
# init image source toxicity scale user
# use year
# slot machine roll work midjourney exploration retro scifihorror httpstwittercomvolstofresearch source inspiration source process idea process idea
#
# Topic 2: Sample Messages for Review
# tool
# improvement gpus pipeline
# issue intent
# image_prompt
# thank device
#
# Topic 3: Sample Messages for Review
# option occasion dpi topaz purpose hallucination detail upscaler
# upscaler riot
# guidance
# model
# pixel
#
# Topic 4: Sample Messages for Review
# zooming video
# yeah prison sense power
# pawn phrase ability giger chess set
# video
# photo inits
#
# Topic 5: Sample Messages for Review
# resolution value atm
# guess learn
# issue image people
# cityscape artist
# thing ancient scripture geometry symbol
#
# Topic 6: Sample Messages for Review
# better
# way
# brain imagination practice
# pattern prompt
# stock part
#
# Topic 7: Sample Messages for Review
# stupidfunny channel
# sense part message book sort fantasy author
# kind sense
# beta midjourney beta signup link httpso9q981dirmktypeformcomtozztf1mvc curio
# extra
#
# Topic 8: Sample Messages for Review
# range_scale clamp_max cutn cutn_batches cutn_whole_portion cutn_bw_portion seed
# okay
# mario
# reason status highactivity downtime phase turn gon channel discussion activity time
# list random topic day topic list command
#
# Topic 9: Sample Messages for Review
# metaverse people irc
# smth way clutter issue
# thing thing discord bot people tech demo scale behalf mission people question hype hivemind trust user question stuff mirror strategy enterprise discussion test ability question test
# cli person audience
# thing user
#
# Topic 10: Sample Messages for Review
# yeah word
# word
# idea word ban
# channel people botsfood food
# straightforward set word dictionary idea
#
# Topic 11: Sample Messages for Review
# thing behaviour
# word face
# option alt style beta people
# change word block trust list
# list
#
# Topic 12: Sample Messages for Review
# ...
# self promotion link video httpsyoutubemi2jotcgjqa
# part project generator creator hub
#
# Topic 2: Sample Messages for Review
# help
# bot
# size image app quality
# image
# need
#
# Topic 3: Sample Messages for Review
# announcement
# channel
# command thing cutout frame check command list pin command
# work channel type imagine
# please deletedchannel
#
# Topic 4: Sample Messages for Review
# quin
# quin
# squanchy fonk
# access setting remix mode
# result blah
#
# Topic 5: Sample Messages for Review
# imagine everybody
# service
# quality
# user
# thing
#
# Topic 6: Sample Messages for Review
# journey
# opinion style quality
# character
# art
# book character
#
# Topic 7: Sample Messages for Review
# use depiction identity humor
# trial
# help artwork
# command
# right word prompt result
#
# Topic 8: Sample Messages for Review
# people
# way model
# thx
# comparison project strength user suit
# base model beta devs quality check deletedchannel
#
# Topic 9: Sample Messages for Review
# click server name drop menu people screen side
# lot people time
# worry case time image post link report channel
# video prompt rror
# tip
#
# Topic 10: Sample Messages for Review
# image thunderfury blade windseeker sword world warcraft male assassin rogue shadow body cloak dark
# question day
# amount credit
# yeah speak software time
# fact day human title animal braintobody ratio animal evolution mind network concept thanks brain way specie
#
# Topic 11: Sample Messages for Review
# image reference variation bit
# image
# warning source image content image generation fault picture image
# party theme
# prompt lady front curve
#
# Topic 12: Sample Messages for Review
# feature
# form mod announcement
# bot server
# api
# image practice
#
# Topic 13: Sample Messages for Review
# image
# jotaro job cowboy hat
# photo photo
# face image image face prompt face recognition coffee
# time
#
# Topic 14: Sample Messages for Review
# link work guess question let brb
# health support
# question
# thank help
# thanks
#
# Topic 15: Sample Messages for Review
# torcello
# room
# home
# feature
# information
#
# Topic 16: Sample Messages for Review
# need lot prompt
# newbie
# gtg guy badass day
# thank feedback please suggestionfeedbacks deletedchannel
# thank
#
# Topic 17: Sample Messages for Review
# language
# thank
# friend bluewillow time book page panel book paper matte paper
# adult content naked thing plenty
# matter reckon
#
# Topic 18: Sample Messages for Review
# caricature
# people contest solution
# time rule server matter scheme thing life people work job etc
# sorry spam invite strategy future
# paint channep
#
# Topic 19: Sample Messages for Review
# vote poll
# invitecto bluewillow
# convenient
# word inappropriate annoying image
# servce
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 127968 (\N{HOUSE BUILDING}) missing from current font.
#   pdf.savefig()
# <ipython-input-1-1c5cc12cd4f6>:104: UserWarning: Glyph 65073 (\N{PRESENTATION FORM FOR VERTICAL EM DASH}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_r_StableDiffusion - SD Main - general [1031106064776712226] (2022-12-01 to 2023-02-01)_anonymized.csv
# In stage 0: transferred 4873 clusters with 20 clusters populated
# In stage 1: transferred 4067 clusters with 20 clusters populated
# In stage 2: transferred 3733 clusters with 20 clusters populated
# In stage 3: transferred 3466 clusters with 20 clusters populated
# In stage 4: transferred 3411 clusters with 20 clusters populated
# In stage 5: transferred 3282 clusters with 20 clusters populated
# In stage 6: transferred 3207 clusters with 20 clusters populated
# In stage 7: transferred 3169 clusters with 20 clusters populated
# In stage 8: transferred 3145 clusters with 20 clusters populated
# In stage 9: transferred 3162 clusters with 20 clusters populated
# In stage 10: transferred 3157 clusters with 20 clusters populated
# In stage 11: transferred 3129 clusters with 20 clusters populated
# In stage 12: transferred 3187 clusters with 20 clusters populated
# In stage 13: transferred 3185 clusters with 20 clusters populated
# In stage 14: transferred 3192 clusters with 20 clusters populated
# In stage 15: transferred 3161 clusters with 20 clusters populated
# In stage 16: transferred 3147 clusters with 20 clusters populated
# In stage 17: transferred 3145 clusters with 20 clusters populated
# In stage 18: transferred 3152 clusters with 20 clusters populated
# In stage 19: transferred 3159 clusters with 20 clusters populated
# In stage 20: transferred 3135 clusters with 20 clusters populated
# In stage 21: transferred 3121 clusters with 20 clusters populated
# In stage 22: transferred 3094 clusters with 20 clusters populated
# In stage 23: transferred 3100 clusters with 20 clusters populated
# In stage 24: transferred 3088 clusters with 20 clusters populated
# In stage 25: transferred 3139 clusters with 20 clusters populated
# In stage 26: transferred 3027 clusters with 20 clusters populated
# In stage 27: transferred 3059 clusters with 20 clusters populated
# In stage 28: transferred 3079 clusters with 20 clusters populated
# In stage 29: transferred 3075 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# feel thread clearnet reddit github etc
# artist
# discord
# consensus pre post processing result
# place
#
# Topic 1: Sample Messages for Review
# thinking organization proai association
# thought
# pipe business egg water
# card workstation diffusion kind benchmark number
# quadro bos graphic price price cost get
#
# Topic 2: Sample Messages for Review
# people
# niche niche niche
# part style
# takedown regardless reason action
# splotch colour
#
# Topic 3: Sample Messages for Review
# commits startup error sonar traveler extension extension version course error script traceback call file cusersusernamedesktopstablediffusionwebuimodulesscriptspy line load_scripts script_loadingload_modulescriptfilepath file cusersusernamedesktopstablediffusionwebuimodulesscript_loadingpy line load_module file line exec_module file importlib_bootstrap line cusersusernamedesktopstablediffusionwebuiextensionsstablediffusionwebuiprompttravelscriptsprompt_travelpy line module modulessd_samplers single_sample_to_image importerror name single_sample_to_image modulessd_samplers error script traceback call file cusersusernamedesktopstablediffusionwebuimodulesscriptspy line load_scripts script_loadingload_modulescriptfilepath file cusersusernamedesktopstablediffusionwebuimodulesscript_loadingpy line load_module file line exec_module file importlib_bootstrap line cusersusernamedesktopstablediffusionwebuiextensionsstablediffusionwebuisonarscriptssonarpy line module def sample_naivemodelcfgdenoiser xtensor sigmaslist extra_args nameerror name cfgdenoiser
# launcher
# hey install
# append themedark end url themedark command line
# nai
#
# Topic 4: Sample Messages for Review
# look xformers pytorch
# architecture bug support series
# gen params
# computer build
# rest access data center a100s disposal luck processing lot income tie speed
#
# Topic 5: Sample Messages for Review
# image concept word concept pixel text concept world
# stuff nansexception tensor nan unet precision picture card type try commandline argument
# research model web data set blip history tech point directory web page website directory directory set switch board blip
# httpsgithubcomhuggingfacediffusers checkpoint_path yourmodelnameckpt model_path pathtofoldermesshere consider filesize
# space model client
#
# Topic 6: Sample Messages for Review
# model mse vae vae drama
# model
# btw vae anythingv3 vae
# need pagefile gig ram whatheck
# lot people file
#
# Topic 7: Sample Messages for Review
# question step step image screen load time image google colab instance
# yeah time client work moment
# cpu
# picture
# desktop gpu work ram
#
# Topic 8: Sample Messages for Review
# face restorer setting deletedchannel generator test grid difference
# image render architecture deletedchannel landscape drawing channel sure use
# ooo ruckusmatter
# image example image text training data scrape internet image time associate sort combination phrasing image data
# matter automation consumer end detail training photo knowledge base detail pas make picture button step user pas matter course base size site enhance button need fix occasion resolution resolution detail output model matter implementation
#
# Topic 9: Sample Messages for Review
# venv
# darn experience colabs
# repo ctrlc ctrlv
# mind
# way flag localhost port network traffic router port incoming traffic port choice port webui home network address port username password setting mode prompt credential connection
#
# Topic 10: Sample Messages for Review
# webui leak ecosystem
# batch script webui store output image
# space path venv change break
# window program access file
# code
#
# Topic 11: Sample Messages for Review
# colab gib
# step colab
# prtogen huggingface heard civitai today
# way huggingface
# httpscivitaicommodels2110gloriousstyle
#
# Topic 12: Sample Messages for Review
# infrastructure society
# anatomy aspect
# tech limiting factor part dna copy
# internet
# picture haha
#
# Topic 13: Sample Messages for Review
# option imo middle
# speaking anybody xformers work linux distros
# lot
# confusingannoying setting
# way thing time grid generator
#
# Topic 14: Sample Messages for Review
# arch_ss prompt
# ill stab
# ftx fraud
# model prompt
# midjourney midjourney style
#
# Topic 15: Sample Messages for Review
# info
# point argument
# increase strength name
# httpsgithubcomquestianonsdupdates use
# embedding log time image count run embeddings embeddings seed
#
# Topic 16: Sample Messages for Review
# advice run time
# lot quality image
# option gpu scream terror mouse cursor dreambooth tab
# work
# listen lot shit training
#
# Topic 17: Sample Messages for Review
# prompt extension httpsgithubcomadieyalsddynamicprompts
# yeah
# lowvram medvram setting auto webui
# yeah rock place
# channel guide example stuff older change minute httpswwwyoutubecomaitrepreneur
#
# Topic 18: Sample Messages for Review
# 166its
# course privacy server copy capacity software
# channel question
# vram
# beginner guide webui
#
# Topic 19: Sample Messages for Review
# diffusion sort memory generation color dress color color change color difference
# bias towards reading conclusion towards
# odd
# exif
# strength pretending step latter step
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_r_StableDiffusion - SD Main - general [1031106064776712226] (2024-01-01 to 2024-03-01)_anonymized.csv
# In stage 0: transferred 3225 clusters with 20 clusters populated
# In stage 1: transferred 2663 clusters with 20 clusters populated
# In stage 2: transferred 2482 clusters with 20 clusters populated
# In stage 3: transferred 2352 clusters with 20 clusters populated
# In stage 4: transferred 2354 clusters with 20 clusters populated
# In stage 5: transferred 2259 clusters with 20 clusters populated
# In stage 6: transferred 2232 clusters with 20 clusters populated
# In stage 7: transferred 2241 clusters with 20 clusters populated
# In stage 8: transferred 2193 clusters with 20 clusters populated
# In stage 9: transferred 2158 clusters with 20 clusters populated
# In stage 10: transferred 2183 clusters with 20 clusters populated
# In stage 11: transferred 2172 clusters with 20 clusters populated
# In stage 12: transferred 2162 clusters with 20 clusters populated
# In stage 13: transferred 2201 clusters with 20 clusters populated
# In stage 14: transferred 2180 clusters with 20 clusters populated
# In stage 15: transferred 2166 clusters with 20 clusters populated
# In stage 16: transferred 2150 clusters with 20 clusters populated
# In stage 17: transferred 2153 clusters with 20 clusters populated
# In stage 18: transferred 2165 clusters with 20 clusters populated
# In stage 19: transferred 2133 clusters with 20 clusters populated
# In stage 20: transferred 2132 clusters with 20 clusters populated
# In stage 21: transferred 2180 clusters with 20 clusters populated
# In stage 22: transferred 2159 clusters with 20 clusters populated
# In stage 23: transferred 2091 clusters with 20 clusters populated
# In stage 24: transferred 2133 clusters with 20 clusters populated
# In stage 25: transferred 2166 clusters with 20 clusters populated
# In stage 26: transferred 2130 clusters with 20 clusters populated
# In stage 27: transferred 2097 clusters with 20 clusters populated
# In stage 28: transferred 2111 clusters with 20 clusters populated
# In stage 29: transferred 2097 clusters with 20 clusters populated
#
# Topic 0: Sample Messages for Review
# work
# api
# content thing standard thing occasion image scratch anymore exercise frustration
# post help desk
# beware spider zombie
#
# Topic 1: Sample Messages for Review
# limit
# tbf drive diffusion thing drive drive diffusion
# thanks
# dadaptlion choice d00001 dadapt algorithm sdxl experience
# way shit
#
# Topic 2: Sample Messages for Review
# aolkowhy
# yea exchange information angle
# adetailer face
# paint
# code
#
# Topic 3: Sample Messages for Review
# training system deliberate
# info
# powershell modulescript
# sticker
# somthing mine
#
# Topic 4: Sample Messages for Review
# image
# somebody custom style prompt
# size model
# style tag
# model style style
#
# Topic 5: Sample Messages for Review
# use preview image node
# workflow stylecharacter video workflow frame input image result change video animatediff batch frame frame time animatediff output way frame batch thanks
# community guideline lol
# svd list civitai
# result lol
#
# Topic 6: Sample Messages for Review
# mean style style analog hand anime thanks anyways
# corpo custom launcher
# archaismhttpsgithubcomyuanxiaoscdeepnudeanimagetoimagetechnology
# people artist tool future artist
# use thing behaves tile
#
# Topic 7: Sample Messages for Review
# option ego direction
# okay question application llm computer vision task skus inference way p100 p40 inference
# koyhya people
# result okay
# quality story quality market top
#
# Topic 8: Sample Messages for Review
# version creator quality image
# offering mean
# random shit
# suturing
# httpsdiscordcomchannels103779958378437019610377995837843702021203930591968493570 training lora need photo dataset parameter
#
# Topic 9: Sample Messages for Review
# pull end
# theme goal trainer dirt interface way swarm optional mode
# parent
# help aspect stuff nature understand folder stablediffusion folder line
# question prompt result person prompt weight output person
#
# Topic 10: Sample Messages for Review
# back
# combination boorus training
# repo install instruction
# nickname check
# microsoftpowertoys source winget choco install powertoys
#
# Topic 11: Sample Messages for Review
# repd hoax
# command photo blonde woman expression eye outfit12 face shot viewer eye lips12she cafe scenery backdrop dazziling necklace handsreal perspective
# api
# era gui wrapper kohyas mess trainer uis
# solution conversion decode sdxl vae
#
# Topic 12: Sample Messages for Review
# sd_vae quicksettings list setting
# prompt person image
# esrgan upscaler generation
# httpsyoutubetd4whbh7evo
# record repo
#
# Topic 13: Sample Messages for Review
# opposite amuse
# approach upside downside
# thanks tip currency price inference compare quadro skus rtx t4a100v100h100
# model
# binding
#
# Topic 14: Sample Messages for Review
# vae none
# nvm
# cityscape space interior thing nature
# optimizer_args dadaptlion scheduler
# time bitcoin bot
#
# Topic 15: Sample Messages for Review
# dick situation
# finger guru
# model httpscivitaicommodels16481anyfetus badhands5 badartist httpscivitaicommodels5224badartistnegativeembedding
# wait
# example highend stuff google model size sdxl checkpointlora gpus asics amazon gaudi line microsofts maia
#
# Topic 16: Sample Messages for Review
# way github repos
# tutorial coco video generation
# show example training set friend approval deal
# hey gpu month apps gpu thanks
# nansexception tensor nan unet precision picture card type try cross attention layer option setting diffusion commandline argument use argument check
#
# Topic 17: Sample Messages for Review
# chat regenerate
# version premade model
# stabilitymatrix
# libs torch
# branch pytorch cross attention effect torch
#
# Topic 18: Sample Messages for Review
# feature creativity blend
# feature window setting webui gander generation window
# loop awhile super upgrade purpose game card
# resolution
# ooo batch vram
#
# Topic 19: Sample Messages for Review
# httpsgeminigooglecomapp
# model animation rig bunch stock animation figure idea way
# cause deepfake training time
# people maniac
# object background object caption background
