# %%
# !pip install git+https://github.com/rwalk/gsdmm.git
# !pip install nltk spacy gensim pyLDAvis networkx wordcloud

import os
import pandas as pd
import numpy as np
import re
import random
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import pos_tag
import nltk
import spacy
import gensim
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
import networkx as nx
from collections import Counter
from itertools import combinations
from matplotlib.backends.backend_pdf import PdfPages

# Load Spacy's English model for Named Entity Recognition
nlp = spacy.load("en_core_web_sm")

# Mount Google Drive to access the dataset stored there
from google.colab import drive
drive.mount('/content/drive')

# Download necessary NLTK resources for tokenization and POS tagging
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

general_stopwords = {
    'would', 'could', 'should', 'might', 'must', 'will', 'shall', 'can', 'may', 'wouldn', 'couldn', 'shouldn',
    'mightn', 'mustn', 'won', 'shan', 'can', 'mayn', 'just', 'don', 'didn', 'doesn', 'aren', 'isn', 'wasn',
    'weren', 'hasn', 'haven', 'hadn', 'does', 'did', 'don', 'does', 'did', 'don', 'now', 'then', 'once',
    'after', 'before', 'since', 'during', 'while', 'until', 'ago', 'yet', 'still', 'even', 'ever', 'always',
    'never', 'sometimes', 'often', 'usually', 'again', 'too', 'also', 'only', 'really', 'very', 'much',
    'more', 'most', 'many', 'several', 'few', 'some', 'any', 'each', 'every', 'all', 'both', 'either',
    'neither', 'anyone', 'everyone', 'someone', 'nobody', 'noone', 'nothing', 'anything', 'something',
    'everything', 'another', 'such', 'one', 'two', 'three', 'first', 'second', 'third', 'next', 'last',
    'same', 'other', 'different', 'new', 'old', 'young', 'long', 'short', 'high', 'low', 'large', 'small'
}

# Combine all sets of stop words
stop_words = set(stopwords.words('english')) | general_stopwords

# Define the preprocessing function
def preprocess(text):
    lemmatizer = WordNetLemmatizer()
    # Remove all non-word characters and lower the text
    text = re.sub(r'[^\w\s]', '', text.lower())
    # Split text into tokens
    tokens = text.split()
    # Apply NER to remove usernames and named entities
    doc = nlp(' '.join(tokens))
    tokens = [token.text for token in doc if not token.ent_type_]
    # POS 的位置提前了，本来在最后
    # Retain only nouns as they are significant for topic identification
    nouns = [word for word, pos in pos_tag(tokens) if pos.startswith('NN')]
    # 筛选本来 lemmatize 和 len(word) > 2 是在同一行的，有可能 lemmatize 之后 word length 小于 2，所以这里把长度筛选放在后面了
    # Lemmatize tokens and remove stop words and short words
    nouns = [lemmatizer.lemmatize(word) for word in nouns]
    nouns = [word for word in nouns if word not in stop_words and len(word) > 2]
    return nouns

# Function to load and preprocess data from CSV files
def load_data(file_path):
    df = pd.read_csv(file_path)
    df['preprocessed'] = df['Content'].apply(preprocess)
    return df['preprocessed'].tolist()

# Path to the folder containing the dataset
folder_path = '/content/drive/My Drive/Discord dataset/Cleaned data/'
file_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.csv')]

# Function to evaluate coherence
def evaluate_coherence(dictionary, docs, limit, start=2, step=3):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.ldamodel.LdaModel(corpus=[dictionary.doc2bow(doc) for doc in docs],
                                                id2word=dictionary,
                                                num_topics=num_topics,
                                                random_state=100,
                                                update_every=1,
                                                chunksize=100,
                                                passes=10,
                                                alpha='auto',
                                                per_word_topics=True)
        model_list.append(model)
        coherencemodel = gensim.models.CoherenceModel(model=model, texts=docs, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values

# Function to randomly select messages from each topic for manual review
def random_message_selection(docs, best_model, dictionary, num_samples=5):
    topics = best_model.show_topics(num_words=10, formatted=False)
    for topic_id, _ in topics[:5]:  # Limit to top 5 topics
        topic_docs = [doc for doc in docs if any(topic_id == topic[0] for topic in best_model.get_document_topics(dictionary.doc2bow(doc), minimum_probability=0.1))]
        sampled_messages = random.sample(topic_docs, min(len(topic_docs), num_samples))
        print(f"\nTopic {topic_id}: Sample Messages for Review")
        for message in sampled_messages:
            print(' '.join(message))

# Function to save plots to a PDF
def save_plots_to_pdf(file_path, best_model, dictionary, top_clusters):
    pdf_file_name = f'{os.path.basename(file_path)}_report.pdf'
    with PdfPages(pdf_file_name) as pdf:
        for topic_id in top_clusters:
            # Word cloud
            topic_words = dict(best_model.show_topic(topic_id, topn=50))
            wordcloud = WordCloud(background_color='white', width=800, height=400).generate_from_frequencies(topic_words)
            plt.figure(figsize=(10, 5))
            plt.imshow(wordcloud, interpolation='bilinear')
            plt.title(f"Topic {topic_id} Word Cloud for {os.path.basename(file_path)}")
            plt.axis("off")
            pdf.savefig()
            plt.close()

            # Bar chart
            sorted_topic_words = dict(sorted(topic_words.items(), key=lambda item: item[1], reverse=True)[:10])
            plt.figure(figsize=(10, 5))
            plt.bar(sorted_topic_words.keys(), sorted_topic_words.values())
            plt.title(f"Top Words in Topic {topic_id}")
            plt.xticks(rotation=45)
            pdf.savefig()
            plt.close()

            # Network graph
            words = list(sorted_topic_words.keys())
            word_pairs = list(combinations(words, 2))
            G = nx.Graph()
            G.add_edges_from(word_pairs)
            pos = nx.spring_layout(G)
            plt.figure(figsize=(10, 5))
            nx.draw(G, pos, with_labels=True, node_size=50, font_size=10, edge_color='grey')
            plt.title(f"Word Co-occurrence Network for Topic {topic_id}")
            pdf.savefig()
            plt.close()

    return pdf_file_name

# Process each file, perform topic modeling, and generate visualizations
for file_path in file_paths:
    print(f"Processing file: {file_path}")
    docs = load_data(file_path)
    # Remove any empty documents resulting from preprocessing
    docs = [doc for doc in docs if doc]

    if len(docs) > 0:
        # Create a dictionary of all words in documents
        dictionary = gensim.corpora.Dictionary(docs)
        # Remove extremes to focus on relevant words only
        dictionary.filter_extremes(no_below=10, no_above=0.5, keep_n=10000)
        vocab_length = len(dictionary)

        if vocab_length == 0:
            print("No vocabulary available after filtering extremes. Skipping.")
            continue

        # Evaluate coherence for different number of topics
        model_list, coherence_values = evaluate_coherence(dictionary, docs, limit=20)  # Increase to explore more topics

        # Select the model with the highest coherence
        best_model_index = coherence_values.index(max(coherence_values))
        best_model = model_list[best_model_index]

        # Random message selection for validation
        random_message_selection(docs, best_model, dictionary)

        # Visualize the topics using pyLDAvis
        try:
            lda_display = gensimvis.prepare(best_model, [dictionary.doc2bow(doc) for doc in docs], dictionary)
            pyLDAvis.display(lda_display)
        except Exception as e:
            print(f"Error in pyLDAvis visualization: {e}")

        # Generate and display word clouds for each of the top 5 topics
        sorted_clusters = sorted(range(best_model.num_topics), key=lambda k: sum([tup[1] for tup in best_model.get_topic_terms(k)]), reverse=True)
        top_clusters = sorted_clusters[:5]

        # Save plots to PDF
        pdf_file_name = save_plots_to_pdf(file_path, best_model, dictionary, top_clusters)

        # Provide a link to download the PDF file
        from google.colab import files
        files.download(pdf_file_name)
    else:
        print("Not enough data to build the model or all documents are empty.")
# Out:
# Collecting git+https://github.com/rwalk/gsdmm.git
#   Cloning https://github.com/rwalk/gsdmm.git to /tmp/pip-req-build-6f79dikx
#   Running command git clone --filter=blob:none --quiet https://github.com/rwalk/gsdmm.git /tmp/pip-req-build-6f79dikx
#   Resolved https://github.com/rwalk/gsdmm.git to commit 4ad1b6b6976743681ee4976b4573463d359214ee
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gsdmm==0.1) (1.26.4)
# Building wheels for collected packages: gsdmm
#   Building wheel for gsdmm (setup.py) ... done
#   Created wheel for gsdmm: filename=gsdmm-0.1-py3-none-any.whl size=4586 sha256=7f8c6a64ad1cde75e8e814cfcd4761c05ce31957b82789459c20ff99f0e3f4fe
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fhjf7v5w/wheels/da/d3/6e/a612d7cff0fcfb6470b8c113fc04931ecffb466ac19b9c5f3c
# Successfully built gsdmm
# Installing collected packages: gsdmm
# Successfully installed gsdmm-0.1
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.6)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.4.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.3)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.1.4)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.10.1)
# Collecting funcy (from pyLDAvis)
#   Downloading funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.3.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.4)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 10.4 MB/s eta 0:00:00
# Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-2.0 pyLDAvis-3.4.1
# Mounted at /content/drive
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_Midjourney - Chat - discussion [938713143759216720] (2022-01-01 to 2022-07-01)_anonymized.csv
#
# Topic 16: Sample Messages for Review
# people mind midjourney hahah sorry party
# place picture frame haha
# bug yeah
# heck yeah
# yeah bit face restoration photoshopping
#
# Topic 13: Sample Messages for Review
# aspect ratio
# try size
# image text
# theory support amount text time response
# size credit plan
#
# Topic 10: Sample Messages for Review
# thanks
# thanks shot
# yeah thanks website
# sense thanks ancient
# channel request kind goof
#
# Topic 0: Sample Messages for Review
# bet gallery discord option
# word yes
# people issue month option
# word
# list word
#
# Topic 15: Sample Messages for Review
# plan credit thinkin
# job error memory image
# credit trial upscale variation command credit credit
# thing error problem render time relax mode thing people result
# job menu work
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_PromptHero - PromptHero - 🗨│general [1030178486398234684] (2022-10-13 to 2023-01-01)_anonymized.csv
#
# Topic 4: Sample Messages for Review
# hey thought model base openjourney finetunes base complaint lot problem people
# hey journey diffusion
# hey course
# hey model vaes gradient time button list custom model search tool download download hussle
# hey franck idea dreambooth fine model image modelckpt image subject resource lot people service gpu process repo httpsgithubcomjoepennadreamboothstablediffusion repo guide training subreddit ton knowledge google colabs httpswwwredditcomrdreamboothcommentsxnycm0dreambooth_implementation_with_stable_diffusion
#
# Topic 14: Sample Messages for Review
# issue room guide link
# yeah model card link colab httpscolabresearchgooglecomdrive1vkuxkkesynyi2olzm8mrwqcokqtsurmuspsharing
# couple link colab hugging face
# ran news stability model link transcript emad discord httpswwwredditcomrstablediffusioncommentsy2dinkcommentis32y1d
# thanks video link
#
# Topic 7: Sample Messages for Review
# yes lot power
# hello guy newbie fall parachute world art prompthero lot site
# showcase pro video diffusion video lot information
# lot
# lexica lot result prompthero difference quality
#
# Topic 15: Sample Messages for Review
# feature quality image
# simple option prompt model feature replacement a1111 option savvy individual install
# canvas feature offer txt2img tho
# hey challenge challengeinfo channel
# youtube channel super interesting diffusion image output
#
# Topic 3: Sample Messages for Review
# version comparison reddit httpswwwredditcomrstablediffusioncommentszkbwqdi_tried_various_models_with_the_same_settings
# difference version
# version image version
# model prompt word version
# discord community glad news
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 128488 (\N{LEFT SPEECH BUBBLE}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_Maze Guru - AI Art, Anime & Social - Chat - 💬｜english-discussion [1037291441434677268] (2024-01-01 to 2024-03-01)_anonymized.csv
#
# Topic 0: Sample Messages for Review
# interface return
# type result
# detail
# picture
# time gore fluffy pony
#
# Topic 1: Sample Messages for Review
# dalee style credit
# sorry link tolerance pedos screenshots
# provide
# let plane warhead
# nsfw server post content thank
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from current font.
#   pdf.savefig()
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 65372 (\N{FULLWIDTH VERTICAL LINE}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_Maze Guru - AI Art, Anime & Social - Chat - 💬｜english-discussion [1037291441434677268] (2022-11-01 to 2023-04-01)_anonymized.csv
#
# Topic 10: Sample Messages for Review
#
# Topic 3: Sample Messages for Review
#
# Topic 8: Sample Messages for Review
# thanks
# thanks concern
# thanks lotwe feedback team problem
# thanks share
# thanks bot
#
# Topic 11: Sample Messages for Review
# image consent artist
# user choice command worry stay info discord
# cause user link look creation user
# art service artist artist life
# user post number evaluation area worry
#
# Topic 15: Sample Messages for Review
# bot right server problem display manner
# question mtgs norn propts diva featureless face headcrest result negative featureless face work cuz diva
# result
# usage right huggingface
# upscaler result guy look
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from current font.
#   pdf.savefig()
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 65372 (\N{FULLWIDTH VERTICAL LINE}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_👽 WOMBOVERSE 👽 - 《 👽》LOUNGE - 💬│general-chat [774124295524712480] (2024-01-01 to 2024-03-01)_anonymized.csv
#
# Topic 6: Sample Messages for Review
# coffee aka robusta
# course fault
# thanks
# thanks semester test scription
# thank
#
# Topic 1: Sample Messages for Review
# point
# game
# grotesque cost character ill life
# people marmite others
# word post
#
# Topic 2: Sample Messages for Review
# mine designer lexica
# app iphone problem superslow rendering lot error
# mine
# back
# server room server bot server use room image
#
# Topic 7: Sample Messages for Review
# hey lou employee dream
# hey command wombot2 channel
# work skit
# android app memory cache device device app login info
# hello skit video command plan moment
#
# Topic 9: Sample Messages for Review
# bun facebook please
# tommy
# yeah bun chaos lord doubt desk
# fun
# suggestion team people look
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 128125 (\N{EXTRATERRESTRIAL ALIEN}) missing from current font.
#   pdf.savefig()
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 12298 (\N{LEFT DOUBLE ANGLE BRACKET}) missing from current font.
#   pdf.savefig()
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 12299 (\N{RIGHT DOUBLE ANGLE BRACKET}) missing from current font.
#   pdf.savefig()
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_👽 WOMBOVERSE 👽 - 《 👽》LOUNGE - 💬│general-chat [774124295524712480] (2020-11-01 to 2021-12-01)_anonymized.csv
#
# Topic 4: Sample Messages for Review
# portal escape message server rickroll people
# role traffic team ping
# thank
# issue message user
# optifine boosting mod lmao
#
# Topic 3: Sample Messages for Review
# search wombo
# name
# dam amrit name
# chromebook
# bit bruh
#
# Topic 0: Sample Messages for Review
# feedback
# guy lobby self
# hmmmmmm ill ask
# register implementation template motor
# thanks saturday
#
# Topic 6: Sample Messages for Review
# question wombo song war song
# app emulator ldplayer bluestacks version app result httpsyoutubevgbycvwdina
# app emulator ldplayer bluestacks version app result httpsyoutubevgbycvwdina
# watermark
# app emulator ldplayer bluestacks version app result httpsyoutubevgbycvwdina
#
# Topic 10: Sample Messages for Review
# cool
# bit work lol
# ill limit work lol
# chug jug leviathan
# chug jug leviathan
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 128125 (\N{EXTRATERRESTRIAL ALIEN}) missing from current font.
#   pdf.savefig()
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 12298 (\N{LEFT DOUBLE ANGLE BRACKET}) missing from current font.
#   pdf.savefig()
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 12299 (\N{RIGHT DOUBLE ANGLE BRACKET}) missing from current font.
#   pdf.savefig()
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_Midjourney - Chat - discussion [938713143759216720] (2022-02-01 to 2022-04-01)_anonymized.csv
#
# Topic 5: Sample Messages for Review
# result work
# issue gpus database bottleneck
# benefit result shitpost channel
# word wound word wound model
# model resolution future
#
# Topic 8: Sample Messages for Review
# quirk image bot server image code method inbox pngs title
# resolution type thing
# yep stuff end bug
# reference dream comment bot room haha
# type video people quality
#
# Topic 6: Sample Messages for Review
# wait people image command
# prompt guide message deletedchannel page
# hackin uppercase result berk word token capital letter
# word style others
# yeah love contact bunch people social share credit community link right
#
# Topic 7: Sample Messages for Review
# artist
# designer simple trick
# people prompt generation
# future idea game time variation target generation portrait character fun picking variation target image
# beginning channel couple question diffusion fuck blowing mind way custom resolutionsaspect ratio fact term plan tool discord channel
#
# Topic 1: Sample Messages for Review
# davidh use medium tempera charcoal paper alabaster gilt brass reproduction glass jewel
# issue quality
# pricing survey
# answer eula answer discord people server image purpose use lot people thing people term thing time
# image phone gallery file system file photo
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_LimeWire - create AI Images, Audio & Video - Community - 🏠︱general [1051607872695455884]_anonymized.csv
#
# Topic 0: Sample Messages for Review
# auto mod discord limewire message
# point developer api image creation day
# sir
# team type information date date delay explanation
# wanna speraetion topic future system creator team
#
# Topic 1: Sample Messages for Review
# limers
# image please answer thanks advance
# limewire holder nft platform get pro status
# atif
# web3
#
# Topic 2: Sample Messages for Review
# guy image show server
# lwolimewireoriginals server supply rarity
# people server
# zendesk support issue ticket
# place weather degree
#
# Topic 3: Sample Messages for Review
# hey question ama
# yeahh
# help let limewire
# studio image httpslimewirecomstudio
# link image image img2img feature
#
# Topic 4: Sample Messages for Review
# increase ticket change
# market
# lot video icon change miss
# reallyy
# moon
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 127968 (\N{HOUSE BUILDING}) missing from current font.
#   pdf.savefig()
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 65073 (\N{PRESENTATION FORM FOR VERTICAL EM DASH}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_PromptHero - PromptHero - 🗨│general [1030178486398234684]_anonymized.csv
#
# Topic 0: Sample Messages for Review
# gimme midjourney please
# prompt
# hey access course mod power access access channel course
# upload picture cracked marble
# macaroni
#
# Topic 1: Sample Messages for Review
# artist story step dream goal concept artist game company gamma minus test lead artist concept artist crew game title bit book foundation stuff life life time program midjourney others head love program dream concept artist industry project game film medium imagination kid video game film feeling art generative program creativity company project instagram twitter adventure professional work studio
# afternoon image interior warehouse bean
# area website post nsfw content
# copilot
# hey project llm rag text2image prompt user prompt vectordb coder guy anybody amount prompt image vectordb touch number number prompt prompt gold
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 128488 (\N{LEFT SPEECH BUBBLE}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_LimeWire - create AI Images, Audio & Video - Community - 🏠︱general [1051607872695455884] (1)_anonymized.csv
#
# Topic 0: Sample Messages for Review
# antobloom work
# difference people rookie move branch channel
# feature
# man lol
# hello guide deletedchannel thank
#
# Topic 1: Sample Messages for Review
# ngl lol
# avatar image
# point fee cost pocket
# look lead
# yes
#
# Topic 2: Sample Messages for Review
# perspective style model prompt prompt style
# server message invite link
# time error
# imagine prompt water world
# warning worry message
#
# Topic 3: Sample Messages for Review
# man
# doofy server
# mention function issue server
# image image link prompt
# use image way upload image discord imgur service
#
# Topic 4: Sample Messages for Review
# descriptives link
# sorry mod info
# organization
# click image press browser link
# command photo
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 127968 (\N{HOUSE BUILDING}) missing from current font.
#   pdf.savefig()
# <ipython-input-4-25da8df3174b>:121: UserWarning: Glyph 65073 (\N{PRESENTATION FORM FOR VERTICAL EM DASH}) missing from current font.
#   pdf.savefig()
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_r_StableDiffusion - SD Main - general [1031106064776712226] (2022-12-01 to 2023-02-01)_anonymized.csv
#
# Topic 9: Sample Messages for Review
# dunno mind school quality duke voice
# arch linux cuda xformers fine
# grid plot script grid
# art videogame character lol overwatch stuff existence skin trait character bit
# art server rule
#
# Topic 3: Sample Messages for Review
# takedown regardless reason action
# nope guess pic
# message version torch version choice torchvision version system venv scratch extension dependency extension comment dependency developer knowledge python care issue
# part embeds mix time
# painting style picture color way haha
#
# Topic 7: Sample Messages for Review
# firespam sub moment mod post flooding
# mcmonkey spaceship model subreddit httpshuggingfacecocorruptlakescifidiffusion
# got github tos
# embeds checkpoint
# technology cause wave noooo
#
# Topic 1: Sample Messages for Review
# map time cursor algo get x10 cheeers image clone image sampler
# way git
# wait vae folder root directory
# wait configyaml folder modelsstablediffusion
# gpu linux please stop error error error mind
#
# Topic 6: Sample Messages for Review
# extra tab
# difference
# difference text encoder
# thing diffusion use gpus position use batch gpu batch time gpus instance gpu project use case wife vacation
# lol
# Processing file: /content/drive/My Drive/Discord dataset/Cleaned data/cleaned_r_StableDiffusion - SD Main - general [1031106064776712226] (2024-01-01 to 2024-03-01)_anonymized.csv
#
# Topic 13: Sample Messages for Review
# shit
# animation environment physic
# default message tcmalloc startup
# setup lcm otherwise default setup
# animatediffsvd animation trade accuracy quality detailers allows animation line problem
#
# Topic 10: Sample Messages for Review
# tbh motion director net course
# software engineering mode type software design mode user default setting template change theme selector mode hand user experience product testing software design concept pattern skill productivity career prospect principle design pattern design microservices software type bug reporting acceptance regression sanity permission rest api compatibility load testing security testing3 citation httpsstudycomacademylessondesignconceptsinsoftwareengineeringtypesexampleshtml
# image web attention mask nose photoshop process denoise
# acount pay fine gift card
# folder grid photo man duplicate way conclusion idea model
#
# Topic 2: Sample Messages for Review
# lot model loras use
# lot sense
# batch lot lot lot vram
# image web attention mask nose photoshop process denoise
# prompting latents case latents spot prompt
#
# Topic 1: Sample Messages for Review
# mine dadaptlion debias thing training detail quality
# a1111 lycoris way lora lycoris folder
# bot message
# set instruction disc set instruction repo stand repository
# reddit thread work background picture way background
#
# Topic 5: Sample Messages for Review
# step
# alphafold guess name
# guess
# sampler latents step condition unets produce image majority rule
# unicode cjk model list

# %%
import os
import pandas as pd
import numpy as np
import re
import random
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import pos_tag
import nltk
import spacy
import gensim
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
import networkx as nx
from collections import Counter
from itertools import combinations
from matplotlib.backends.backend_pdf import PdfPages

# Load Spacy's English model for Named Entity Recognition
nlp = spacy.load("en_core_web_sm")

# Mount Google Drive to access the dataset stored there
from google.colab import drive
# drive.mount('/content/drive')

# Download necessary NLTK resources for tokenization and POS tagging
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

general_stopwords = {
    'would', 'could', 'should', 'might', 'must', 'will', 'shall', 'can', 'may', 'wouldn', 'couldn', 'shouldn',
    'mightn', 'mustn', 'won', 'shan', 'can', 'mayn', 'just', 'don', 'didn', 'doesn', 'aren', 'isn', 'wasn',
    'weren', 'hasn', 'haven', 'hadn', 'does', 'did', 'don', 'does', 'did', 'don', 'now', 'then', 'once',
    'after', 'before', 'since', 'during', 'while', 'until', 'ago', 'yet', 'still', 'even', 'ever', 'always',
    'never', 'sometimes', 'often', 'usually', 'again', 'too', 'also', 'only', 'really', 'very', 'much',
    'more', 'most', 'many', 'several', 'few', 'some', 'any', 'each', 'every', 'all', 'both', 'either',
    'neither', 'anyone', 'everyone', 'someone', 'nobody', 'noone', 'nothing', 'anything', 'something',
    'everything', 'another', 'such', 'one', 'two', 'three', 'first', 'second', 'third', 'next', 'last',
    'same', 'other', 'different', 'new', 'old', 'young', 'long', 'short', 'high', 'low', 'large', 'small'
}

# Combine all sets of stop words
stop_words = set(stopwords.words('english')) | general_stopwords

# Define the preprocessing function
def preprocess(text):
    lemmatizer = WordNetLemmatizer()
    # Remove all non-word characters and lower the text
    text = re.sub(r'[^\w\s]', '', text.lower())
    # Split text into tokens
    tokens = text.split()
    # Apply NER to remove usernames and named entities
    doc = nlp(' '.join(tokens))
    tokens = [token.text for token in doc if not token.ent_type_]
    # Retain only nouns as they are significant for topic identification
    nouns = [word for word, pos in pos_tag(tokens) if pos.startswith('NN')]
    if 'look' in tokens:
      print(text)
      print(list(pos_tag(tokens)))
    # Lemmatize tokens and remove stop words and short words
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words and len(word) > 2]
    return nouns

# Function to load and preprocess data from CSV files
def load_data(file_path):
    df = pd.read_csv(file_path)
    df['preprocessed'] = df['Content'].apply(preprocess)
    return df['preprocessed'].tolist()

load_data('data.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# the capitalism art earlier was pretty cool  interesting to see what ai thinks capitalism looks like
# [('capitalism', 'NN'), ('art', 'NN'), ('earlier', 'RBR'), ('pretty', 'RB'), ('cool', 'JJ'), ('interesting', 'VBG'), ('see', 'NN'), ('think', 'VBP'), ('capitalism', 'NN'), ('look', 'VBP'), ('like', 'IN')]
# if you have problem running command just look at deletedchannel
# [('problem', 'NN'), ('running', 'VBG'), ('command', 'NN'), ('look', 'NN'), ('deletedchannel', 'NN')]
# so can you please tell me how i can get the thing i want to actually look like what i want
# [('please', 'VB'), ('tell', 'VB'), ('get', 'VB'), ('thing', 'NN'), ('want', 'VBP'), ('actually', 'RB'), ('look', 'VBP'), ('like', 'IN'), ('want', 'NN')]
# i mean i just joined a few minutes ago but it looks to be free
# [('mean', 'NN'), ('joined', 'VBD'), ('minute', 'JJ'), ('look', 'NN'), ('free', 'JJ')]
# idkthis bot and midjourney bot look exactly the same
# [('idkthis', 'NN'), ('bot', 'NN'), ('midjourney', 'NN'), ('bot', 'NN'), ('look', 'NN'), ('exactly', 'RB')]
# do i look like i just fell off the discord short bus
# [('look', 'NN'), ('like', 'IN'), ('fell', 'VBD'), ('discord', 'NN'), ('bus', 'NN')]
# wu looks like its unlimited and free
# [('look', 'NN'), ('like', 'IN'), ('unlimited', 'JJ'), ('free', 'JJ')]
# it can be just look at how ppl are getting good results has more options
# [('look', 'NN'), ('ppl', 'IN'), ('getting', 'VBG'), ('good', 'JJ'), ('result', 'NN'), ('option', 'NN')]
# so the backend looks like its connected to midjourney
# [('backend', 'JJ'), ('look', 'NN'), ('like', 'IN'), ('connected', 'VBN'), ('midjourney', 'NN')]
# nvm about that sundering your bodies thing looks like the mods took care of it
# [('nvm', 'RB'), ('sundering', 'VBG'), ('body', 'NN'), ('thing', 'NN'), ('look', 'NN'), ('like', 'IN'), ('mod', 'NN'), ('took', 'VBD'), ('care', 'NN')]
# oh really i should look into that then
# [('look', 'NN')]
# but to be fair this bluewillow ai sounds fishy to me like their faq and other channels look extremely unprofessional and they didnt even remove the leveling feature of  mee6 which is clearly useless for such server
# [('fair', 'JJ'), ('bluewillow', 'JJ'), ('sound', 'NN'), ('fishy', 'NNS'), ('like', 'IN'), ('faq', 'JJ'), ('channel', 'NNS'), ('look', 'VBP'), ('extremely', 'RB'), ('unprofessional', 'JJ'), ('did', 'VBD'), ('nt', 'RB'), ('remove', 'VB'), ('leveling', 'NN'), ('feature', 'NN'), ('clearly', 'RB'), ('useless', 'JJ'), ('server', 'NN')]
# oh i see thats a little strange though we will look at it
# [('see', 'VB'), ('that', 'DT'), ('s', 'JJ'), ('little', 'JJ'), ('strange', 'JJ'), ('though', 'IN'), ('look', 'NN')]
# oh shi place looks real nice
# [('look', 'NN'), ('real', 'JJ'), ('nice', 'JJ')]
# question did you upscale the detail it looks      fantastic
# [('question', 'NN'), ('upscale', 'JJ'), ('detail', 'NN'), ('look', 'NN'), ('fantastic', 'JJ')]
# thats strange we will look at it could you provide a screenshot of it if possible
# [('that', 'DT'), ('s', 'VBZ'), ('strange', 'JJ'), ('look', 'NN'), ('provide', 'VBP'), ('screenshot', 'NN'), ('possible', 'JJ')]
# huh it looks like a random user is in the lead and the competition ends on monday i think
# [('huh', 'JJ'), ('look', 'NN'), ('like', 'IN'), ('random', 'NN'), ('user', 'JJ'), ('lead', 'NN'), ('competition', 'NN'), ('end', 'NN'), ('think', 'NN')]
# looks like nhx is on the lead
# [('look', 'NN'), ('like', 'IN'), ('lead', 'NN')]
# thanks to everyone participating in our invite competition it looks like this is going to be a close one
# [('thanks', 'NNS'), ('participating', 'VBG'), ('invite', 'JJ'), ('competition', 'NN'), ('look', 'NN'), ('like', 'IN'), ('going', 'VBG'), ('close', 'JJ')]
# is there anywhere a folder or gallery where my images are stored for later if i want to look up something
# [('image', 'NN'), ('stored', 'VBD'), ('later', 'RBR'), ('want', 'VBP'), ('look', 'NN')]
# right now that feature is not available but you should search your mentions in the server should look like this
# [('right', 'JJ'), ('feature', 'NN'), ('available', 'JJ'), ('search', 'NN'), ('mention', 'NN'), ('server', 'RB'), ('look', 'VBP'), ('like', 'IN')]
# how do i get more detail in my renders i saw some renders in environmental which ahve crazy amounts of detail but all of mine look painty if it makes sense even if i add parameters like hyperrealistic photograph etc
# [('get', 'VB'), ('detail', 'JJ'), ('render', 'NN'), ('saw', 'VBD'), ('render', 'JJR'), ('environmental', 'JJ'), ('ahve', 'NN'), ('crazy', 'JJ'), ('amount', 'NN'), ('detail', 'NN'), ('mine', 'NN'), ('look', 'VBP'), ('painty', 'JJ'), ('make', 'VBP'), ('sense', 'NN'), ('add', 'VBP'), ('parameter', 'NN'), ('like', 'IN'), ('hyperrealistic', 'JJ'), ('photograph', 'NN'), ('etc', 'NN')]
# is anyone having problem with upscaling like its either not doing it or it looks really bad
# [('problem', 'NN'), ('upscaling', 'VBG'), ('like', 'IN'), ('look', 'NN'), ('bad', 'JJ')]
# you can search your mentions in the server should look like this
# [('search', 'NN'), ('mention', 'NN'), ('server', 'RB'), ('look', 'VBP'), ('like', 'IN')]
# very interesting i will have to look into it
# [('interesting', 'JJ'), ('look', 'NN')]
# the picture i cant get is a monster of any sort witha keyhole in its chest  i also tried keyhole by itself apparently the bot cant make keyholes that look like keyholes
# [('picture', 'NN'), ('ca', 'MD'), ('nt', 'VB'), ('get', 'VB'), ('monster', 'JJ'), ('sort', 'NN'), ('witha', 'VBD'), ('keyhole', 'JJ'), ('chest', 'NN'), ('tried', 'VBD'), ('apparently', 'RB'), ('bot', 'VBN'), ('ca', 'MD'), ('nt', 'RB'), ('make', 'VB'), ('keyhole', 'JJ'), ('look', 'NN'), ('like', 'IN'), ('keyhole', 'NN')]
# the interface looks exactly like midjourney  is it a midjourney ai engine
# [('interface', 'NN'), ('look', 'VBP'), ('exactly', 'RB'), ('like', 'IN'), ('midjourney', 'NN'), ('midjourney', 'NN'), ('engine', 'NN')]
# we are not mj just the buttons looks same as its the default ui check deletedchannel  for more info
# [('button', 'NN'), ('look', 'NN'), ('default', 'NN'), ('check', 'NN'), ('deletedchannel', 'NN'), ('info', 'NN')]
# why the human body is so weirdly shaped  look her feets
# [('human', 'JJ'), ('body', 'NN'), ('weirdly', 'RB'), ('shaped', 'VBD'), ('look', 'JJR'), ('feets', 'NNS')]
# depends on the look
# [('depends', 'NNS'), ('look', 'VBP')]
# that looks like the symbol is different maybe different language keyboard or because its big font you use only one    if you notice after the 32 theres the right      you need two   without space ar
# [('look', 'NN'), ('like', 'IN'), ('symbol', 'NN'), ('maybe', 'RB'), ('language', 'NN'), ('keyboard', 'NN'), ('big', 'JJ'), ('font', 'NN'), ('use', 'NN'), ('notice', 'NN'), ('there', 'RB'), ('right', 'RB'), ('need', 'VB'), ('without', 'IN'), ('space', 'NN')]
# why the quality of the ai image looks off it was any of my prompts
# [('quality', 'NN'), ('image', 'NN'), ('look', 'NN'), ('prompt', 'NN')]
# for now only via your mentions you search your mentions should look like this
# [('via', 'IN'), ('mention', 'NN'), ('search', 'NN'), ('mention', 'NN'), ('look', 'NN'), ('like', 'IN')]
# when you type it should look like this
# [('type', 'JJ'), ('look', 'NN'), ('like', 'IN')]
# like the sizing  how can i make the size big enough that it looks good in print and not low res
# [('like', 'IN'), ('sizing', 'VBG'), ('make', 'VBP'), ('size', 'NN'), ('big', 'JJ'), ('enough', 'RB'), ('look', 'NN'), ('good', 'JJ'), ('print', 'NN'), ('re', 'NN')]
# thanks ill look around
# [('thanks', 'NNS'), ('ill', 'VBP'), ('look', 'VBP'), ('around', 'IN')]
# thanks ill look around
# [('thanks', 'NNS'), ('ill', 'VBP'), ('look', 'VBP'), ('around', 'IN')]
# i had to look up a different word roman is a more pc word for mj
# [('look', 'NN'), ('word', 'NN'), ('roman', 'NN'), ('word', 'NN')]
# mj and bw are completely different in every aspect you should try both and look the differences yourself
# [('completely', 'RB'), ('aspect', 'JJ'), ('try', 'NN'), ('look', 'NN'), ('difference', 'NN')]
# no bro it looks like this
# [('look', 'NN'), ('like', 'IN')]
# take a look at deletedchannel and make sure you are following all steps correctly
# [('take', 'VB'), ('look', 'NN'), ('deletedchannel', 'NNS'), ('make', 'VBP'), ('sure', 'JJ'), ('following', 'JJ'), ('step', 'NN'), ('correctly', 'RB')]
# take a look at deletedchannel
# [('take', 'VB'), ('look', 'NN'), ('deletedchannel', 'NNS')]
# why these pics looks so cheap against midjourney  am i using it wrong
# [('pic', 'NN'), ('look', 'NN'), ('cheap', 'JJ'), ('midjourney', 'NN'), ('using', 'VBG'), ('wrong', 'JJ')]
# i find the upscale feature however making the images look worse in upscaled
# [('find', 'VB'), ('upscale', 'JJ'), ('feature', 'NN'), ('however', 'RB'), ('making', 'VBG'), ('image', 'NN'), ('look', 'NN'), ('worse', 'JJR'), ('upscaled', 'JJ')]
# has anyone found what this bot is best at it seems to make a lot of things looks painted and distorted
# [('found', 'VBN'), ('bot', 'NN'), ('best', 'JJS'), ('seems', 'VBZ'), ('make', 'VBP'), ('lot', 'NN'), ('thing', 'NN'), ('look', 'NN'), ('painted', 'VBD'), ('distorted', 'JJ')]
# dcmmgg444
# 9177  hi dcm thanks for your message yes i am interested in this and i have joined your group ill have a look around and see if i can figure out how to generate some images i didnt have any joy with mid journey  but i need to take another stab at it chat soon hopefully
# [('dcmmgg444', 'NN'), ('dcm', 'NN'), ('thanks', 'NNS'), ('message', 'VB'), ('yes', 'RB'), ('interested', 'JJ'), ('joined', 'VBD'), ('group', 'NN'), ('ill', 'NN'), ('look', 'VBP'), ('around', 'IN'), ('see', 'JJ'), ('figure', 'NN'), ('generate', 'VB'), ('image', 'NN'), ('did', 'VBD'), ('nt', 'JJ'), ('joy', 'NN'), ('mid', 'NN'), ('journey', 'NN'), ('need', 'VBP'), ('take', 'VB'), ('stab', 'NN'), ('chat', 'RB'), ('soon', 'RB'), ('hopefully', 'RB')]
# deletedchannel look at the image2image directions at the bottom of the channel
# [('deletedchannel', 'NNS'), ('look', 'VBP'), ('image2image', 'JJ'), ('direction', 'NN'), ('bottom', 'NN'), ('channel', 'NN')]
# just the interface look similiar
# [('interface', 'NN'), ('look', 'NN'), ('similiar', 'NN')]
# unfortunately there is currently no feature to quickly locate all of your images but you can search for your mentions within the server should look like this
# [('unfortunately', 'RB'), ('currently', 'RB'), ('feature', 'JJ'), ('quickly', 'RB'), ('locate', 'VBP'), ('image', 'NN'), ('search', 'NN'), ('mention', 'NN'), ('within', 'IN'), ('server', 'JJ'), ('look', 'VBP'), ('like', 'IN')]
# deleted user wondering if you still need prompt engineers been an ai artist for about 3 years now would like to speak to you if position still available i was just shown this and look forward to seeing what this generator can do
# [('deleted', 'VBN'), ('user', 'NN'), ('wondering', 'VBG'), ('need', 'NN'), ('prompt', 'NNS'), ('engineer', 'VBP'), ('artist', 'NN'), ('like', 'IN'), ('speak', 'JJ'), ('position', 'NN'), ('available', 'JJ'), ('shown', 'VBN'), ('look', 'NN'), ('forward', 'RB'), ('seeing', 'VBG'), ('generator', 'NN')]
# regarding how you can start here you can take a look at deletedchannel after that you can go to the rookie channels and use the command imagine
# [('regarding', 'VBG'), ('start', 'NNS'), ('take', 'VB'), ('look', 'NN'), ('deletedchannel', 'NNS'), ('rookie', 'NN'), ('channel', 'NN'), ('use', 'NN'), ('command', 'NN'), ('imagine', 'NN')]
# i will check it out looks promising
# [('check', 'VB'), ('look', 'NN'), ('promising', 'VBG')]
# hey welcome check deletedchannel  for more information then you can take a look at the rookie channels
# [('hey', 'NN'), ('welcome', 'VBD'), ('check', 'NN'), ('deletedchannel', 'NN'), ('information', 'NN'), ('take', 'VB'), ('look', 'NN'), ('rookie', 'NN'), ('channel', 'NN')]
# thank you the httpswwwbluewillowai page said the newbies channel but it looks like old
# [('thank', 'NN'), ('httpswwwbluewillowai', 'NN'), ('page', 'NN'), ('said', 'VBD'), ('look', 'NN'), ('like', 'IN')]
# what are you trying to generate is the word inside the prompt box should look like this
# [('trying', 'VBG'), ('generate', 'NN'), ('word', 'NN'), ('inside', 'IN'), ('prompt', 'JJ'), ('box', 'JJ'), ('look', 'NN'), ('like', 'IN')]
# it doenst really matter that it looks offline
# [('doenst', 'JJ'), ('matter', 'NN'), ('look', 'NN'), ('offline', 'NN')]
# i ask you to remove the warning from me because if you look at the source of the image it initially did not bring the content of 18 i generated my image and restarted the generation its not my fault that i was given pictures that may have a forbidding image
# [('ask', 'NN'), ('remove', 'VB'), ('warning', 'VBG'), ('look', 'NN'), ('source', 'NN'), ('image', 'NN'), ('initially', 'RB'), ('bring', 'VB'), ('content', 'NN'), ('generated', 'VBN'), ('image', 'NN'), ('restarted', 'VBN'), ('generation', 'NN'), ('fault', 'NN'), ('given', 'VBN'), ('picture', 'NN'), ('forbidding', 'VBG'), ('image', 'NN')]
# take a look here
#
# aspect ratios always at the end of the prompt
# horizontal command ar 32  imagine water color painting of a cat no 3d photograph ar 32
# vertical command  ar 23  imagine water color painting of a cat no 3d photograph ar 23
# [('take', 'VB'), ('look', 'NN'), ('aspect', 'NN'), ('ratio', 'JJ'), ('end', 'NN'), ('prompt', 'NN'), ('horizontal', 'JJ'), ('command', 'NN'), ('imagine', 'NN'), ('water', 'NN'), ('color', 'NN'), ('painting', 'VBG'), ('cat', 'NN'), ('photograph', 'JJ'), ('vertical', 'JJ'), ('command', 'NN'), ('imagine', 'NN'), ('water', 'NN'), ('color', 'NN'), ('painting', 'VBG'), ('cat', 'NN'), ('photograph', 'NN')]
# take a look here
# [('take', 'VB'), ('look', 'NN')]
# hi all ive been playing and watching what others put in to generate images and ive seen lots of people putting what i guess is artist names at the end of their prompts is that right
#
# also i know about cinematic style i know there is also neonsomething but is there a list of the main stylings that can be used to give me a better idea ive been looking through lexica site which i believe the images there were made with bluewillow yeah
#
# ive had a look through the faq but wondering if there is any other resources that either the team has done or people who have used the tool that anyone can recommend
# [('i', 'NN'), ('ve', 'VBP'), ('playing', 'VBG'), ('watching', 'VBG'), ('others', 'NNS'), ('put', 'VBD'), ('generate', 'JJ'), ('image', 'NN'), ('i', 'NN'), ('ve', 'VBP'), ('seen', 'VBN'), ('lot', 'NN'), ('people', 'NNS'), ('putting', 'VBG'), ('guess', 'JJ'), ('artist', 'NN'), ('name', 'NN'), ('end', 'NN'), ('prompt', 'NN'), ('right', 'RB'), ('know', 'JJ'), ('cinematic', 'JJ'), ('style', 'NN'), ('know', 'VBP'), ('neonsomething', 'VBG'), ('list', 'NN'), ('main', 'JJ'), ('stylings', 'NNS'), ('used', 'VBN'), ('give', 'VBP'), ('better', 'JJR'), ('idea', 'NN'), ('i', 'NN'), ('ve', 'VBP'), ('looking', 'VBG'), ('lexica', 'NN'), ('site', 'NN'), ('believe', 'VBP'), ('image', 'NN'), ('made', 'VBN'), ('bluewillow', 'IN'), ('yeah', 'NN'), ('i', 'NN'), ('ve', 'VBP'), ('look', 'NN'), ('faq', 'JJ'), ('wondering', 'VBG'), ('resource', 'NN'), ('team', 'NN'), ('done', 'VBN'), ('people', 'NNS'), ('used', 'VBN'), ('tool', 'JJ'), ('recommend', 'NN')]
# look up your mention history on the server
# [('look', 'NN'), ('mention', 'NN'), ('history', 'NN'), ('server', 'NN')]
# take a look at promptfaq
# [('take', 'VB'), ('look', 'NN'), ('promptfaq', 'NN')]
# take a look at  deletedchannel  after that go to rookie channels and use the command imagine
# [('take', 'VB'), ('look', 'NN'), ('deletedchannel', 'NNS'), ('rookie', 'NN'), ('channel', 'NN'), ('use', 'NN'), ('command', 'NN'), ('imagine', 'NN')]
# renes86 i am agree with u about esti some youtubers said they preferred shopify over etsi which is less expensive and finicky there are also many addon modules afterwards i guess its better to try and make a name for myself and then create my own shop with lower prices
#
# for my part i dream of being able to offer personalized objects with my own creations to my loved ones im also looking for tips from good sites i may start with mugs because to offer clothes you have to know the size of people
#
# i am looking for a site capable of printing metal key rings with my creations if ever while strolling you find a site that looks reliable i would like a link
# [('renes86', 'NNS'), ('agree', 'VBP'), ('esti', 'NN'), ('youtubers', 'NNS'), ('said', 'VBD'), ('preferred', 'JJ'), ('shopify', 'NN'), ('etsi', 'NN'), ('le', 'RBR'), ('expensive', 'JJ'), ('finicky', 'JJ'), ('addon', 'NN'), ('module', 'NN'), ('afterwards', 'NNS'), ('guess', 'NN'), ('better', 'RBR'), ('try', 'VB'), ('make', 'VB'), ('name', 'JJ'), ('create', 'NN'), ('shop', 'NN'), ('lower', 'JJR'), ('price', 'NN'), ('part', 'NN'), ('dream', 'NN'), ('able', 'JJ'), ('offer', 'NN'), ('personalized', 'VBD'), ('object', 'JJ'), ('creation', 'NN'), ('loved', 'VBD'), ('one', 'CD'), ('looking', 'VBG'), ('tip', 'NN'), ('good', 'JJ'), ('site', 'NN'), ('start', 'NN'), ('mug', 'NN'), ('offer', 'NN'), ('clothes', 'NNS'), ('know', 'VBP'), ('size', 'NN'), ('people', 'NNS'), ('looking', 'VBG'), ('site', 'NN'), ('capable', 'JJ'), ('printing', 'NN'), ('metal', 'NN'), ('key', 'NN'), ('ring', 'VBG'), ('creation', 'NN'), ('strolling', 'VBG'), ('find', 'VBP'), ('site', 'NN'), ('look', 'NN'), ('reliable', 'JJ'), ('like', 'IN'), ('link', 'NN')]
# take a look here promptfaq maybe it can help you
# [('take', 'VB'), ('look', 'NN'), ('promptfaq', 'NN'), ('maybe', 'RB'), ('help', 'NN')]
# take a look at deletedchannel
# [('take', 'VB'), ('look', 'NN'), ('deletedchannel', 'NNS')]
# which image looks good guys select only one pretty please
# [('image', 'NN'), ('look', 'NN'), ('good', 'JJ'), ('guy', 'NN'), ('select', 'VBP'), ('pretty', 'JJ'), ('please', 'NN')]
# lets look forward who will win
# [('let', 'VB'), ('look', 'VB'), ('forward', 'RB'), ('win', 'VB')]
# they look so friendly
# [('look', 'NN'), ('friendly', 'JJ')]
# we dont have any features yet for now we need to look forward to the further announcements for bluewillow features
# [('do', 'VB'), ('nt', 'DT'), ('feature', 'NN'), ('need', 'VBP'), ('look', 'VBP'), ('forward', 'JJ'), ('announcement', 'NN'), ('bluewillow', 'NN'), ('feature', 'NN')]
# it looks gorgeous a lot of the time now
# [('look', 'NN'), ('gorgeous', 'JJ'), ('lot', 'NN'), ('time', 'NN')]
# there are many ideas start by simply experimenting
# mix different styles and see what happens
# after a while connect the style of the authors to your incarnations and see what happens
# the authors differ in style landscape architecture people technology
# there are also differences in the incarnations of style
# lets say the same anime  there are a bunch of them
# gradually picking up 12345  you will get a result that will please you
# we will look forward to your work bluewillowrblue
# [('idea', 'NN'), ('start', 'NN'), ('simply', 'RB'), ('experimenting', 'VBG'), ('mix', 'JJ'), ('style', 'NN'), ('see', 'NN'), ('happens', 'VBZ'), ('connect', 'JJ'), ('style', 'NN'), ('author', 'NN'), ('incarnation', 'NN'), ('see', 'VBP'), ('happens', 'VBZ'), ('author', 'NN'), ('differ', 'NN'), ('style', 'NN'), ('landscape', 'NN'), ('architecture', 'NN'), ('people', 'NNS'), ('technology', 'NN'), ('difference', 'NN'), ('incarnation', 'NN'), ('style', 'NN'), ('let', 'VB'), ('say', 'VB'), ('anime', 'JJ'), ('bunch', 'NN'), ('gradually', 'RB'), ('picking', 'VBG'), ('get', 'VB'), ('result', 'JJ'), ('please', 'NN'), ('look', 'VB'), ('forward', 'JJ'), ('work', 'NN'), ('bluewillowrblue', 'NN')]
# take a look at deletedchannel after that go to the rookie channels and use the command imagine
# [('take', 'VB'), ('look', 'NN'), ('deletedchannel', 'NNS'), ('rookie', 'NN'), ('channel', 'NN'), ('use', 'NN'), ('command', 'NN'), ('imagine', 'NN')]
# looks cool like this
# [('look', 'VB'), ('cool', 'NNS'), ('like', 'IN')]
# hi take a look deletedchannel  then go to rookie channels and use the imagine command then in the prompt you describe what you want to generate in the image
# [('take', 'VB'), ('look', 'NN'), ('deletedchannel', 'NNS'), ('rookie', 'NN'), ('channel', 'NN'), ('use', 'NN'), ('imagine', 'NN'), ('command', 'NN'), ('prompt', 'JJ'), ('describe', 'NN'), ('want', 'VBP'), ('generate', 'NN'), ('image', 'NN')]
# take a look deletedchannel after that go to rookie channels and use the imagine command then in the prompt you describe what you want to generate in the image
# [('take', 'VB'), ('look', 'NN'), ('deletedchannel', 'NNS'), ('rookie', 'NN'), ('channel', 'NN'), ('use', 'NN'), ('imagine', 'NN'), ('command', 'NN'), ('prompt', 'JJ'), ('describe', 'NN'), ('want', 'VBP'), ('generate', 'NN'), ('image', 'NN')]
# the promts dont look like the reference at all
# [('promts', 'NN'), ('do', 'VBP'), ('nt', 'RB'), ('look', 'VB'), ('like', 'IN'), ('reference', 'NN')]
# you can search through your mentions within the server should look like this
# [('search', 'NN'), ('mention', 'NN'), ('within', 'IN'), ('server', 'JJ'), ('look', 'VBP'), ('like', 'IN')]
# any good pop art prompts to look like this
# [('good', 'JJ'), ('pop', 'NN'), ('art', 'NN'), ('prompt', 'JJ'), ('look', 'NN'), ('like', 'IN')]
# thats great we will look into it
# [('that', 'DT'), ('s', 'VBZ'), ('great', 'JJ'), ('look', 'NN')]
# hello   there is currently no feature to quickly locate all of your creations but you can search for their mentions within the server it should look like this
# [('hello', 'NNS'), ('currently', 'RB'), ('feature', 'VBP'), ('quickly', 'RB'), ('locate', 'VB'), ('creation', 'NN'), ('search', 'NN'), ('mention', 'NN'), ('within', 'IN'), ('server', 'JJ'), ('look', 'VBP'), ('like', 'IN')]
# promptdiscussion and you can take a look a promptfaq
# [('promptdiscussion', 'NN'), ('take', 'VB'), ('look', 'NN'), ('promptfaq', 'NN')]
# and we will take a look
# [('take', 'VB'), ('look', 'NN')]
# hey welcome take a look at deletedchannel after that go to the rookie channels and use the command imagine
# [('hey', 'JJ'), ('welcome', 'JJ'), ('take', 'NN'), ('look', 'NN'), ('deletedchannel', 'NNS'), ('rookie', 'NN'), ('channel', 'NN'), ('use', 'NN'), ('command', 'NN'), ('imagine', 'NN')]
# hello how can i look up my recent prompt or images
# [('hello', 'NN'), ('look', 'NN'), ('recent', 'JJ'), ('prompt', 'JJ'), ('image', 'NN')]
# i am unsure how do i change  look
# [('unsure', 'JJ'), ('change', 'NN'), ('look', 'NN')]
# take a look at deletedchannel after that go to the rookie channels and use the command imagine
# [('take', 'VB'), ('look', 'NN'), ('deletedchannel', 'NNS'), ('rookie', 'NN'), ('channel', 'NN'), ('use', 'NN'), ('command', 'NN'), ('imagine', 'NN')]
# take a look at deletedchannel thats the info channel after that go to any rookie channel and use the command imagine
# [('take', 'VB'), ('look', 'NN'), ('deletedchannel', 'NNS'), ('that', 'WDT'), ('s', 'VBP'), ('use', 'NN'), ('command', 'NN'), ('imagine', 'NN')]
# [[],
#  [],
#  ['capitalism', 'art', 'see', 'capitalism'],
#  ['yeah', 'think'],
#  ['art', 'competition', 'vote', 'piece', 'winner', 'card', 'thought'],
#  ['heck', 'yeah'],
#  ['member', 'discord'],
#  ['sound'],
#  ['fun'],
#  [],
#  [],
#  ['server'],
#  [],
#  [],
#  ['fun', 'friend'],
#  ['awesome'],
#  [],
#  ['brain'],
#  ['niche', 'focus'],
#  ['focus', 'panda'],
#  ['cat'],
#  ['mine', 'thing'],
#  ['enjoy', 'pixar', 'spin', 'thinfs'],
#  ['niche', 'imagination', 'nt'],
#  ['boundary'],
#  ['word'],
#  ['list', 'word', 'space', 'creation', 'ideation', 'balance'],
#  ['way', 'room'],
#  ['hey'],
#  ['imagine'],
#  ['channel'],
#  ['thanks'],
#  ['see', 'people', 'image', 'command'],
#  ['find', 'people', 'service', 'ban'],
#  ['make', 'sentence'],
#  ['race', 'car', 'track', 'sir'],
#  ['speech', 'business', 'service'],
#  ['nt', 'term', 'service'],
#  ['diaper', 'tos'],
#  ['friend'],
#  ['image', 'service'],
#  ['please', 'refrain', 'nudity'],
#  ['try', 'use', 'sense', 'prompt'],
#  ['see', 'nudity', 'place', 'bro'],
#  ['create', 'nudity', 'please', 'result'],
#  ['ban', 'platform'],
#  ['try'],
#  ['dot', 'hover', 'message'],
#  ['setting'],
#  ['body', 'report'],
#  ['pls', 'post', 'sorry'],
#  ['show'],
#  ['click', 'copy'],
#  ['admin', 'delete'],
#  ['work'],
#  ['copy', 'message', 'delete'],
#  ['weird', 'prompt'],
#  ['see', 'stuff'],
#  ['use', 'reaction', 'flag', 'post'],
#  [],
#  ['prompt'],
#  ['result'],
#  ['thank'],
#  ['syrup'],
#  ['use', 'raunchy'],
#  ['beartv', 'raunchy'],
#  ['pootcoot'],
#  ['use', 'raunchy'],
#  ['thing'],
#  ['list', 'rule', 'reference', 'word'],
#  [],
#  ['bit'],
#  ['sorry', 'search'],
#  ['pootcoot'],
#  ['search', 'nudity', 'material'],
#  ['difference', 'cause', 'trouble'],
#  ['sorry'],
#  ['cat',
#   'girl',
#   'hand',
#   'foot',
#   'kind',
#   'hairy',
#   'spaghetti',
#   'face',
#   'photorealistic'],
#  [],
#  ['thing'],
#  ['way', 'image'],
#  ['thank', 'guy', 'thing'],
#  ['question'],
#  ['ban', 'understand', 'rule'],
#  ['enjoy', 'art', 'liking'],
#  [],
#  [],
#  ['thanks'],
#  ['nt', 'use', 'check', 'deletedchannel'],
#  [],
#  ['list', 'technique'],
#  ['feature'],
#  ['list', 'command'],
#  ['bot', 'operate'],
#  ['style', 'seed', 'chaos'],
#  ['question', 'owner'],
#  ['prompt', 'faq'],
#  ['elon', 'musk', 'bezos', 'etc'],
#  ['focus', 'tech'],
#  [],
#  ['computer'],
#  [],
#  ['outta'],
#  ['make', 'explicit', 'content'],
#  ['bread'],
#  ['food'],
#  ['problem', 'command', 'look', 'deletedchannel'],
#  ['capability', 'bot', 'result'],
#  ['hear'],
#  ['question', 'art', 'issue'],
#  ['thx', 'appreciate'],
#  [],
#  ['sorry', 'phone', 'see'],
#  [],
#  [],
#  [],
#  ['thx', 'man', 'appreciate'],
#  [],
#  ['thanks'],
#  ['problem', 'let'],
#  [],
#  [],
#  ['hear'],
#  ['part', 'theme'],
#  ['hey'],
#  [],
#  [],
#  [],
#  ['kind', 'theme', 'focus'],
#  ['fun'],
#  ['cool'],
#  ['gon', 'prompt'],
#  ['alright'],
#  ['edit', 'photo', 'photoshop', 'software'],
#  ['sick'],
#  ['check'],
#  [],
#  [],
#  ['lunch', 'dinner'],
#  [],
#  [],
#  ['gingerbread', 'lol'],
#  ['hope', 'holiday'],
#  ['hey'],
#  ['kind', 'art', 'making'],
#  [],
#  ['people'],
#  ['book', 'character'],
#  ['character'],
#  ['avenger'],
#  ['love'],
#  ['hope'],
#  ['art', 'spiderman', 'combination'],
#  ['combination', 'character'],
#  ['try', 'combination', 'result', 'spiderman'],
#  ['video', 'guy', 'batman', 'superman', 'fusion'],
#  ['thing', 'want'],
#  ['foodfoodfood'],
#  ['experiment', 'see'],
#  ['antobloom', 'love', 'work'],
#  ['guy'],
#  ['idea', 'merge', 'hulk'],
#  ['marvel', 'merger', 'idea'],
#  ['update'],
#  ['create'],
#  ['thx', 'man', 'appreciate'],
#  ['name'],
#  [],
#  [],
#  ['sticker'],
#  ['gotcha'],
#  ['get', 'character', 'style'],
#  ['steampunk', 'style', 'spiderman', 'spiderman'],
#  ['foodfoodfood'],
#  ['dr3amak3r', 'vote', 'poll'],
#  ['play', 'zombie', 'game'],
#  ['imagination', 'blank', 'ill'],
#  [],
#  ['day', 'guy'],
#  [],
#  ['northeast'],
#  ['middle'],
#  ['ocean'],
#  ['question', 'mind', 'tag', 'guy', 'instagram', 'grow', 'guy', 'content'],
#  ['sure'],
#  ['fact', 'appreciate'],
#  ['thx', 'yeah', 'problem'],
#  ['bluewillow'],
#  ['contest'],
#  ['image'],
#  ['post', 'image', 'deletedchannel', 'channel', 'vote'],
#  ['thanks'],
#  ['poll', 'vote'],
#  ['question', 'art', 'complaining'],
#  ['prompt'],
#  [],
#  [],
#  ['need', 'help'],
#  ['dgdogparty'],
#  ['top'],
#  ['image', 'nt', 'rule'],
#  ['fix'],
#  ['person'],
#  ['thank'],
#  ['aye'],
#  ['yes'],
#  ['cool', 'idea'],
#  ['way', 'idea', 's'],
#  ['idea'],
#  ['beta', 'mode', 'moment'],
#  ['hope', 'i', 've', 'power', 'time', 'storm'],
#  ['brolu', 'hey', 'please', 'lypsula', 'oreja', 'con'],
#  ['user', 'ban'],
#  ['thank', 'reporting'],
#  ['midjourney'],
#  ['hey', 'heart'],
#  ['ticket', 'question'],
#  ['management', 'right'],
#  ['sure'],
#  ['instruction'],
#  ['imagine', 'type'],
#  ['work'],
#  [],
#  ['screenshot'],
#  [],
#  ['yeah', 'text'],
#  ['command'],
#  ['side', 'account', 'work'],
#  [],
#  ['wanna', 'show', 'screen'],
#  ['slash', 'command', 'button', 'click', 'sign'],
#  [],
#  ['server'],
#  ['problem'],
#  ['hello', 'channel'],
#  ['sorry'],
#  ['fan', 'food'],
#  ['food', 'channel'],
#  ['post', 'food', 'pic', 'everyday'],
#  ['subscription'],
#  [],
#  ['mean', 'look'],
#  ['sus', 'lol'],
#  ['charge', 'cover', 'cost', 'community'],
#  ['discord'],
#  ['hope', 'el', 'workbot'],
#  [],
#  ['model'],
#  ['detail', 'website', 'link', 'discord'],
#  ['detail', 'thanks', 'prioritize', 'detail'],
#  ['thanks'],
#  ['stuff'],
#  ['user',
#   'discord',
#   'end',
#   'guy',
#   'midjourney',
#   'cost',
#   'midjourney',
#   'serversite'],
#  [],
#  ['spin', 'offrecreation', 'midjourney'],
#  ['use', 'model', 'midjourney', 'create', 'community', 'art'],
#  ['cool', 'thank'],
#  ['bot', 'fire', 'ngl'],
#  ['idkthis', 'bot', 'midjourney', 'bot', 'look'],
#  ['mid', 'journey', 'money', 'amount', 'try'],
#  [],
#  [],
#  ['subscription', 'midjourney'],
#  ['cool'],
#  ['weight', 'work', 'bot'],
#  ['api', 'devs'],
#  ['holiday'],
#  ['link', 'image', 'use', 'prompt'],
#  ['thanks', 'hour', 'night', 'thing', 'let'],
#  ['interface', 'midjourney', 'engine', 'engine', 'sort', 'feel'],
#  ['prompt', 'put'],
#  ['result', 'result'],
#  ['set', 'access', 'choose', 'command'],
#  ['diffusion'],
#  ['midjourney', 'model', 'learn'],
#  ['hope', 'bring', 'happiness'],
#  ['image', 'creation', 'reviewing'],
#  ['assuming', 'download', 'keep'],
#  ['ihave'],
#  ['body'],
#  ['art', 'combination'],
#  ['get', 'use', 'reference', 'image', 'character', 'sketch'],
#  [],
#  ['hour'],
#  ['hello', 'loving', 'peaceful'],
#  ['hello', 'year'],
#  ['year'],
#  ['firework'],
#  ['twitter'],
#  ['okay', 'community'],
#  ['game', 'section'],
#  ['bot', 'server'],
#  ['answer', 'right'],
#  [],
#  ['help', 'community', 'team', 'work'],
#  ['team'],
#  [],
#  ['gallery', 'collection', 'creation'],
#  ['building', 'feature', 'future'],
#  [],
#  ['instagram', 'link', 'broken'],
#  ['start', 'art'],
#  ['cafe', 'group'],
#  ['annnd', 'make', 'pic'],
#  ['time', 'somebody', 'auto', 'deletes'],
#  ['gon', 'figure'],
#  ['issue', 'discord', 'thing', 'get', 'auto', 'deleting'],
#  ['message'],
#  ['channel', 'metal', 'rules420'],
#  ['image', 'medium'],
#  ['tell'],
#  ['share', 'link', 'discord'],
#  ['theme'],
#  [],
#  ['foodfoodfood', 'image', 'prompt'],
#  ['people'],
#  [],
#  [],
#  ['s', 'borking', 'message'],
#  [],
#  ['involves', 'markiplier'],
#  ['okay'],
#  ['tell'],
#  ['model'],
#  ['tell', 'use', 'reference', 'picture', 'text', 'prompt', 'thank'],
#  ['end', 'text', 'prompt'],
#  ['midjourney', 'model'],
#  ['help', 'style', 'spaceship', 'vessel', 'tip'],
#  ['thanks'],
#  ['art'],
#  ['hello', 'people'],
#  ['guy', 'discord', 'thing', 'work', 'hope', 'channel', 'suggestion', 'use'],
#  ['image', 'theme'],
#  ['foodfoodfood',
#   'hey',
#   'start',
#   'work',
#   'wondering',
#   'plan',
#   'share',
#   'work',
#   'example',
#   'specify',
#   'tagg',
#   'page',
#   'thank'],
#  ['image',
#   'thunderfury',
#   'windseeker',
#   'sword',
#   'world',
#   'warcraft',
#   'male',
#   'assassin',
#   'rogue',
#   'shadow',
#   'body',
#   'cloak',
#   'dark',
#   'start'],
#  ['foodfoodfood', 'question', 'way', 'create'],
#  ['foodfoodfood', 'mean'],
#  ['ellaflyer', 'level'],
#  ['advice',
#   'discord',
#   'idea',
#   'screen',
#   'area',
#   'art',
#   'prompt',
#   'suggestion',
#   'please',
#   'generator',
#   'video',
#   'youtube',
#   'advice',
#   'welcome'],
#  ['record',
#   'image',
#   'prompt',
#   'community',
#   'advice',
#   'know',
#   'concern',
#   'anyones',
#   'name',
#   'permission'],
#  ['way', 'image', 'generator', 'copy', 'image'],
#  ['reason', 'type', 'character', 'ask'],
#  ['thing', 'diffusion'],
#  ['thing'],
#  [],
#  ['morning'],
#  ['feel', 'journey'],
#  ['song', 'bot', 'satisfying'],
#  ['piece'],
#  ['try'],
#  ['day'],
#  ['alright'],
#  ['bot', 'fork', 'midj'],
#  ['source', 'code'],
#  ['hey', 'story'],
#  ['checking', 'time'],
#  ['stuff', 'keep', 'wonder', 'hand'],
#  ['mean', 'name', 'thing', 'bird'],
#  ['feature', 'future'],
#  ['please', 'prompt'],
#  ['gotcha'],
#  ['person', 'transformer', 'server'],
#  ['net'],
#  ['fact', 'character', 'ask'],
#  ['guy'],
#  ['hey', 'hbu'],
#  ['level'],
#  ['work', 'day', 'weekend'],
#  ['night',
#   'user',
#   'generation',
#   'comparison',
#   'devs',
#   'honest',
#   'feedback',
#   'platform',
#   'way',
#   'image',
#   'quality',
#   'ability',
#   'prompt',
#   'mile',
#   'midjourney',
#   'testp',
#   'model',
#   'default',
#   'platform',
#   'league',
#   'interface',
#   'reason',
#   'pick'],
#  ['fork', 'call'],
#  ['thanks'],
#  ['let'],
#  ['midjourney', 'heck', 'lot', 'blue', 'willow', 'quit', 'pay', 'use'],
#  ['heyo'],
#  ['end', 'name'],
#  ['haha'],
#  ['thanks'],
#  ['respect'],
#  ['sifi', 'story', 'use', 'art', 'help', 'writer', 'block', 'idea', 'haha'],
#  ['theme'],
#  ['sifi', 'spaceship'],
#  ['wow', 'kind', 'people'],
#  ['alpha', 'torvar', 'level'],
#  ['service', 'part', 'community', 'community', 'way', 'support', 'bluewillow'],
#  ['alot', 'people', 'loner'],
#  ['generate', 'learning'],
#  ['question', 'bluewillow', 'time', 'learning'],
#  ['tho', 'people', 'thing'],
#  ['right'],
#  ['need'],
#  ['matter', 'reckon'],
#  ['need', 'lot'],
#  [],
#  ['level'],
#  ['evolves'],
#  ['contest'],
#  ['guy', 'invite'],
#  ['lol', 'correct', 'statement'],
#  ['programmer', 'team', 'build', 'community', 'cool', 'programmer'],
#  [],
#  ['clone', 'mid', 'journey', 'discord', 'server'],
#  ['lol'],
#  ['people'],
#  ['scam', 'lol', 'reporting', 'discord', 'server'],
#  ['tech'],
#  [],
#  ['discord', 'server', 'violation', 'term', 'service'],
#  ['yeah', 'midjourney', 'copy', 'room'],
#  [],
#  ['level'],
#  ['room', 'name', 'lol'],
#  ['look', 'discord', 'bus'],
#  ['care'],
#  [],
#  ['clone', 'tech', 'server', 'layout'],
#  ['midjourney'],
#  ['month'],
#  ['hope', 'lol'],
#  ['midjourney', 'tell'],
#  ['yes', 'work'],
#  ['lol'],
#  ['banrion', 'level'],
#  ['tbf', 'journey', 'account'],
#  ['work'],
#  ['change', 'join'],
#  ['runnin', 'core'],
#  ['alyen', 'level'],
#  ['job', 'capacity'],
#  ['yea'],
#  ['imagine', 'image'],
#  ['day'],
#  ['ill', 'chance'],
#  ['tech', 'diffusion'],
#  ['cooler',
#   'work',
#   'system',
#   'render',
#   'algorithm',
#   'help',
#   'cooldown',
#   'system',
#   'bot'],
#  ['query', 'algo', 'system'],
#  ['wonder', 'thing'],
#  ['faith'],
#  ['bot', 'midjourney', 'level'],
#  ['clock'],
#  ['chickensauce', 'level'],
#  ['thank', 'effort'],
#  ['interface', 'midjourney'],
#  ['yup', 'community', 'people', 'watch', 'people'],
#  ['bunch', 'source'],
#  ['hey'],
#  [],
#  ['result', 'feed'],
#  ['neat', 'try'],
#  ['sus', 'random', 'people', 'link'],
#  ['resist', 'lol'],
#  ['purplesmartai', 'setup', 'work', 'midjourney', 'bot', 'discord', 'server'],
#  ['capability'],
#  ['cover', 'cost', 'money', 'user', 'cool', 'community'],
#  ['bot'],
#  ['report', 'report'],
#  ['lol', 'love'],
#  ['thanks', 'matter', 'time', 'use', 'command', 'imagine'],
#  ['look'],
#  ['level'],
#  ['channel'],
#  ['service', 'lmao'],
#  ['rush'],
#  ['yuura', 'level'],
#  ['quality', 'worse'],
#  ['practice', 'i', 'result'],
#  ['thing', 'see', 'gen', 'image'],
#  ['way'],
#  ['human'],
#  ['report', 'report', 'channel'],
#  ['snitch', 'get', 'stitch'],
#  ['battle'],
#  [],
#  ['characterai'],
#  ['sheer', 'cliff'],
#  [],
#  ['character', 'personality', 'style'],
#  ['chat'],
#  ['dump', 'information', 'realistic'],
#  ['talk', 'people', 'version'],
#  [],
#  ['filter'],
#  [],
#  ['money', 'try', 'generate', 'anyways', 'community'],
#  ['look', 'result', 'option'],
#  ['server'],
#  ['see', 'day'],
#  ['lmao', 'pretend', 'mistress', 'stuff', 'tbh'],
#  ['screenshots'],
#  ['clever'],
#  ['mental', 'health', 'support'],
#  ['try'],
#  ['thanks'],
#  ['aspect', 'level'],
#  ['yeah'],
#  ['bot'],
#  ['server'],
#  ['idk'],
#  ['guy'],
#  ['dalle', 'dalle', 'meh', 'others'],
#  ['user', 'level'],
#  ['think'],
#  ['bluewillow'],
#  ['thing', 'server'],
#  ['think', 'mod'],
#  ['level'],
#  ['construction'],
#  ['s', 'difference'],
#  ['model', 'process', 'image', 'make', 'image'],
#  ['head',
#   'newbie',
#   'room',
#   'try',
#   'prompt',
#   'post',
#   'community',
#   'page',
#   'chance',
#   'win'],
#  ['got', 'nt', 'get', 'contact'],
#  ['way'],
#  ['want', 'thank'],
#  ['search', 'directory', 'pas', 'thanks'],
#  ['glad'],
#  ['art',
#   'platform',
#   'bluewillow',
#   'art',
#   'tool',
#   'use',
#   'platform',
#   'journey',
#   'artwork',
#   'feel',
#   'join',
#   'pressure',
#   'contest',
#   'hope'],
#  [],
#  [],
#  ['level'],
#  ['sent', 'people'],
#  ['yeah', 'bot', 'description'],
#  ['photo', 'use', 'license'],
#  ['use', 'image', 'use', 'image'],
#  ['ths248', 'level'],
#  ['comment', 'community', 'grow'],
#  ['thanks'],
#  ['server'],
#  [],
#  ['bot'],
#  ['organizedgalaxies', 'level'],
#  ['thanks'],
#  [],
#  ['get'],
#  ['characterai', 'haha'],
#  ['tos', 'usage', 'cost', 'etc'],
#  [],
#  [],
#  ['command', 'type'],
#  ['check', 'deletedchannel'],
#  ['look', 'midjourney'],
#  ['bot'],
#  ['model', 'model', 'deletedchannel', 'team'],
#  ['cool', 'metaanalysis', 'model', 'idea'],
#  ['difference', 'vintedoisdiffusionv01', 'rpg_v2beta', 'forget'],
#  ['option', 'platform', 'try', 'sampler', 'model', 'cfg7', 'matrix'],
#  ['heck', 'ability', 'mouse', 'model', 'page', 'point', 'model', 'track'],
#  ['level'],
#  ['lol', 'corn'],
#  [],
#  ['woah'],
#  ['advertisement'],
#  ['revolution',
#   'consequence',
#   'disaster',
#   'race',
#   'lifeexpectancy',
#   'country',
#   'society',
#   'life',
#   'indignity',
#   'suffering',
#   'world',
#   'suffering',
#   'damage',
#   'world',
#   'development',
#   'technology',
#   'situation',
#   'indignity',
#   'damage',
#   'world',
#   'disruption',
#   'suffering',
#   'lead',
#   'suffering',
#   'country'],
#  ['nt', 'program', 'sfw'],
#  ['check', 'group', 'diffusion'],
#  ['glitch', 'get', 'sfw'],
#  ['ask', 'prompt', 'min'],
#  [],
#  ['place', 'feedback'],
#  ['subscription', 'midjourney'],
#  ['hello', 'time', 'people', 'moment', 'bit', 'inconvenience', 'time'],
#  ['image', 'generate', 'enjoy'],
#  ['hope', 'server', 'user'],
#  ['job'],
#  ['nt', 'matterspodcasts', 'notification', 'setting'],
#  ['thanks', 'job'],
#  ['question', 'huh'],
#  [],
#  ['chickensauce', 'turn', 'bot'],
#  ['raid'],
#  ['chickensauce', 'turn', 'join'],
#  ['raid'],
#  ['report', 'discord'],
#  ['raid'],
#  ['attack', 'group'],
#  ['sort', 'rest'],
#  ['lot', 'people', 'time'],
#  ['body', 'thing', 'look', 'mod', 'care'],
#  ['hello',
#   'admin',
#   'bluewillowai',
#   'sure',
#   'admin',
#   'message',
#   'thanks',
#   'advance'],
#  ['ticket', 'staff', 'mod'],
#  ['thanks', 'lot'],
#  [],
#  ['search', 'username'],
#  ['admins', 'online'],
#  ['fix', 'right'],
#  [],
#  ['permission', 'bot', 'role'],
#  ['admins', 'ability'],
#  ['sorry'],
#  ['hope'],
#  ['art'],
#  ['server'],
#  ['way', 'dimension'],
#  ['seed', 'etc'],
#  ['picture', 'diffusion'],
#  ['guy', 'documentation', 'use', 'prompt', 'stuff', 'etc'],
#  ['documentation'],
#  [],
#  ['guy', 'staff', 'level'],
#  [],
#  ['answer', 'gotten', 'tbh'],
#  ['wonder', 'midjourney', 'data', 'i', 've', 'way', 'generator'],
#  ['publish', 'source', 'code'],
#  ['mid', 'journey'],
#  ['picture', 'money'],
#  ['mid', 'journey'],
#  [],
#  ['level'],
#  ['thing', 'stuff'],
#  ['use', 'well', 'source', 'afaik'],
#  ['look'],
#  ['nt', 'journey', 'know'],
#  ['training',
#   'data',
#   'matter',
#   'lot',
#   'base',
#   'stability',
#   'scraper',
#   'online',
#   'data',
#   'set',
#   'community',
#   'generation',
#   'model',
#   'usage',
#   'lot'],
#  ['level'],
#  ['sound', 'fishy', 'channel', 'leveling', 'feature', 'server'],
#  ['sort', 'documentation'],
#  ['woah', 'lot'],
#  ['bluewillow', 'tbh'],
#  [],
#  ['knowledge', 'image', 'generation', 'stuff'],
#  ['accurate', 'support'],
#  ['generation', 'dity', '_', 'time'],
#  ['issue', 'delete', 'user'],
#  ['report', 'report'],
#  ['diffusion',
#   'filter',
#   'lot',
#   'people',
#   'stuff',
#   'tbh',
#   'part',
#   'nsfw',
#   'channel'],
#  ['agree'],
#  ['end',
#   'day',
#   'data',
#   've',
#   'dalle',
#   'generate',
#   'knife',
#   'example',
#   'part',
#   'list',
#   'word'],
#  ['safe'],
#  ['word', 'list'],
#  ['lot', 'actor'],
#  ['warning', 'user', 'thank'],
#  ['model', 'data'],
#  [],
#  ['somepoint', 'cover', 'cost', 'way'],
#  ['way', 'picture', 'phone', 'art'],
#  ['internet'],
#  ['discord', 'phone'],
#  [],
#  ['thing'],
#  ['see'],
#  [],
#  ['art', 'stolen'],
#  [],
#  ['realize', 'art', 'image'],
#  ['idk', 'game', 'video', 'game', 'character'],
#  ['model', 'way', 'reference', 'photo', 'imagine', 'promptwwwphotocom'],
#  ['feature', 'stay', 'announcement'],
#  ['midjourney', 'copycat'],
#  ['time', 'use'],
#  [],
#  [],
#  ['point', 'fee', 'keep', 'cover', 'cost', 'pocket'],
#  ['pay', 'exclusivity', 'share', 'image'],
#  ['somepoint', 'offer'],
#  ['thing'],
#  ['character', 'thing', 'type', 'eren', 'yeager', 'space', 'ship'],
#  ['anyways', 'search', 'anime'],
#  ['random', 'image'],
#  ['anime', 'thanks'],
#  ['question'],
#  ['guy', 'staff'],
#  ['wafarer', 'keywords', 'image', 'generate'],
#  ['way'],
#  ['character'],
#  ['guy', 'staff', 'level'],
#  ['use', 'bot'],
#  ['type', 'imagine', 'image', 'example', 'bull', 'frog', 'park', 'bench'],
#  ['type', 'give'],
#  ['level'],
#  ['issue', 'image', 'idea'],
#  [],
#  ['size'],
#  ['thing'],
#  ['try'],
#  ['difference'],
#  ['midjourney'],
#  ['level'],
#  ['mage', 'level'],
#  ['people'],
#  ['midjourney', 'cost', 'money', 'lot', 'need', 'time', 'state'],
#  ['art', 'picture'],
#  ['feature'],
#  ['thanks', 'question'],
#  ['ellats', 'level'],
#  ['image', 'model', 'age'],
#  ['adult', 'image', 'child'],
#  ['explain', 'post', 'screen', 'bot', 'tell', 'time', 'know', 'error'],
#  ['ticket', 'deletedchannel', 'post', 'issue', 'staff'],
#  ['lol', 'timeout', 'file', 'join', 'chat'],
#  ['level'],
#  ['post', 'yourhighlights'],
#  ['post', 'check', 'filename', 'content'],
#  ['file', 'name', 'file', 'name', 'bot', 'file', 'name', 'message', 'lol'],
#  ['timeout', 'lol'],
#  ['job', 'thing', 'body', 'head', 'screen'],
#  ['thank', 'get'],
#  ['software', 'make', 'time'],
#  ['speak', 'software', 'use', 'screen', 'bot'],
#  ['profile', 'picture', 'lol'],
#  ['look'],
#  ['timeout', 'lol'],
#  ['gib', 'badge', 'plz'],
#  ['corn', 'king'],
#  ['reminder',
#   'please',
#   'link',
#   'member',
#   'continue',
#   'condone',
#   'link',
#   'discord',
#   'intention',
#   'user',
#   'link',
#   'link',
#   'competition',
#   'people'],
#  ['idea',
#   'expand',
#   'community',
#   'youtubers',
#   'community',
#   'blogger',
#   'feature',
#   'thanks'],
#  ['link', 'discord', 'channel'],
#  ['share', 'channel', 'image', 'generation', 'server'],
#  ['thanks'],
#  ['tool'],
#  ['invitation', 'link'],
#  ['thread'],
#  ['subscription', 'midjourney'],
#  ['gotten', 'join', 'server', 'ykw', 'fck'],
#  ['use', 'bot'],
#  ['hope', 'others', 'deletedchannel', 'sorry', 'kind', 'remind', 'swore'],
#  ['check', 'deletedchannel'],
#  ['apology'],
#  ['worry'],
#  ['look'],
#  ['android_sob'],
#  ['place'],
#  ['help', 'prompt', 'time', 'result', 'want', 'help'],
#  [],
#  ['generator', 'textbook'],
#  [],
#  ['change', 'become', 'bettter'],
#  ['doubt'],
#  [],
#  ['computation', 'time', 'nt', 'cheap'],
#  ['midjourney', 'cost', 'money', 'generation'],
#  ['reality'],
#  ['hope'],
#  ['use', 'boy'],
#  [],
#  [],
#  ['stay',
#   'creator',
#   'release',
#   'feature',
#   'user',
#   'cover',
#   'cost',
#   'user',
#   'room',
#   'ability',
#   'image',
#   'access',
#   'community',
#   'please',
#   'share',
#   'feature',
#   'see'],
#  ['alright'],
#  ['question', 'detail', 'look'],
#  ['dr3amak3r', 'level'],
#  ['nt', 'damn'],
#  ['doubt', 'limit', 'prompt'],
#  ['longer'],
#  ['squanchy', 'fonk'],
#  ['alrighty'],
#  ['squanchy', 'level'],
#  ['use'],
#  ['bot'],
#  ['sorry', 'bot', 'cause', 'competition'],
#  [],
#  ['yes', 'check', 'deletedchannel'],
#  ['pog', 'art'],
#  ['ownership', 'creation'],
#  ['check', 'info', 'deletedchannel'],
#  ['use', 'depiction', 'identity', 'humor'],
#  ['topic', 'view', 'yeah', 'type', 'terrorism', 'content', 'read', 'rule'],
#  ['competition', 'brand', 'spam'],
#  ['competition', 'spam'],
#  ['wiil', 'take'],
#  ['yea', 'people', 'dmd', 'server'],
#  ['word'],
#  ['wmthn'],
#  ['link'],
#  ['message', 'link'],
#  ['spread', 'altsbots'],
#  ['send'],
#  ['midjourney', 'pricing'],
#  ['bluewillow'],
#  ['thing', 'model', 'check', 'deletedchannel'],
#  [],
#  ['amount', 'generation'],
#  ['bot', 'abble', 'server'],
#  ['feature'],
#  ['oooh', 'wait'],
#  ['face'],
#  ['bot', 'block', 'advertising'],
#  ['bot'],
#  ['afterwards'],
#  ['look', 'screenshot'],
#  ['meant'],
#  ['people', 'dm'],
#  ['yeah', 'understand', 'pop', 'message'],
#  ['yes', 'somebody'],
#  ['admin', 'badge'],
#  ['gym'],
#  ['use'],
#  ['super', 'glad', 'deletedchannel'],
#  ['hey', 'redundant', 'difference', 'mid', 'journey'],
#  ['image',
#   'midjourney',
#   'model',
#   'strength',
#   'weakness',
#   'midjourney',
#   'midjourney',
#   'model',
#   'thing',
#   'aim',
#   'model',
#   'result',
#   'disclaimer',
#   'aggregate',
#   'midjourney',
#   'model'],
#  ['model'],
#  [],
#  ['support'],
#  ['hey'],
#  ['question'],
#  ['generation', 'way', 'prompt'],
#  ['faq', 'sense', 'variation', 'switcher', 'prompt', 'model', 'embeddings'],
#  ['diffusion',
#   'model',
#   'ask',
#   'way',
#   'provide',
#   'diffusion',
#   'ghibli',
#   'diffusion'],
#  ['model',
#   'civitai',
#   'huggingface',
#   'use',
#   'nlp',
#   'model',
#   'checkpoint',
#   'keywords',
#   'cartoon',
#   'etc',
#   'spin',
#   'paper',
#   'space',
#   'banana',
#   'dev',
#   'replicate',
#   'generate',
#   'imagery'],
#  ['s'],
#  ['model', 'version'],
#  ['model', 'waifu'],
#  ['wonder',
#   'fast',
#   'serverless',
#   'env',
#   'spin',
#   'spin',
#   'model',
#   'rtx',
#   'card',
#   'gb',
#   'take',
#   'load',
#   'model'],
#  ['please', 'spamming'],
#  ['dm', 'owner', 'discord'],
#  ['yep', 'message', 'join', 'kind', 'contest'],
#  ['yeah', 'thing', 'dm', 'style'],
#  [],
#  ['yeah', 'goal'],
#  ['yeah', 'share', 'channel', 'see'],
#  ['message'],
#  ['work', 'dma'],
#  ['prevent'],
#  ['bot'],
#  ['feature'],
#  ['theme'],
#  ['check', 'dailytheme'],
#  ['nt', 'guy', 'campaign', 'hell'],
#  ['s', 'link', 'please', 'spam'],
#  ['lord', 'tag', 'role'],
#  ['random', 'cool'],
#  ['confusion',
#   'concern',
#   'competition',
#   'invitation',
#   'way',
#   'competition',
#   'goal',
#   'friend',
#   'people',
#   'spam',
#   'assure',
#   'prevent',
#   'incident',
#   'thank',
#   'understanding'],
#  ['people', 'check'],
#  ['message', 'tho'],
#  ['damn', 'fun', 'tho', 'lol'],
#  ['btw', 'work', 'thing', 'channel'],
#  ['hope',
#   'check',
#   'deletedchannel',
#   'use',
#   'command',
#   'pick',
#   'rookie20',
#   'channel',
#   'use',
#   'info',
#   'deletedchannel'],
#  ['very_souless1', 'level'],
#  ['question', 'way', 'count', 'reading', 'point', 'competition', 'count'],
#  [],
#  ['community', 'whole', 'project', 'neat'],
#  ['hey', 'guy', 'bluewillow', 'discordserver'],
#  [],
#  ['hey', 'diffusion', 'midjourney'],
#  ['goal', 'incentivise', 'bot', 'usage'],
#  ['link', 'work'],
#  ['way', 'server'],
#  ['reason', 'announcement', 'channel'],
#  ['level'],
#  ['link'],
#  ['staff', 'position', 'lol'],
#  ['look', 'random', 'lead', 'competition', 'end', 'think'],
#  [],
#  ['channel'],
#  ['yikes', 'lol'],
#  ['think', 'command'],
#  ['mighty', 'convenient'],
#  ['i', 've', 'time', 'people', 'randomly'],
#  ['think', 'admins'],
#  ['doc', 'channel', 'work'],
#  ['beta', 'mode', 'bot', 'moment'],
#  ['guy', 'work'],
#  ['thanks'],
#  ['imagine', 'prompt'],
#  ['thing', 'work', 'others'],
#  ['thanks'],
#  ['people', 'thinking', 'admins'],
#  ['wait', 'minute', 'cash', 'prize', 'contest'],
#  ['result', 'spam', 'alt', 'abuse', 'intent', 'contest', 'message', 'friend'],
#  ['glad', 'message'],
#  ['message', 'discord', 'server', 'staff', 'reputation', 'server'],
#  ['message', 'contest'],
#  ['koolgamer', 'level'],
#  ['holy', 'shit'],
#  ['warns'],
#  ['cash', 'prize', 'people', 'extreme', 'bot', 'people', 'friend', 'etc'],
#  ['dollar', 'amount', 'discourage', 'bot', 'behavior'],
#  ['sorry', 'spam', 'strategy', 'future'],
#  ['stop', 'bot', 'change', 'competition'],
#  ['documentation', 'command', 'line', 'symbol'],
#  [],
#  ['thanks'],
#  ['use'],
#  ['command', 'prompt'],
#  ['check', 'deletedchannel'],
#  ['limit', 'image'],
#  ['cause', 'i', 'hour'],
#  ['look', 'lead'],
#  ['competition', 'end'],
#  ['wot'],
#  ['level'],
#  ['people'],
#  ['invite', 'discord'],
#  ['httpsdiscordcominvitepm7ccyub'],
#  ['question'],
#  ['service'],
#  ['check', 'deletedchannel'],
#  ['website'],
#  ['discordggbluewillow'],
#  ['think'],
#  ['model'],
#  ['help', 'darth', 'vader', 'officer', 'world', 'war', 'find', 'promt'],
#  ['try', 'promptdiscussion', 'swap', 'word', 'play'],
#  ['generate', 'image', 'url'],
#  ['feature'],
#  ['dr3amak3r', 'creator'],
#  ['dr3amak3r',
#   'twitter',
#   'instagram',
#   'love',
#   'check',
#   'work',
#   'praise',
#   'work'],
#  ['dr3amak3r', '_'],
#  ['day'],
#  ['kind', 'problem'],
#  ['report', 'content', 'see'],
#  ['dm', 'server', 'name'],
#  ['nope'],
#  ['welcome'],
#  ['guy', 'commande', 'copy', 'make', 'result'],
#  [],
#  ['disign'],
#  ['picture', 'variation', 'item'],
#  ['copy', 'picture', 'adress', 'get'],
#  ['trial'],
#  ['wait', 'copy', 'paste', 'midjourney', 'lol'],
#  ['thing'],
#  ['tool', 'concept'],
#  ['bluewillow'],
#  ['competition', 'tho'],
#  ['gon'],
#  [],
#  [],
#  ['get'],
#  ['get'],
#  ['work', 'man'],
#  ['tbh', 'people'],
#  ['role', 'thing', 'btw'],
#  ['use', 'lmao'],
#  [],
#  ['display', 'picture'],
#  ['post', 'art'],
#  ['use', 'server', 'post', 'drawing'],
#  ['post', 'art'],
#  ['post', 'yourhighlights'],
#  ['deletedchannel', 'people', 'support', 'use', 'tool'],
#  ['variation'],
#  ['select'],
#  [],
#  [],
#  [],
#  ['lol',
#   'contest',
#   'youtube',
#   'channel',
#   'video',
#   'competition',
#   'please',
#   'community'],
#  ['channel', 'promote'],
#  ['man'],
#  ['people', 'alt', 'account', 'annoyance'],
#  ['tho', 'smth'],
#  ['self', 'promotion', 'video', 'httpsyoutubemi2jotcgjqa'],
#  ['botting'],
#  ['video', 'thanks', 'review', 'community'],
#  ['check', 'channel', 'subscribe'],
#  ['community', 'generation', 'fee'],
#  ['worthwhile', 'goal'],
#  ['please'],
#  ['wait', 'minute', 'price'],
#  ['way', 'resolution', 'image'],
#  ['ityger', 'level'],
#  ['video', 'ftp', 'thank', 'check', 'channel'],
#  ['channel', 'appreciate', 'review'],
#  ['inv', 'blue', 'bot', 'server'],
#  [],
#  ['time'],
#  [],
#  ['sleep'],
#  ['chickensauce', 'please'],
#  ['user', 'level'],
#  ['alr', 'peace'],
#  ['art', 'post', 'discord', 'server'],
#  ['level'],
#  ['competition'],
#  ['bec', 'instagram', 'post', 'section'],
#  ['channel'],
#  ['name', 'channel', 'couple', 'moment', 'public'],
#  ['hey', 'picture', 'file', 'imagine', 'prompt'],
#  ['feature'],
#  ['thanks'],
#  ['time'],
#  [],
#  ['stay'],
#  ['thanks', 'competition', 'look'],
#  ['hit'],
#  ['lot'],
#  ['influx'],
#  ['wtf'],
#  [],
#  ['use', 'bot'],
#  ['start', 'prompt'],
#  ['bluewillow'],
#  ['torcello', 'level'],
#  ['invite', 'bluewillow'],
#  ['click', 'server', 'name', 'drop', 'menu', 'invite', 'people'],
#  [],
#  ['found'],
#  ['screen', 'see', 'name', 'server', 'click'],
#  ['invite', 'discord', 'icon', 'invite'],
#  ['message', 'invite', 'link'],
#  ['create', 'face', 'eagle'],
#  ['promptdiscussion',
#   'bit',
#   'wordsnumbers',
#   'face',
#   'body',
#   'face',
#   'body',
#   'face',
#   'etc'],
#  ['level'],
#  ['need', 'use', 'picture'],
#  ['midjourney', 'function', 'platform', 'functionality'],
#  ['cool', 'write'],
#  ['people', 'output'],
#  ['thanks'],
#  ['click', 'server', 'name', 'drop', 'menu', 'people', 'side'],
#  ['need', 'help'],
#  ['level'],
#  ['picture', 'query'],
#  ['beta', 'mode'],
#  ['competition'],
#  ...]
